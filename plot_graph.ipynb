# %%
import matplotlib.pyplot as plt
import numpy as np
from pylab import plot, show, title, xlabel, ylabel
from pylab import legend
from pylab import axis

# %%
    ##กำลังเพิ่มการเเก้ไข

    fig, ax = plt.subplots(figsize=(16, 9))
    
    #scores
    sc = [0.9629,0.8962,0.9308,0.9679,0.9802,0.9975,0.9901,0.9777]
    sc1 = [0.8962,0.9135,0.8987,0.8938,0.8938,0.8814,0.8049,0.8543]
    sc2 = [0.7580,0.6913,]
    sc3 = [0.9382,0.9012]
    sc4 = 0.9135
    sc5 = 0.8493
    sc6 = 0.9037
    sc7 = 0.8469
    #paremeter
    para = [5.3,7.8,9.2,12,19,30,43,66]
    para2 = [23.59,42.66]
    para3 = [23.56,42.63]
    para4 = 4.2
    para5 = 54
    para6 = 22
    para7 = 84.9
    #networks name
    nets = ['Eff-B0','Eff-B1','Eff-B2','Eff-B3','Eff-B4','Eff-B5','Eff-B6','Eff-B7']
    nets2 = ['ResNet-50','ResNet-101']
    nets3 = ['ResNet-50-V2','ResNet-101-V2']
    nets4='NASNetMobile'
    nets5='InceptionResNetV2'
    nets6='InceptionV3'
    nets7='NASNetLarge'
    # setting x and y axis range 
    plt.ylim(0.68,1.03) 
    plt.xlim(0.00,88.00) 
    # plotting the points  
    plt.plot(para, sc , color='#c65102', linestyle='-', linewidth = 2, marker='o', markerfacecolor='r', markersize=8) 
    plt.plot(para, sc1, color='#047495', linestyle='-', linewidth = 2, marker='o', markerfacecolor='#0165fc', markersize=8) 
    plt.plot(para2, sc2, color='#c65102', linestyle='dashed', linewidth = 2, marker='o', markerfacecolor='r', markersize=8) 
    plt.plot(para3, sc3, color='#c65102', linestyle='dashed', linewidth = 2, marker='o', markerfacecolor='r', markersize=8) 
    plt.plot(para4, sc4, color='#c65102', marker='o',linestyle=' ', markerfacecolor='r', markersize=8) 
    plt.plot(para5, sc5, color='#c65102', marker='o',linestyle=' ', markerfacecolor='r', markersize=8) 
    plt.plot(para6, sc6, color='#c65102', marker='o',linestyle=' ', markerfacecolor='r', markersize=8) 
    plt.plot(para7, sc7, color='#c65102', marker='o',linestyle=' ', markerfacecolor='r', markersize=8)     
    for i in range(0,6):
        label = "{:}".format(nets[i+2])
        plt.annotate(label, (para[i+2], sc[i+2]), textcoords="offset points", xytext=(0,10), ha='center')
        plt.annotate(label, (para[i+2], sc1[i+2]), textcoords="offset points", xytext=(0,-20), ha='center') 
    plt.annotate(nets[0], (para[0], sc[0]), textcoords="offset points", xytext=(0,10), ha='center')
    plt.annotate(nets[0], (para[0], sc1[0]), textcoords="offset points", xytext=(0,-20), ha='center')
    plt.annotate(nets[1], (para[1], sc[1]), textcoords="offset points", xytext=(0,10), ha='center')
    for i in range(0,len(para2)):
        label1 = "{:}".format(nets2[i])
        plt.annotate(label1, (para2[i], sc2[i]), textcoords="offset points", xytext=(0,10), ha='center')
    for i in range(0,len(para3)):
        label2= "{:}".format(nets3[i])
        plt.annotate(label2, (para3[i], sc3[i]), textcoords="offset points", xytext=(0,10), ha='center')    
    
    plt.annotate(nets4, (para4, sc4), textcoords="offset points", xytext=(0,10), ha='center')      
    plt.annotate(nets5, (para5, sc5), textcoords="offset points", xytext=(0,10), ha='center') 
    plt.annotate(nets6, (para6, sc6), textcoords="offset points", xytext=(0,10), ha='center') 
    plt.annotate(nets7, (para7, sc7), textcoords="offset points", xytext=(0,10), ha='center') 
    # Apply the legend to tell the graphs apart
       #legend(['EffNet(ImageNet)', 'EffNet(Noisy-Student)','ResNet(ImageNet)','ResNet-V2(ImageNet)'])
    legend(['ImageNet', 'Noisy-Student'], bbox_to_anchor=(0.15,0.12))

    # Apply the TITLE, X-axis and Y-axis label
    title(' Performance comparison',fontsize=20)
    xlabel('Number of Parameters(Millions)',fontsize=18)
    ylabel('Accuracy',fontsize=18)

    show()

# %%
fig, ax = plt.subplots(figsize=(20, 9))
    
#scores
sc = [0.9629,0.96049,0.9432,0.9629,0.9283,0.9777,0.953]

#paremeter
para = [3,415,784,3025,3629,3927,3982]

#networks name
nets = ['B0-2','B0-5','B0-8','B0-60','B0-99','B0-138','B0-164']

# setting x and y axis range 
plt.ylim(0.90,1.03) 
plt.xlim(-40.00,4200.00) 

# plotting the points  
plt.plot(para, sc , color='#c65102', linestyle='-', linewidth = 2, marker='o', markerfacecolor='r', markersize=8)  
   
for i in range(0,len(para)):
    label = "{:}".format(nets[i])
    plt.annotate(label, (para[i], sc[i]), textcoords="offset points", xytext=(0,10), ha='center')
     
# Apply the legend to tell the graphs apart
legend(['EffNet B0'], bbox_to_anchor=(0.10,0.09))

# Apply the TITLE, X-axis and Y-axis label
title(' Performance comparison',fontsize=20)
xlabel('Number of Parameters(Thousands)',fontsize=18)
ylabel('Accuracy',fontsize=18)

show()

# %%
#สมบูรณ์

# %%
fig, ax = plt.subplots(figsize=(20, 9))
    
#scores
sc = [0.9629,0.96049,0.958,0.9629,0.9283,0.9777,0.953]
sc1 =[0.9975,0.8938,0.9382,0.9358,0.9876,0.995,0.9753]

#paremeter
para = [3,415,784,3025,3629,3927,3982]
para1 = [4,1056,9944,22656,26082,27843,28193]
#networks name
nets = ['B0-2','B0-5','B0-8','B0-60','B0-99','B0-138','B0-164']
nets1 = ['B5-2','B5-5','B5-34','B5-151','B5-242','B5-333','B5-398']
# setting x and y axis range 
plt.ylim(0.87,1.03) 
plt.xlim(-200.00,28500.00) 

# plotting the points  
plt.plot(para, sc , color='#c65102', linestyle='-', linewidth = 2, marker='o', markerfacecolor='r', markersize=8)  
plt.plot(para1, sc1 , color='#047495', linestyle='-', linewidth = 2, marker='o', markerfacecolor='b', markersize=8)  

for i in range(0,len(para)):
    label = "{:}".format(nets[i])
    plt.annotate(label, (para[i], sc[i]), textcoords="offset points", xytext=(0,10), ha='center')
for i in range(0,len(para1)):
    label = "{:}".format(nets1[i])
    plt.annotate(label, (para1[i], sc1[i]), textcoords="offset points", xytext=(0,10), ha='center')
     
# Apply the legend to tell the graphs apart
legend(['EffNet B0','EffNet B5'], bbox_to_anchor=(0.12,0.09))

# Apply the TITLE, X-axis and Y-axis label
title(' Performance comparison',fontsize=20)
xlabel('Number of Parameters(Thousands)',fontsize=18)
ylabel('Accuracy',fontsize=18)

show()

# %%
import matplotlib.pyplot as plt
import numpy as np

fig, ax = plt.subplots(figsize=(20, 9))

# using some dummy data for this example
xs = ['R1','top_conv','block7a_project_conv','block6a_se_excite','block5a_se_excite','block4a_se_excite','block3a_se_excite']
xs1 = ['R1','top_conv','block7a_project_conv','block6a_se_excite','block5a_se_excite','block4a_se_excite','block3a_se_excite']

ys = [0.9629,0.96049,0.958,0.9629,0.9283,0.9777,0.953]
ys1 =[0.9975,0.8938,0.9382,0.9358,0.9876,0.995,0.9753]

label = ['B0-2','B0-5','B0-8','B0-60','B0-99','B0-138','B0-164']
label1 = ['B5-2','B5-5','B5-34','B5-151','B5-242','B5-333','B5-398']

# setting x and y axis range 
plt.ylim(0.90,1.01) 
# plt.xlim(-200.00,28500.00) 

# 'bo-' means blue color, round points, solid lines
plt.plot(xs,ys,color='#650021', linestyle='-', linewidth = 2, marker='o', markerfacecolor='r', markersize=8)
# plt.plot(xs1,ys1,color='#047495', linestyle='-', linewidth = 2, marker='o', markerfacecolor='b', markersize=8)
# zip joins x and y coordinates in pairs
# for i in range(0,len(ys)):

#     plt.annotate(label[i], # this is the text
#                  (xs[i],ys[i]), # this is the point to label
#                  textcoords="offset points", # how to position the text
#                  xytext=(0,10), # distance from text to points (x,y)
#                  ha='center',fontsize=12) # horizontal alignment can be left, right or center

for i in range(0,len(ys)):
        label = "{:}".format(ys[i])
        plt.annotate(label, (xs[i], ys[i]), textcoords="offset points", xytext=(0,10), ha='center',fontsize=12)

# for i in range(0,len(ys)):
#     plt.annotate(label1[i], # this is the text
#                  (xs1[i],ys1[i]), # this is the point to label
#                  textcoords="offset points", # how to position the text
#                  xytext=(0,10), # distance from text to points (x,y)
#                  ha='center') # horizontal alignment can be left, right or center

# Apply the legend to tell the graphs apart
# legend(['EffNet B0','EffNet B5'], bbox_to_anchor=(0.10,0.10))
legend(['EffNet B0'], bbox_to_anchor=(0.13,0.10),fontsize=12)
# Apply the TITLE, X-axis and Y-axis label
title(' Performance comparison',fontsize=20)
xlabel('Unfreeze layers',fontsize=18)
ylabel('Accuracy',fontsize=18)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

fig, ax = plt.subplots(figsize=(20, 9))

# using some dummy data for this example
# xs = ['R1','top_conv','block7a_project_conv','block6a_se_excite','block5a_se_excite','block4a_se_excite','block3a_se_excite']
xs1 = ['R1','top_conv','block7a_project_conv','block6a_se_excite','block5a_se_excite','block4a_se_excite','block3a_se_excite']

# ys = [0.9629,0.96049,0.958,0.9629,0.9283,0.9777,0.953]
# ys1 =[0.9975,0.8938,0.9382,0.9358,0.9876,0.995,0.9753]
ys1 =[0.98,0.8938,0.9382,0.9358,0.9876,0.995,0.9753]

# label = ['B0-2','B0-5','B0-8','B0-60','B0-99','B0-138','B0-164']
label1 = ['B5-2','B5-5','B5-34','B5-151','B5-242','B5-333','B5-398']

# setting x and y axis range 
plt.ylim(0.85,1.01) 
plt.plot(xs1,ys1,color='#650021', linestyle='-', linewidth = 2, marker='o', markerfacecolor='r', markersize=8)

for i in range(0,len(ys1)):
        label = "{:}".format(ys1[i])
        plt.annotate(label, (xs1[i], ys1[i]), textcoords="offset points", xytext=(0,10), ha='center',fontsize=12)

legend(['EffNet B5'], bbox_to_anchor=(0.13,0.10),fontsize=12)
# Apply the TITLE, X-axis and Y-axis label
title(' Performance comparison',fontsize=20)
xlabel('Unfreeze layers',fontsize=18)
ylabel('Accuracy',fontsize=18)

plt.show()

# %%
#___________________________________________________________________________________________

# %%
# By batch size

import matplotlib.pyplot as plt
import numpy as np

fig, ax = plt.subplots(figsize=(20, 9))

# using some dummy data for this example
xs = ['1','2','4','8','16','32','64','128']

ys = [0.9827,0.9827,0.9802,0.9851,0.9851,0.9629,0.9802,0.9728]

# setting x and y axis range 
plt.ylim(0.95,1.01) 
# plt.xlim(-200.00,28500.00) 

# 'bo-' means blue color, round points, solid lines
plt.plot(xs,ys,color='#650021', linestyle='-', linewidth = 2, marker='o', markerfacecolor='r', markersize=8)

for i in range(0,len(ys)):
        label = "{:}".format(ys[i])
        plt.annotate(label, (xs[i], ys[i]), textcoords="offset points", xytext=(0,10), ha='center',fontsize=12)

# Apply the legend to tell the graphs apart
legend(['EffNet B5'], bbox_to_anchor=(0.150,0.150),fontsize=14)

# Apply the TITLE, X-axis and Y-axis label
title(' Performance comparison',fontsize=20)
xlabel('Batch size',fontsize=18)
ylabel('Accuracy',fontsize=18)

plt.show()

# %%
# By batch size

import matplotlib.pyplot as plt
import numpy as np

fig, ax = plt.subplots(figsize=(20, 9))

# using some dummy data for this example
xs = ['1','2','4','8','16','32','64','128']

ys = [0.9827,0.9827,0.9802,0.9851,0.9851,0.9629,0.9802,0.9728]

# label = ['B0-2','B0-5','B0-8','B0-60','B0-99','B0-138','B0-164']

# setting x and y axis range 
plt.ylim(0.95,1.01) 
# plt.xlim(-200.00,28500.00) 

# 'bo-' means blue color, round points, solid lines
plt.plot(xs,ys,color='#650021', linestyle='-', linewidth = 2, marker='o', markerfacecolor='r', markersize=8)

for i in range(0,len(ys)):
        label = "{:}".format(ys[i])
        plt.annotate(label, (xs[i], ys[i]), textcoords="offset points", xytext=(0,10), ha='center',fontsize=12)

# Apply the legend to tell the graphs apart
legend(['EffNet B5'], bbox_to_anchor=(0.150,0.150),fontsize=14)

# Apply the TITLE, X-axis and Y-axis label
title(' Performance comparison',fontsize=20)
xlabel('Batch size',fontsize=18)
ylabel('Accuracy',fontsize=18)

plt.show()

# %%
#___________________________________________________________________________________________

# %%
#Compare EffNet B0,B5 Unfreeze layer 

import matplotlib.pyplot as plt
import numpy as np

fig, ax = plt.subplots(figsize=(20, 9))

# using some dummy data for this example
xs = ['R1','top_conv','block7a_project_conv','block6a_se_excite','block5a_se_excite','block4a_se_excite','block3a_se_excite']
xs1 = ['R1','top_conv','block7a_project_conv','block6a_se_excite','block5a_se_excite','block4a_se_excite','block3a_se_excite']

ys = [0.9629,0.96049,0.958,0.9629,0.9283,0.9777,0.953]
ys1 =[0.9975,0.8938,0.9382,0.9358,0.9876,0.995,0.9753]

label = ['B0-2','B0-5','B0-8','B0-60','B0-99','B0-138','B0-164']
label1 = ['B5-2','B5-5','B5-34','B5-151','B5-242','B5-333','B5-398']

# setting x and y axis range 
plt.ylim(0.87,1.01) 
# plt.xlim(-200.00,28500.00) 

# 'bo-' means blue color, round points, solid lines
plt.plot(xs,ys,color='#c65102', linestyle='-', linewidth = 2, marker='o', markerfacecolor='r', markersize=8)
plt.plot(xs1,ys1,color='#047495', linestyle='-', linewidth = 2, marker='o', markerfacecolor='b', markersize=8)
# zip joins x and y coordinates in pairs
for i in range(0,len(ys)):

    plt.annotate(label[i], # this is the text
                 (xs[i],ys[i]), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,10), # distance from text to points (x,y)
                 ha='center') # horizontal alignment can be left, right or center

for i in range(0,len(ys)):
    plt.annotate(label1[i], # this is the text
                 (xs1[i],ys1[i]), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,10), # distance from text to points (x,y)
                 ha='center') # horizontal alignment can be left, right or center

# Apply the legend to tell the graphs apart
legend(['EffNet B0','EffNet B5'], bbox_to_anchor=(0.10,0.10))

# Apply the TITLE, X-axis and Y-axis label
title(' Performance comparison',fontsize=20)
xlabel('Unfreeze layers',fontsize=18)
ylabel('Accuracy',fontsize=18)

plt.show()

# %%
label = ['B0-2','B0-5','B0-8','B0-60','B0-99','B0-138','B0-164']
label1 = ['B5-2','B5-5','B5-34','B5-151','B5-242','B5-333','B5-398']

# %%
import matplotlib.pyplot as plt
import numpy as np

fig, ax = plt.subplots(figsize=(20, 9))

# using some dummy data for this example
xs = ['R1','top_conv','block7a_project_conv','block6a_se_excite','block5a_se_excite','block4a_se_excite','block3a_se_excite']
xs1 = ['R1','top_conv','block7a_project_conv','block6a_se_excite','block5a_se_excite','block4a_se_excite','block3a_se_excite']
xs2 = ['top_conv','block7a_project_conv','block6a_se_excite','block5a_se_excite','block4a_se_excite','block3a_se_excite']
xs3 = ['top_conv','block7a_project_conv','block6a_se_excite','block5a_se_excite','block4a_se_excite','block3a_se_excite']

ys = [0.9629,0.96049,0.958,0.9629,0.9283,0.9777,0.953]
ys1 = [0.9975,0.8938,0.9382,0.9358,0.9876,0.995,0.9753]
ys2 = [0.8518,0.8419,0.9432,0.9876,0.995,0.9925]
ys3 = [0.8024,0.9086,0.9703,0.9679,0.9925,0.9753]

label = ['B0-2','B0-5','B0-8','B0-60','B0-99','B0-138','B0-164']
label1 = ['B5-32','B5-32','B5-32','B5-32','B5-16','B5-16','B5-8']
label2 = ['B5-16','B5-16','B5-16','B5-16']

# setting x and y axis range 
plt.ylim(0.79,1.01) 
# plt.xlim(-200.00,28500.00) 

# 'bo-' means blue color, round points, solid lines
plt.plot(xs,ys,color='#c65102', linestyle='-', linewidth = 2, marker='o', markerfacecolor='r', markersize=8)
plt.plot(xs1,ys1,color='#047495', linestyle='-', linewidth = 2, marker='o', markerfacecolor='b', markersize=8)
plt.plot(xs2,ys2,color='#ae7181', linestyle='-', linewidth = 2, marker='o', markerfacecolor='#ff028d', markersize=8)
plt.plot(xs3,ys3,color='#40a368', linestyle='-', linewidth = 2, marker='o', markerfacecolor='#01ff07', markersize=8)
# plt.plot(xs1,ys1,color='#047495', linestyle='-', linewidth = 2, marker='o', markerfacecolor='b', markersize=8)

# zip joins x and y coordinates in pairs
for i in range(0,len(ys)):

    plt.annotate(label[i], # this is the text
                 (xs[i],ys[i]), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,10), # distance from text to points (x,y)
                 ha='center') # horizontal alignment can be left, right or center

for i in range(0,len(ys)):
    plt.annotate(label1[i], # this is the text
                 (xs1[i],ys1[i]), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,10), # distance from text to points (x,y)
                 ha='center') # horizontal alignment can be left, right or center
    
# for i in range(0,len(label2)):
#     plt.annotate(label2[i], # this is the text
#                  (xs2[i],ys2[i]), # this is the point to label
#                  textcoords="offset points", # how to position the text
#                  xytext=(0,10), # distance from text to points (x,y)
#                  ha='center') # horizontal alignment can be left, right or center
    
# plt.annotate(label2[-1], (xs1[-1], ys2[-1]), textcoords="offset points", xytext=(0,10), ha='center') 

# Apply the legend to tell the graphs apart
legend(['EffNet B0 32','EffNet B5','EffNet B5 16','EffNet B5 8'], bbox_to_anchor=(1.0,0.148))

# Apply the TITLE, X-axis and Y-axis label
title(' Performance comparison',fontsize=20)
xlabel('Unfreeze layers',fontsize=18)
ylabel('Accuracy',fontsize=18)

plt.show()

# %%
[0.8024,0.9086,0.9679,0.9925,0.9753]

# %%
##ยังไม่เพิ่ม

# %%
    fig, ax = plt.subplots(figsize=(14, 8))
    
    #scores
    sc = [0.9629,0.8962,0.9308,0.9679,0.9802,0.9975,0.9901,0.9777]
    sc1 = [0.8962,0.9135,0.8987,0.8938,0.8938,0.8814,0.8049,0.8543]
    sc2 = [0.7580,0.6913,]
    sc3 = [0.9382,0.9012]
    #paremeter
    para = [5.3,7.8,9.2,12,19,30,43,66]
    para2 = [23.59,42.66]
    para3 = [23.56,42.63]
    #networks name
    nets = ['Eff-B0','Eff-B1','Eff-B2','Eff-B3','Eff-B4','Eff-B5','Eff-B6','Eff-B7']
    nets2 = ['ResNet-50','ResNet-101']
    nets3 = ['ResNet-50-V2','ResNet-101-V2']
    # setting x and y axis range 
    plt.ylim(0.68,1.03) 
    plt.xlim(3.00,70.00) 
    # plotting the points  
    plt.plot(para, sc , color='#c65102', linestyle='-', linewidth = 2, marker='o', markerfacecolor='r', markersize=8) 
    plt.plot(para, sc1, color='#047495', linestyle='-', linewidth = 2, marker='o', markerfacecolor='#0165fc', markersize=8) 
    plt.plot(para2, sc2, color='#516572', linestyle='dashed', linewidth = 2, marker='o', markerfacecolor='r', markersize=8) 
    plt.plot(para3, sc3, color='#516572', linestyle='dashed', linewidth = 2, marker='o', markerfacecolor='r', markersize=8) 
        
    for i in range(0,len(para)):
        label = "{:}".format(nets[i])
        plt.annotate(label, (para[i], sc[i]), textcoords="offset points", xytext=(0,10), ha='center')
        plt.annotate(label, (para[i], sc1[i]), textcoords="offset points", xytext=(0,-20), ha='center') 
    for i in range(0,len(para2)):
        label1 = "{:}".format(nets2[i])
        plt.annotate(label1, (para2[i], sc2[i]), textcoords="offset points", xytext=(0,10), ha='center')
    for i in range(0,len(para3)):
        label2= "{:}".format(nets3[i])
        plt.annotate(label2, (para3[i], sc3[i]), textcoords="offset points", xytext=(0,10), ha='center')    
    
    # Apply the legend to tell the graphs apart
       #legend(['EffNet(ImageNet)', 'EffNet(Noisy-Student)','ResNet(ImageNet)','ResNet-V2(ImageNet)'])
    legend(['EffNet(ImageNet)', 'EffNet(Noisy-Student)','ResNet(ImageNet)','ResNet-V2(ImageNet)'], bbox_to_anchor=(0.22,0.2))

    # Apply the TITLE, X-axis and Y-axis label
    title(' Performance comparison',fontsize=20)
    xlabel('Number of Parameters(Millions)',fontsize=18)
    ylabel('Accuracy',fontsize=18)

    show()

# %%
        label = "{:}".format(nets[i+1])
        plt.annotate(label, (para[i+1], sc[i+1]), textcoords="offset points", xytext=(0,10), ha='right')
        plt.annotate(label, (para[i+1], sc1[i+1]), textcoords="offset points", xytext=(0,10), ha='left')

# %%
    fig, ax = plt.subplots(figsize=(14, 8))
    
    #scores
    sc = [0.8962,0.9308,0.9679,0.9802,0.9975,0.9901,0.9777]
    sc1 = [0.9135,0.8987,0.8938,0.8938,0.8814,0.8049,0.8543]
    sc2 = [0.7580,0.6913,]
    sc3 = [0.9382,0.9012]
    #paremeter
    para = [7.8,9.2,12,19,30,43,66]
    para2 = [23.59,42.66]
    para3 = [23.56,42.63]
    #networks name
    nets = ['Eff-B1','Eff-B2','Eff-B3','Eff-B4','Eff-B5','Eff-B6','Eff-B7']
    nets2 = ['ResNet-50','ResNet-101']
    nets3 = ['ResNet-50-V2','ResNet-101-V2']
    # setting x and y axis range 
    plt.ylim(0.68,1.03) 
    plt.xlim(5.00,70.00) 
    # plotting the points  
    plt.plot(para, sc , color='#c65102', linestyle='-', linewidth = 2, marker='o', markerfacecolor='r', markersize=8) 
    plt.plot(para, sc1, color='#047495', linestyle='-', linewidth = 2, marker='o', markerfacecolor='#0165fc', markersize=8) 
    plt.plot(para2, sc2, color='#516572', linestyle='dashed', linewidth = 2, marker='o', markerfacecolor='r', markersize=8) 
    plt.plot(para3, sc3, color='#516572', linestyle='dashed', linewidth = 2, marker='o', markerfacecolor='r', markersize=8) 
        
    for i in range(0,len(para)):
        label = "{:}".format(nets[i])
        plt.annotate(label, (para[i], sc[i]), textcoords="offset points", xytext=(0,10), ha='center')
        plt.annotate(label, (para[i], sc1[i]), textcoords="offset points", xytext=(0,10), ha='center') 
    for i in range(0,len(para2)):
        label1 = "{:}".format(nets2[i])
        plt.annotate(label1, (para2[i], sc2[i]), textcoords="offset points", xytext=(0,10), ha='center')
    for i in range(0,len(para3)):
        label2= "{:}".format(nets3[i])
        plt.annotate(label2, (para3[i], sc3[i]), textcoords="offset points", xytext=(0,10), ha='center')    
    
    # Apply the legend to tell the graphs apart
    legend(['EffNet(ImageNet)', 'EffNet(Noisy-Student)','ResNet(ImageNet)','ResNet-V2(ImageNet)'])

    # Apply the TITLE, X-axis and Y-axis label
    title(' Performance comparison',fontsize=20)
    xlabel('Number of Parameters(Millions)',fontsize=18)
    ylabel('Accuracy',fontsize=18)

    show()

# %%
    fig, ax = plt.subplots(figsize=(14, 7))
    
    #scores
    sc = [0.8962,0.9308,0.9679,0.9802,0.9975,0.9901,0.9777]
    sc1 = [0.9135,0.8987,0.8938,0.8938,0.8814,0.8049,0.8543]
    sc2 = [0.7580,0.9382,0.6913,0.9012]
    #paremeter
    para = [7.8,9.2,12,19,30,43,66]
    para2 = [23.59,23.56,42.66,42.63]
    # setting x and y axis range 
    plt.ylim(0.65,1.02) 
    plt.xlim(5.00,70.00) 
    # plotting the points  
    plt.plot(para, sc , color='#c65102', linestyle='-', linewidth = 2, marker='o', markerfacecolor='r', markersize=8) 
    plt.plot(para, sc1, color='#047495', linestyle='-', linewidth = 2, marker='o', markerfacecolor='#0165fc', markersize=8) 
    plt.plot(para2, sc2, color='#516572', linestyle='dashed', linewidth = 2, marker='o', markerfacecolor='r', markersize=8) 
    
    # Apply the legend to tell the graphs apart
    legend(['EffNet(ImageNet)', 'EffNet(Noisy-Student)','ResNet(ImageNet)'])

    # Apply the TITLE, X-axis and Y-axis label
    title(' Performance comparison',fontsize=20)
    xlabel('Number of Parameters(Millions)',fontsize=18)
    ylabel('Accuracy',fontsize=18)

    show()

# %%
    fig, ax = plt.subplots(figsize=(14, 7))
    
    #scores
    sc = [0.8962,0.9308,0.9679,0.9802,0.9975,0.9901,0.9777]
    sc1 = [0.9135,0.8987,0.8938,0.8938,0.8814,0.8049,0.8543]
    sc2 = [0.7580,0.9382,0.6913,0.9012]
    #paremeter
    para = [7.8,9.2,12,19,30,43,66]
    para2 = [23.59,23.56,42.66,42.63]
    #networks name
    nets = ['Eff-B1','Eff-B2','Eff-B3','Eff-B4','Eff-B5','Eff-B6','Eff-B7']
    nets1 = ['ResNet-50','ResNet-50-V2','ResNet-101','ResNet-101-V2']
    # setting x and y axis range 
    plt.ylim(0.65,1.02) 
    plt.xlim(5.00,70.00) 
    # plotting the points  
    plt.plot(para, sc , color='#c65102', linestyle='-', linewidth = 2, marker='o', markerfacecolor='r', markersize=8) 
    plt.plot(para, sc1, color='#047495', linestyle='-', linewidth = 2, marker='o', markerfacecolor='#0165fc', markersize=8) 
    plt.plot(para2, sc2, color='#516572', linestyle='dashed', linewidth = 2, marker='o', markerfacecolor='r', markersize=8) 
        
    for i in range(0,len(para)):
        label = "{:}".format(nets[i])
        plt.annotate(label, (para[i], sc[i]), textcoords="offset points", xytext=(0,10), ha='center')
        plt.annotate(label, (para[i], sc1[i]), textcoords="offset points", xytext=(0,10), ha='center') 
    for i in range(0,len(para2)):
        label1 = "{:}".format(nets1[i])
        plt.annotate(label1, (para2[i], sc2[i]), textcoords="offset points", xytext=(0,10), ha='center')    
    
    # Apply the legend to tell the graphs apart
    legend(['EffNet(ImageNet)', 'EffNet(Noisy-Student)','ResNet(ImageNet)'])

    # Apply the TITLE, X-axis and Y-axis label
    title(' Performance comparison',fontsize=20)
    xlabel('Number of Parameters(Millions)',fontsize=18)
    ylabel('Accuracy',fontsize=18)

    show()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.clf()

# using some dummy data for this example
xs = np.arange(0,10,1)
ys = np.random.normal(loc=3, scale=0.4, size=10)

# 'bo-' means blue color, round points, solid lines
plt.plot(xs,ys,'bo-')

# zip joins x and y coordinates in pairs
for x,y in zip(xs,ys):

    label = "{:.2f}".format(y)

    plt.annotate(label, # this is the text
                 (x,y), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,10), # distance from text to points (x,y)
                 ha='center') # horizontal alignment can be left, right or center

plt.xticks(np.arange(0,10,1))
plt.yticks(np.arange(0,7,0.5))

plt.show()

# %%
    fig, ax = plt.subplots(figsize=(14, 7))
    
    #scores
    sc = [0.8962,0.9308,0.9679,0.9802,0.9975,0.9901,0.9777]
    sc1 = [0.9135,0.8987,0.8938,0.8938,0.8814,0.8049,0.8543]
    sc2 = [0.7580,0.9382,0.6913,0.9012]
    #paremeter
    para = [7.8,9.2,12,19,30,43,66]
    para2 = [23.59,23.56,42.66,42.63]
    # setting x and y axis range 
    plt.ylim(0.65,1.02) 
    plt.xlim(5.00,70.00) 
    # plotting the points  
    a = plt.plot(para, sc , color='#c65102', linestyle='-', linewidth = 2, marker='o', markerfacecolor='r', markersize=8) 
#     plt.plot(para, sc1, color='#047495', linestyle='-', linewidth = 2, marker='o', markerfacecolor='#0165fc', markersize=8) 
#     plt.plot(para2, sc2, color='#516572', linestyle='dashed', linewidth = 2, marker='o', markerfacecolor='r', markersize=8) 
    nets = ['Eff-B1','Eff-B2','Eff-B3','Eff-B4','Eff-B5','Eff-B6','Eff-B7']
    for x,y in zip(para,sc):
        lb = nets
        label = "{:}".format(y)

        plt.annotate(label, # this is the text
                     (x,y), # this is the point to label
                     textcoords="offset points", # how to position the text
                     xytext=(0,10), # distance from text to points (x,y)
                     ha='center') # horizontal alignment can be left, right or center
    
    
    # Apply the legend to tell the graphs apart
#     legend(['EffNet(ImageNet)', 'EffNet(Noisy-Student)','ResNet(ImageNet)'])

    # Apply the TITLE, X-axis and Y-axis label
    title(' Performance comparison',fontsize=20)
    xlabel('Number of Parameters(Millions)',fontsize=18)
    ylabel('Accuracy',fontsize=18)

    show()

# %%
    fig, ax = plt.subplots(figsize=(14, 7))
    
    #scores
    sc = [0.8962,0.9308,0.9679,0.9802,0.9975,0.9901,0.9777]
    sc1 = [0.9135,0.8987,0.8938,0.8938,0.8814,0.8049,0.8543]
    sc2 = [0.7580,0.9382,0.6913,0.9012]
    #paremeter
    para = [7.8,9.2,12,19,30,43,66]
    para2 = [23.59,23.56,42.66,42.63]
    # setting x and y axis range 
    plt.ylim(0.65,1.02) 
    plt.xlim(5.00,70.00) 
    # plotting the points  
    a = plt.plot(para, sc , color='#c65102', linestyle='-', linewidth = 2, marker='o', markerfacecolor='r', markersize=8) 
#     plt.plot(para, sc1, color='#047495', linestyle='-', linewidth = 2, marker='o', markerfacecolor='#0165fc', markersize=8) 
#     plt.plot(para2, sc2, color='#516572', linestyle='dashed', linewidth = 2, marker='o', markerfacecolor='r', markersize=8) 
    nets = ['Eff-B1','Eff-B2','Eff-B3','Eff-B4','Eff-B5','Eff-B6','Eff-B7']
    
    for i in range(0,len(para)):
        label = "{:}".format(nets[i])
        plt.annotate(label, # this is the text
                     (para[i], sc[i]), # this is the point to label
                     textcoords="offset points", # how to position the text
                     xytext=(0,10), # distance from text to points (x,y)
                     ha='center') 
        
    # Apply the legend to tell the graphs apart
#     legend(['EffNet(ImageNet)', 'EffNet(Noisy-Student)','ResNet(ImageNet)'])

    # Apply the TITLE, X-axis and Y-axis label
    title(' Performance comparison',fontsize=20)
    xlabel('Number of Parameters(Millions)',fontsize=18)
    ylabel('Accuracy',fontsize=18)

    show()

# %%
    fig, ax = plt.subplots(figsize=(14, 5))
    
    sc = [0.8962,0.9308,0.9679,0.9802,0.9975,0.9901,0.9777]
    sc1 = [0.9135,0.8987,0.8938,0.8938,0.8814,0.8049,0.8543]
    net = ['ResNet-50','ResNet-50-V2','ResNet-101','ResNet-101-V2']
    sc2 = [0.7580,0.9382,0.6913,0.9012]
    #months = range(5, 8)
    nets = ['Eff-B1','Eff-B2','Eff-B3','Eff-B4','Eff-B5','Eff-B6','Eff-B7']

    # plotting the points  
    plt.plot(nets, sc, color='k', linestyle='-', linewidth = 2, marker='o', markerfacecolor='r', markersize=8) 
    plt.plot(nets, sc1, color='k', linestyle='-', linewidth = 2, marker='o', markerfacecolor='blue', markersize=8) 
    plt.plot(net, sc2, color='k', linestyle='dashed', linewidth = 2, marker='o', markerfacecolor='r', markersize=8) 
    # Apply the legend to tell the graphs apart
    legend(['EffNet(ImageNet)', 'EffNet(Noisy-Student)','ResNet(ImageNet)'])

    # Apply the TITLE, X-axis and Y-axis label
    title(' Performance comparison',fontsize=20)
    xlabel('Networks',fontsize=18)
    ylabel('Accuracy',fontsize=18)

    show()

# %%
    net = ['ResNet-50','ResNet-50-V2','ResNet-101','ResNet-101-V2']
    sc2 = [0.7580,0.9382,0.6913,0.9012]

# %%
import matplotlib.pyplot as plt

# %%
    fig, ax = plt.subplots(figsize=(14, 5))
    
    sc = [0.8962,0.9308,0.9679,0.9802,0.9975,0.9901,0.9777,0.7580,0.9382,0.6913,0.9012]
    sc1 = [0.9135,0.8987,0.8938,0.8938,0.8814,0.8049,0.8543]

    #months = range(1, 8)
    nets = ['Eff-B1','Eff-B2','Eff-B3','Eff-B4','Eff-B5','Eff-B6','Eff-B7']
    # Plot the line WITH dots and the LINE
   #plot(months, ladera_temp_1996, months, ladera_temp_2006, marker='+')
    net = ['Eff-B1','Eff-B2','Eff-B3','Eff-B4','Eff-B5','Eff-B6','Eff-B7','ResNet-50','ResNetv2-50','ResNet-101','ResNetv2-101']
   #OR you can plot separately like this and the final show() method will know that it needs to plot everything that is queued up.
#     plot(net, sc, marker='o')
#     plot(nets, sc1, marker='o')
    #plot(months, ladera_temp_2016, marker='o')
    # plotting the points  
    plt.plot(net, sc, color='g', linestyle='dashed', linewidth = 2, marker='o', markerfacecolor='blue', markersize=8) 
    plt.plot(nets, sc1, color='r', linestyle='dashed', linewidth = 2, marker='o', markerfacecolor='blue', markersize=8) 
    # Apply the legend to tell the graphs apart
    legend(['ImageNet', 'Noisy-Student'])

    # Apply the TITLE, X-axis and Y-axis label
    title(' Performance comparison',fontsize=20)
    xlabel('Networks',fontsize=18)
    ylabel('Accuracy',fontsize=18)

    show()

# %% [markdown]
# # กราฟประสิทธิภาพ no flip and 2 Loss

# %%
fig, ax = plt.subplots(figsize=(20, 6))

#X,Y
acc_crossloss_val = [0.7825,0.7795,0.81,0.8,0.78,0.85,0.81,0.8,0.7,0.81,0.7,0.79,0.77,0.8193]
acc_crossloss_val_treshold = [0.47,0.31,0.43,0.42,0.47,0.35,0.34,0.46,0.3,0.3,0.3,0.36,0.34,0.33]
acc_crossloss_test = [0.7842,0.79,0.81,0.78,0.78,0.85,0.83,0.82,0.7,0.81,0.7,0.7,0.76,0.81]
acc_crossloss_test_treshold =[0.51,0.3,0.48,0.48,0.57,0.39,0.35,0.55,0.3,0.3,0.3,0.3,0.34,0.34]
model = ['Eff-B0','Eff-B1','Eff-B2','Eff-B3','Eff-B4','Eff-B5','Eff-B6','Eff-B7','ResNet-50','ResNet-50-V2',
         'ResNet-101','ResNet-101-V2','IncepRNV2','IncepV3']

#axis y size
plt.ylim(0.2,0.9) 

#plot
plt.plot(model, acc_crossloss_val , color='#15b01a', linestyle='-', linewidth = 2, marker='o', markerfacecolor='#89fe05', markersize=8)
plt.plot(model, acc_crossloss_val_treshold , color='#15b01a', linestyle='-', linewidth = 2, marker='.', markerfacecolor='#89fe05', markersize=8)
plt.plot(model, acc_crossloss_test , color='#f97306', linestyle='-', linewidth = 2, marker='o', markerfacecolor='#fd411e', markersize=8)
plt.plot(model, acc_crossloss_test_treshold , color='#f97306', linestyle='-', linewidth = 2, marker='.', markerfacecolor='#fd411e', markersize=8)

#label
for x,y,z,a,b in zip(model,acc_crossloss_val,acc_crossloss_val_treshold,acc_crossloss_test,acc_crossloss_test_treshold):
    lb = nets
    label1 = "{:}".format(y)
    label2 = "{:}".format(z)
    label3 = "{:}".format(a)
    label4 = "{:}".format(b)    
    plt.annotate(label1, (x,y),textcoords="offset points", xytext=(0,10), ha='center')
    plt.annotate(label2, (x,z),textcoords="offset points", xytext=(0,-30), ha='center')
    plt.annotate(label3, (x,a),textcoords="offset points", xytext=(0,-20), ha='center')
    plt.annotate(label4, (x,b),textcoords="offset points", xytext=(0,10), ha='center')
    
#legend
legend(['acc_crossloss_val','acc_crossloss_val_treshold','acc_crossloss_test','acc_crossloss_test_treshold'])


title(' Crossloss',fontsize=20)
xlabel('Model',fontsize=18)
ylabel('Accuracy',fontsize=18)

show()

# %%
fig, ax = plt.subplots(figsize=(20, 6))

#X,Y
focalloss_val = [0.7887,0.78,0.81,0.82,0.79,0.85,0.82,0.81,0.7,0.79,0.7,0.79,0.78,0.82]
focalloss_val_treshold = [0.5,0.31,0.45,0.41,0.46,0.36,0.35,0.45,0.3,0.3,0.31,0.34,0.33,0.32]
focalloss_test = [0.8,0.8,0.8,0.8,0.79,0.85,0.83,0.83,0.7,0.81,0.7,0.81,0.78,0.81]
focalloss_test_treshold =[0.54,0.31,0.51,0.48,0.56,0.42,0.38,0.54,0.3,0.3,0.31,0.34,0.34,0.32]
model = ['Eff-B0','Eff-B1','Eff-B2','Eff-B3','Eff-B4','Eff-B5','Eff-B6','Eff-B7','ResNet-50','ResNet-50-V2',
         'ResNet-101','ResNet-101-V2','IncepRNV2','IncepV3']

#axis y size
plt.ylim(0.2,0.9) 

#plot
plt.plot(model, focalloss_val , color='#15b01a', linestyle='-', linewidth = 2, marker='o', markerfacecolor='#89fe05', markersize=8)
plt.plot(model, focalloss_val_treshold , color='#15b01a', linestyle='-', linewidth = 2, marker='.', markerfacecolor='#89fe05', markersize=8)
plt.plot(model, focalloss_test , color='#f97306', linestyle='-', linewidth = 2, marker='o', markerfacecolor='#fd411e', markersize=8)
plt.plot(model, focalloss_test_treshold , color='#f97306', linestyle='-', linewidth = 2, marker='.', markerfacecolor='#fd411e', markersize=8)

#label
for x,y,z,a,b in zip(model, focalloss_val, focalloss_val_treshold, focalloss_test, focalloss_test_treshold):
    lb = nets
    label1 = "{:}".format(y)
    label2 = "{:}".format(z)
    label3 = "{:}".format(a)
    label4 = "{:}".format(b)    
    plt.annotate(label1, (x,y),textcoords="offset points", xytext=(0,10), ha='center')
    plt.annotate(label2, (x,z),textcoords="offset points", xytext=(0,-30), ha='center')
    plt.annotate(label3, (x,a),textcoords="offset points", xytext=(0,-20), ha='center')
    plt.annotate(label4, (x,b),textcoords="offset points", xytext=(0,10), ha='center')
    
#legend
legend([' focalloss_val(T=50)',' focalloss_val_treshold',' focalloss_test(T=50)',' focalloss_test_treshold'])


title('focalloss',fontsize=20)
xlabel('Model',fontsize=18)
ylabel('Accuracy',fontsize=18)

show()

# %%
acc_crossloss_val = [0.7825,0.7795,0.81,0.8,0.78,0.85,0.81,0.8,0.7,0.81,0.7,0.79,0.77,0.8193]
acc_crossloss_val_treshold = [0.47,0.31,0.43,0.42,0.47,0.35,0.34,0.46,0.3,0.3,0.3,0.36,0.34,0.33]
acc_crossloss_test = [0.7842,0.79,0.81,0.78,0.78,0.85,0.83,0.82,0.7,0.81,0.7,0.7,0.76,0.81]
acc_crossloss_test_treshold =[0.51,0.3,0.48,0.48,0.57,0.39,0.35,0.55,0.3,0.3,0.3,0.3,0.34,0.34]
focalloss_val = [0.7887,0.78,0.81,0.82,0.79,0.85,0.82,0.81,0.7,0.79,0.7,0.79,0.78,0.82]
focalloss_val_treshold = [0.5,0.31,0.45,0.41,0.46,0.36,0.35,0.45,0.3,0.3,0.31,0.34,0.33,0.32]
focalloss_test = [0.8,0.8,0.8,0.8,0.79,0.85,0.83,0.83,0.7,0.81,0.7,0.81,0.78,0.81]
focalloss_test_treshold =[0.54,0.31,0.51,0.48,0.56,0.42,0.38,0.54,0.3,0.3,0.31,0.34,0.34,0.32]

# %%
#Validation

# %%
#1.Before treshold
fig, ax = plt.subplots(figsize=(14, 10))

#X,Y
crossloss_val = [0.7825,0.7795,0.81,0.8,0.78,0.85,0.81,0.8]
crossloss_val2 = [0.7,0.7]
crossloss_val3 = [0.81,0.79]
crossloss_val5 = 0.77
crossloss_val6 = 0.8193
focalloss_val = [0.7887,0.78,0.81,0.82,0.79,0.85,0.82,0.81]
focalloss_val2 =[0.7,0.7]
focalloss_val3 =[0.79,0.79]
focalloss_val5 =0.78
focalloss_val6 =0.82

# model = ['Eff-B0','Eff-B1','Eff-B2','Eff-B3','Eff-B4','Eff-B5','Eff-B6','Eff-B7','ResNet-50','ResNet-50-V2',
#          'ResNet-101','ResNet-101-V2','IncepRNV2','IncepV3']

#paremeter
para = [5.3,7.8,9.2,12,19,30,43,66]
para2 = [23.59,42.66]
para3 = [23.56,42.63]
# para4 = 4.2
para5 = 54
para6 = 22
# para7 = 84.9

#networks name
nets = ['Eff-B0','Eff-B1','Eff-B2','Eff-B3','Eff-B4','Eff-B5','Eff-B6','Eff-B7']
nets2 = ['ResNet-50','ResNet-101']
nets3 = ['ResNet-50-V2','ResNet-101-V2']
# nets4='NASNetMobile'
nets5='InceptionResNetV2'
nets6='InceptionV3'
# nets7='NASNetLarge'

# setting x and y axis range 
plt.ylim(0.68,0.875) 
plt.xlim(0.00,70.00) 
#plot
# plt.plot(model, crossloss_val , color='#15b01a', linestyle='-', linewidth = 2, marker='o', markerfacecolor='#89fe05', markersize=8)
# plt.plot(model, focalloss_val , color='#f97306', linestyle='-', linewidth = 2, marker='o', markerfacecolor='#fd411e', markersize=8)

# crossloss********
plt.plot(para, crossloss_val , color='#15b01a', linestyle='-', linewidth = 2, marker='o', markerfacecolor='#89fe05', markersize=8) 
plt.plot(para2, crossloss_val2, color='#15b01a', linestyle='dashed', linewidth = 2, marker='o', markerfacecolor='#89fe05', markersize=8) 
plt.plot(para3, crossloss_val3, color='#15b01a', linestyle='dashed', linewidth = 2, marker='o', markerfacecolor='#89fe05', markersize=8) 
# plt.plot(para4, crossloss_val4, color='#15b01a', marker='o',linestyle=' ', markerfacecolor='r', markersize=8) 
plt.plot(para5, crossloss_val5, color='#15b01a', marker='o',linestyle=' ', markerfacecolor='#89fe05', markersize=8) 
plt.plot(para6, crossloss_val6, color='#15b01a', marker='o',linestyle=' ', markerfacecolor='#89fe05', markersize=8) 
# plt.plot(para7, crossloss_val7, color='#15b01a', marker='o',linestyle=' ', markerfacecolor='r', markersize=8)     

#  focalloss********
plt.plot(para, focalloss_val , color='#f97306', linestyle='-', linewidth = 2, marker='.', markerfacecolor='#fd411e', markersize=8) 
plt.plot(para2, focalloss_val2, color='#f97306', linestyle='dashed', linewidth = 2, marker='.', markerfacecolor='#fd411e', markersize=8) 
plt.plot(para3, focalloss_val3, color='#f97306', linestyle='dashed', linewidth = 2, marker='.', markerfacecolor='#fd411e', markersize=8) 
# plt.plot(para4, crossloss_val4, color='#15b01a', marker='.',linestyle=' ', markerfacecolor='r', markersize=8) 
plt.plot(para5, focalloss_val5, color='#f97306', marker='.',linestyle=' ', markerfacecolor='#fd411e', markersize=8) 
plt.plot(para6, focalloss_val6, color='#f97306', marker='.',linestyle=' ', markerfacecolor='#fd411e', markersize=8) 
# plt.plot(para7, crossloss_val7, color='#15b01a', marker='.',linestyle=' ', markerfacecolor='r', markersize=8)     

#label
for i in range(0,6):
    label = "{:}".format(nets[i+2])
    plt.annotate(label, (para[i+2], crossloss_val[i+2]), textcoords="offset points", xytext=(0,10), ha='center')
#     plt.annotate(label, (para[i+2], crossloss_val1[i+2]), textcoords="offset points", xytext=(0,-20), ha='center') 
plt.annotate(nets[0], (para[0], crossloss_val[0]), textcoords="offset points", xytext=(0,10), ha='center')
# plt.annotate(nets[0], (para[0], crossloss_val1[0]), textcoords="offset points", xytext=(0,-20), ha='center')
plt.annotate(nets[1], (para[1], crossloss_val[1]), textcoords="offset points", xytext=(0,10), ha='center')
for i in range(0,len(para2)):
    label1 = "{:}".format(nets2[i])
    plt.annotate(label1, (para2[i], crossloss_val2[i]), textcoords="offset points", xytext=(0,10), ha='center')
for i in range(0,len(para3)):
    label2= "{:}".format(nets3[i])
    plt.annotate(label2, (para3[i], crossloss_val3[i]), textcoords="offset points", xytext=(0,10), ha='center')    
    
# plt.annotate(nets4, (para4, sc4), textcoords="offset points", xytext=(0,10), ha='center')      
plt.annotate(nets5, (para5, crossloss_val5), textcoords="offset points", xytext=(0,10), ha='center') 
plt.annotate(nets6, (para6, crossloss_val6), textcoords="offset points", xytext=(0,10), ha='center') 
# plt.annotate(nets7, (para7, sc7), textcoords="offset points", xytext=(0,10), ha='center') 
    
#legend
# legend(['crossloss_val','focalloss_val'])


title('Validation Before Treshold ',fontsize=20)
xlabel('Model',fontsize=18)
ylabel('Accuracy',fontsize=18)

show()

# %%
crossloss_val_treshold = [0.47,0.31,0.43,0.42,0.47,0.35,0.34,0.46,0.3,0.3,0.3,0.36,0.34,0.33]
focalloss_val_treshold =[0.5,0.31,0.45,0.41,0.46,0.36,0.35,0.45,0.3,0.3,0.31,0.34,0.33,0.32]

# %%
#2.After treshold
fig, ax = plt.subplots(figsize=(14, 10))

#X,Y
crossloss_val = [0.47,0.31,0.43,0.42,0.47,0.35,0.34,0.46]
crossloss_val2 = [0.3,0.3]
crossloss_val3 = [0.3,0.36]
crossloss_val5 = 0.34
crossloss_val6 = 0.33
focalloss_val = [0.5,0.31,0.45,0.41,0.46,0.36,0.35,0.45]
focalloss_val2 =[0.3,0.31]
focalloss_val3 =[0.3,0.34]
focalloss_val5 =0.33
focalloss_val6 =0.32

# model = ['Eff-B0','Eff-B1','Eff-B2','Eff-B3','Eff-B4','Eff-B5','Eff-B6','Eff-B7','ResNet-50','ResNet-50-V2',
#          'ResNet-101','ResNet-101-V2','IncepRNV2','IncepV3']

#paremeter
para = [5.3,7.8,9.2,12,19,30,43,66]
para2 = [23.59,42.66]
para3 = [23.56,42.63]
# para4 = 4.2
para5 = 54
para6 = 22
# para7 = 84.9

#networks name
nets = ['Eff-B0','Eff-B1','Eff-B2','Eff-B3','Eff-B4','Eff-B5','Eff-B6','Eff-B7']
nets2 = ['ResNet-50','ResNet-101']
nets3 = ['ResNet-50-V2','ResNet-101-V2']
# nets4='NASNetMobile'
nets5='InceptionResNetV2'
nets6='InceptionV3'
# nets7='NASNetLarge'

# setting x and y axis range 
plt.ylim(0.25,0.6) 
plt.xlim(0.00,70.00) 
#plot
# plt.plot(model, crossloss_val , color='#15b01a', linestyle='-', linewidth = 2, marker='o', markerfacecolor='#89fe05', markersize=8)
# plt.plot(model, focalloss_val , color='#f97306', linestyle='-', linewidth = 2, marker='o', markerfacecolor='#fd411e', markersize=8)

# crossloss********
plt.plot(para, crossloss_val , color='#15b01a', linestyle='-', linewidth = 2, marker='o', markerfacecolor='#89fe05', markersize=8) 
plt.plot(para2, crossloss_val2, color='#15b01a', linestyle='dashed', linewidth = 2, marker='x', markerfacecolor='#89fe05', markersize=8) 
plt.plot(para3, crossloss_val3, color='#15b01a', linestyle='dashed', linewidth = 2, marker='o', markerfacecolor='#89fe05', markersize=8) 
# plt.plot(para4, crossloss_val4, color='#15b01a', marker='o',linestyle=' ', markerfacecolor='r', markersize=8) 
plt.plot(para5, crossloss_val5, color='#15b01a', marker='o',linestyle=' ', markerfacecolor='#89fe05', markersize=8) 
plt.plot(para6, crossloss_val6, color='#15b01a', marker='o',linestyle=' ', markerfacecolor='#89fe05', markersize=8) 
# plt.plot(para7, crossloss_val7, color='#15b01a', marker='o',linestyle=' ', markerfacecolor='r', markersize=8)     

#  focalloss********
plt.plot(para, focalloss_val , color='#f97306', linestyle='-', linewidth = 2, marker='.', markerfacecolor='#fd411e', markersize=8) 
plt.plot(para2, focalloss_val2, color='#f97306', linestyle='dashed', linewidth = 2, marker='x', markerfacecolor='#fd411e', markersize=8) 
plt.plot(para3, focalloss_val3, color='#f97306', linestyle='dashed', linewidth = 2, marker='.', markerfacecolor='#fd411e', markersize=8) 
# plt.plot(para4, crossloss_val4, color='#15b01a', marker='.',linestyle=' ', markerfacecolor='r', markersize=8) 
plt.plot(para5, focalloss_val5, color='#f97306', marker='.',linestyle=' ', markerfacecolor='#fd411e', markersize=8) 
plt.plot(para6, focalloss_val6, color='#f97306', marker='.',linestyle=' ', markerfacecolor='#fd411e', markersize=8) 
# plt.plot(para7, crossloss_val7, color='#15b01a', marker='.',linestyle=' ', markerfacecolor='r', markersize=8)     

#label
for i in range(0,6):
    label = "{:}".format(nets[i+2])
    plt.annotate(label, (para[i+2], crossloss_val[i+2]), textcoords="offset points", xytext=(0,10), ha='center')
#     plt.annotate(label, (para[i+2], crossloss_val1[i+2]), textcoords="offset points", xytext=(0,-20), ha='center') 
plt.annotate(nets[0], (para[0], crossloss_val[0]), textcoords="offset points", xytext=(0,10), ha='center')
# plt.annotate(nets[0], (para[0], crossloss_val1[0]), textcoords="offset points", xytext=(0,-20), ha='center')
plt.annotate(nets[1], (para[1], crossloss_val[1]), textcoords="offset points", xytext=(0,10), ha='center')
for i in range(0,len(para2)):
    label1 = "{:}".format(nets2[i])
    plt.annotate(label1, (para2[i], crossloss_val2[i]), textcoords="offset points", xytext=(0,-20), ha='center')
for i in range(0,len(para3)):
    label2= "{:}".format(nets3[i])
    plt.annotate(label2, (para3[i], crossloss_val3[i]), textcoords="offset points", xytext=(0,10), ha='center')    
    
# plt.annotate(nets4, (para4, sc4), textcoords="offset points", xytext=(0,10), ha='center')      
plt.annotate(nets5, (para5, crossloss_val5), textcoords="offset points", xytext=(0,10), ha='center') 
plt.annotate(nets6, (para6, crossloss_val6), textcoords="offset points", xytext=(0,10), ha='center') 
# plt.annotate(nets7, (para7, sc7), textcoords="offset points", xytext=(0,10), ha='center') 
    
#legend
# legend(['crossloss_val','focalloss_val'])


title('Validation After Treshold ',fontsize=20)
xlabel('Model',fontsize=18)
ylabel('Accuracy',fontsize=18)

show()

# %%
#test

# %%
#1.Before treshold
fig, ax = plt.subplots(figsize=(14, 10))

#X,Y
crossloss_val = [0.7842,0.79,0.81,0.78,0.78,0.85,0.83,0.82]
crossloss_val2 = [0.7,0.7]
crossloss_val3 = [0.81,0.7]
crossloss_val5 = 0.76
crossloss_val6 = 0.81
focalloss_val = [0.8,0.8,0.8,0.8,0.79,0.85,0.83,0.83]
focalloss_val2 =[0.7,0.7]
focalloss_val3 =[0.81,0.81]
focalloss_val5 =0.78
focalloss_val6 =0.81

# model = ['Eff-B0','Eff-B1','Eff-B2','Eff-B3','Eff-B4','Eff-B5','Eff-B6','Eff-B7','ResNet-50','ResNet-50-V2',
#          'ResNet-101','ResNet-101-V2','IncepRNV2','IncepV3']

#paremeter
para = [5.3,7.8,9.2,12,19,30,43,66]
para2 = [23.59,42.66]
para3 = [23.56,42.63]
# para4 = 4.2
para5 = 54
para6 = 22
# para7 = 84.9

#networks name
nets = ['Eff-B0','Eff-B1','Eff-B2','Eff-B3','Eff-B4','Eff-B5','Eff-B6','Eff-B7']
nets2 = ['ResNet-50','ResNet-101']
nets3 = ['ResNet-50-V2','ResNet-101-V2']
# nets4='NASNetMobile'
nets5='InceptionResNetV2'
nets6='InceptionV3'
# nets7='NASNetLarge'

# setting x and y axis range 
plt.ylim(0.68,0.875) 
plt.xlim(0.00,70.00) 
#plot
# plt.plot(model, crossloss_val , color='#15b01a', linestyle='-', linewidth = 2, marker='o', markerfacecolor='#89fe05', markersize=8)
# plt.plot(model, focalloss_val , color='#f97306', linestyle='-', linewidth = 2, marker='o', markerfacecolor='#fd411e', markersize=8)

# crossloss********
plt.plot(para, crossloss_val , color='#15b01a', linestyle='-', linewidth = 2, marker='o', markerfacecolor='#89fe05', markersize=8) 
plt.plot(para2, crossloss_val2, color='#15b01a', linestyle='dashed', linewidth = 2, marker='x', markerfacecolor='#89fe05', markersize=8) 
plt.plot(para3, crossloss_val3, color='#15b01a', linestyle='dashed', linewidth = 2, marker='o', markerfacecolor='#89fe05', markersize=8) 
# plt.plot(para4, crossloss_val4, color='#15b01a', marker='o',linestyle=' ', markerfacecolor='r', markersize=8) 
plt.plot(para5, crossloss_val5, color='#15b01a', marker='o',linestyle=' ', markerfacecolor='#89fe05', markersize=8) 
plt.plot(para6, crossloss_val6, color='#15b01a', marker='o',linestyle=' ', markerfacecolor='#89fe05', markersize=8) 
# plt.plot(para7, crossloss_val7, color='#15b01a', marker='o',linestyle=' ', markerfacecolor='r', markersize=8)     

#  focalloss********
plt.plot(para, focalloss_val , color='#f97306', linestyle='-', linewidth = 2, marker='.', markerfacecolor='#fd411e', markersize=8) 
plt.plot(para2, focalloss_val2, color='#f97306', linestyle='dashed', linewidth = 2, marker='x', markerfacecolor='#fd411e', markersize=8) 
plt.plot(para3, focalloss_val3, color='#f97306', linestyle='dashed', linewidth = 2, marker='.', markerfacecolor='#fd411e', markersize=8) 
# plt.plot(para4, crossloss_val4, color='#15b01a', marker='.',linestyle=' ', markerfacecolor='r', markersize=8) 
plt.plot(para5, focalloss_val5, color='#f97306', marker='.',linestyle=' ', markerfacecolor='#fd411e', markersize=8) 
plt.plot(para6, focalloss_val6, color='#f97306', marker='.',linestyle=' ', markerfacecolor='#fd411e', markersize=8) 
# plt.plot(para7, crossloss_val7, color='#15b01a', marker='.',linestyle=' ', markerfacecolor='r', markersize=8)     

#label
for i in range(0,6):
    label = "{:}".format(nets[i+2])
    plt.annotate(label, (para[i+2], crossloss_val[i+2]), textcoords="offset points", xytext=(0,10), ha='center')
#     plt.annotate(label, (para[i+2], crossloss_val1[i+2]), textcoords="offset points", xytext=(0,-20), ha='center') 
plt.annotate(nets[0], (para[0], crossloss_val[0]), textcoords="offset points", xytext=(0,10), ha='center')
# plt.annotate(nets[0], (para[0], crossloss_val1[0]), textcoords="offset points", xytext=(0,-20), ha='center')
plt.annotate(nets[1], (para[1], crossloss_val[1]), textcoords="offset points", xytext=(0,10), ha='center')
for i in range(0,len(para2)):
    label1 = "{:}".format(nets2[i])
    plt.annotate(label1, (para2[i], crossloss_val2[i]), textcoords="offset points", xytext=(0,10), ha='center')
for i in range(0,len(para3)):
    label2= "{:}".format(nets3[i])
    plt.annotate(label2, (para3[i], crossloss_val3[i]), textcoords="offset points", xytext=(0,-20), ha='center')    
    
# plt.annotate(nets4, (para4, sc4), textcoords="offset points", xytext=(0,10), ha='center')      
plt.annotate(nets5, (para5, crossloss_val5), textcoords="offset points", xytext=(0,10), ha='center') 
plt.annotate(nets6, (para6, crossloss_val6), textcoords="offset points", xytext=(0,10), ha='center') 
# plt.annotate(nets7, (para7, sc7), textcoords="offset points", xytext=(0,10), ha='center') 
    
#legend
# legend(['crossloss_val','focalloss_val'])


title('Test Before Treshold ',fontsize=20)
xlabel('Model',fontsize=18)
ylabel('Accuracy',fontsize=18)

show()

# %%
acc_crossloss_test = [0.7842,0.79,0.81,0.78,0.78,0.85,0.83,0.82,0.7,0.81,0.7,0.7,0.76,0.81]
acc_crossloss_test_treshold =[0.51,0.3,0.48,0.48,0.57,0.39,0.35,0.55,0.3,0.3,0.3,0.3,0.34,0.34]
focalloss_test = [0.8,0.8,0.8,0.8,0.79,0.85,0.83,0.83,0.7,0.81,0.7,0.81,0.78,0.81]
focalloss_test_treshold =[0.54,0.31,0.51,0.48,0.56,0.42,0.38,0.54,0.3,0.3,0.31,0.34,0.34,0.32]

# %%
#2.After treshold
fig, ax = plt.subplots(figsize=(14, 10))

#X,Y
crossloss_val = [0.51,0.3,0.48,0.48,0.57,0.39,0.35,0.55]
crossloss_val2 = [0.3,0.3]
crossloss_val3 = [0.3,0.3]
crossloss_val5 = 0.34
crossloss_val6 = 0.34
focalloss_val = [0.54,0.31,0.51,0.48,0.56,0.42,0.38,0.54]
focalloss_val2 =[0.3,0.31]
focalloss_val3 =[0.3,0.34]
focalloss_val5 =0.34
focalloss_val6 =0.32

# model = ['Eff-B0','Eff-B1','Eff-B2','Eff-B3','Eff-B4','Eff-B5','Eff-B6','Eff-B7','ResNet-50','ResNet-50-V2',
#          'ResNet-101','ResNet-101-V2','IncepRNV2','IncepV3']

#paremeter
para = [5.3,7.8,9.2,12,19,30,43,66]
para2 = [23.59,42.66]
para3 = [23.56,42.63]
# para4 = 4.2
para5 = 54
para6 = 22
# para7 = 84.9

#networks name
nets = ['Eff-B0','Eff-B1','Eff-B2','Eff-B3','Eff-B4','Eff-B5','Eff-B6','Eff-B7']
nets2 = ['ResNet-50','ResNet-101']
nets3 = ['ResNet-50-V2','ResNet-101-V2']
# nets4='NASNetMobile'
nets5='InceptionResNetV2'
nets6='InceptionV3'
# nets7='NASNetLarge'

# setting x and y axis range 
plt.ylim(0.25,0.6) 
plt.xlim(0.00,70.00) 
#plot
# plt.plot(model, crossloss_val , color='#15b01a', linestyle='-', linewidth = 2, marker='o', markerfacecolor='#89fe05', markersize=8)
# plt.plot(model, focalloss_val , color='#f97306', linestyle='-', linewidth = 2, marker='o', markerfacecolor='#fd411e', markersize=8)

# crossloss********
plt.plot(para, crossloss_val , color='#15b01a', linestyle='-', linewidth = 2, marker='o', markerfacecolor='#89fe05', markersize=8) 
plt.plot(para2, crossloss_val2, color='#15b01a', linestyle='dashed', linewidth = 2, marker='x', markerfacecolor='#89fe05', markersize=8) 
plt.plot(para3, crossloss_val3, color='#15b01a', linestyle='dashed', linewidth = 2, marker='o', markerfacecolor='#89fe05', markersize=8) 
# plt.plot(para4, crossloss_val4, color='#15b01a', marker='o',linestyle=' ', markerfacecolor='r', markersize=8) 
plt.plot(para5, crossloss_val5, color='#15b01a', marker='o',linestyle=' ', markerfacecolor='#89fe05', markersize=8) 
plt.plot(para6, crossloss_val6, color='#15b01a', marker='o',linestyle=' ', markerfacecolor='#89fe05', markersize=8) 
# plt.plot(para7, crossloss_val7, color='#15b01a', marker='o',linestyle=' ', markerfacecolor='r', markersize=8)     

#  focalloss********
plt.plot(para, focalloss_val , color='#f97306', linestyle='-', linewidth = 2, marker='.', markerfacecolor='#fd411e', markersize=8) 
plt.plot(para2, focalloss_val2, color='#f97306', linestyle='dashed', linewidth = 2, marker='x', markerfacecolor='#fd411e', markersize=8) 
plt.plot(para3, focalloss_val3, color='#f97306', linestyle='dashed', linewidth = 2, marker='.', markerfacecolor='#fd411e', markersize=8) 
# plt.plot(para4, crossloss_val4, color='#15b01a', marker='.',linestyle=' ', markerfacecolor='r', markersize=8) 
plt.plot(para5, focalloss_val5, color='#f97306', marker='.',linestyle=' ', markerfacecolor='#fd411e', markersize=8) 
plt.plot(para6, focalloss_val6, color='#f97306', marker='.',linestyle=' ', markerfacecolor='#fd411e', markersize=8) 
# plt.plot(para7, crossloss_val7, color='#15b01a', marker='.',linestyle=' ', markerfacecolor='r', markersize=8)     

#label
for i in range(0,6):
    label = "{:}".format(nets[i+2])
    plt.annotate(label, (para[i+2], crossloss_val[i+2]), textcoords="offset points", xytext=(0,10), ha='center')
#     plt.annotate(label, (para[i+2], crossloss_val1[i+2]), textcoords="offset points", xytext=(0,-20), ha='center') 
plt.annotate(nets[0], (para[0], crossloss_val[0]), textcoords="offset points", xytext=(0,10), ha='center')
# plt.annotate(nets[0], (para[0], crossloss_val1[0]), textcoords="offset points", xytext=(0,-20), ha='center')
plt.annotate(nets[1], (para[1], crossloss_val[1]), textcoords="offset points", xytext=(0,10), ha='center')
for i in range(0,len(para2)):
    label1 = "{:}".format(nets2[i])
    plt.annotate(label1, (para2[i], crossloss_val2[i]), textcoords="offset points", xytext=(0,-20), ha='center')
for i in range(0,len(para3)):
    label2= "{:}".format(nets3[i])
    plt.annotate(label2, (para3[i], crossloss_val3[i]), textcoords="offset points", xytext=(0,10), ha='center')    
    
# plt.annotate(nets4, (para4, sc4), textcoords="offset points", xytext=(0,10), ha='center')      
plt.annotate(nets5, (para5, crossloss_val5), textcoords="offset points", xytext=(0,10), ha='center') 
plt.annotate(nets6, (para6, crossloss_val6), textcoords="offset points", xytext=(0,10), ha='center') 
# plt.annotate(nets7, (para7, sc7), textcoords="offset points", xytext=(0,10), ha='center') 
    
#legend
# legend(['crossloss_val','focalloss_val'])


title('Test After Treshold ',fontsize=20)
xlabel('Model',fontsize=18)
ylabel('Accuracy',fontsize=18)

show()

# %% [markdown]
# # Fold1
#
#
# # polt unfreez no flip and 2 Loss

# %%
fig, ax = plt.subplots(figsize=(20, 9))

X = ['R1','top_conv','block7a_se_excite','block6a_se_excite','block5a_se_excite','block4a_se_excite','block3a_se_excite']

yfocal_val_be = [0.7887,0.83,0.84,0.91,0.89,0.91,0.89]
yfocal_val_af = [0.5,0.56,0.63,0.71,0.53,0.3,0.74]
yfocal_test_be = [0.8,0.86,0.88,0.91,0.91,0.91,0.9]
yfocal_test_af = [0.54,0.62,0.71,0.77,0.59,0.3,0.78]
ycross_val_be = [0.7887,0.8315,0.83,0.91,0.89,0.92,0.89]
ycross_val_af = [0.5,0.59,0.59,0.3,0.3,0.3,0.74]
ycross_test_be = [0.8,0.6,0.78,0.73,0.86,0.75,0.84]
ycross_test_af = [0.54,0.66,0.67,0.3,0.3,0.3,0.81]

# setting x and y axis range 
plt.ylim(0.77,0.93) 

plt.plot(X,yfocal_val_be,color='#15b01a', linestyle='-', linewidth = 3, marker='o', markerfacecolor='#15b01a', markersize=8)
plt.plot(X,ycross_val_be,color='#ff028d', linestyle='-', linewidth = 3, marker='o', markerfacecolor='#ff028d', markersize=8)

#label
for x,y,z in zip(X, yfocal_val_be, ycross_val_be):
    label1 = "{:}".format(y)
    label2 = "{:}".format(z)
    plt.annotate(label1, (x,y),textcoords="offset points", xytext=(0,10), ha='center')
    plt.annotate(label2, (x,z),textcoords="offset points", xytext=(0,10), ha='center')
    
    
# Apply the legend to tell the graphs apart
legend(['FocalLoss-Before','CrossLoss-Before'], bbox_to_anchor=(1.0,0.148))

# Apply the TITLE, X-axis and Y-axis label
title('Before Treshold by Validation set',fontsize=20)
xlabel('Unfreeze layers',fontsize=18)
ylabel('Accuracy',fontsize=18)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(20, 9))

X = ['R1','top_conv','block7a_se_excite','block6a_se_excite','block5a_se_excite','block4a_se_excite','block3a_se_excite']

yfocal_val_be = [0.7887,0.83,0.84,0.91,0.89,0.91,0.89]
yfocal_val_af = [0.5,0.56,0.63,0.71,0.53,0.3,0.74]
yfocal_test_be = [0.8,0.86,0.88,0.91,0.91,0.91,0.9]
yfocal_test_af = [0.54,0.62,0.71,0.77,0.59,0.3,0.78]
ycross_val_be = [0.7887,0.91,0.91,0.95,0.94,0.94,0.95]
ycross_val_af = [0.5,0.59,0.59,0.3,0.3,0.3,0.74]
ycross_test_be = [0.8,0.6,0.78,0.73,0.86,0.75,0.84]
ycross_test_af = [0.54,0.66,0.67,0.3,0.3,0.3,0.81]

# setting x and y axis range 
plt.ylim(0.2,0.8) 

plt.plot(X,yfocal_val_af,color='#01ff07', linestyle='-', linewidth = 3, marker='o', markerfacecolor='#01ff07', markersize=8)
plt.plot(X,ycross_val_af,color='#ff81c0', linestyle='-', linewidth = 3, marker='o', markerfacecolor='#ff81c0', markersize=8)

#label
for x,a,b in zip(X,yfocal_val_af, ycross_val_af):
    label3 = "{:}".format(a)
    label4 = "{:}".format(b)    
    plt.annotate(label3, (x,a),textcoords="offset points", xytext=(0,10), ha='center')
    plt.annotate(label4, (x,b),textcoords="offset points", xytext=(0,10), ha='center')
    
    
# Apply the legend to tell the graphs apart
legend(['FocalLoss-After','CrossLoss-After'], bbox_to_anchor=(1.0,0.148))

# Apply the TITLE, X-axis and Y-axis label
title('After Treshold by Validation set',fontsize=20)
xlabel('Unfreeze layers',fontsize=18)
ylabel('Accuracy',fontsize=18)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(20, 9))

X = ['R1','top_conv','block7a_se_excite','block6a_se_excite','block5a_se_excite','block4a_se_excite','block3a_se_excite']

yfocal_val_be = [0.7887,0.83,0.84,0.91,0.89,0.91,0.89]
yfocal_val_af = [0.5,0.56,0.63,0.71,0.53,0.3,0.74]
yfocal_test_be = [0.8,0.86,0.88,0.91,0.91,0.91,0.9]
yfocal_test_af = [0.54,0.62,0.71,0.77,0.59,0.3,0.78]
ycross_val_be = [0.7887,0.91,0.91,0.95,0.94,0.94,0.95]
ycross_val_af = [0.5,0.59,0.59,0.3,0.3,0.3,0.74]
ycross_test_be = [0.8,0.86,0.88,0.91,0.9,0.92,0.91]
ycross_test_af = [0.54,0.66,0.67,0.3,0.3,0.3,0.81]

# setting x and y axis range 
plt.ylim(0.75,1.01) 

plt.plot(X,yfocal_test_be,color='#15b01a', linestyle='-', linewidth = 3, marker='o', markerfacecolor='#15b01a', markersize=8)
plt.plot(X,ycross_test_be,color='#ff028d', linestyle='-', linewidth = 3, marker='o', markerfacecolor='#ff028d', markersize=8)

#label
for x,y,z in zip(X, yfocal_test_be, ycross_test_be):
    label1 = "{:}".format(y)
    label2 = "{:}".format(z) 
    plt.annotate(label1, (x,y),textcoords="offset points", xytext=(0,-20), ha='center')
    plt.annotate(label2, (x,z),textcoords="offset points", xytext=(0,20), ha='center')

    
# Apply the legend to tell the graphs apart
legend(['FocalLoss-Before','CrossLoss-Before'], bbox_to_anchor=(1.0,0.148))

# Apply the TITLE, X-axis and Y-axis label
title(' Before Treshold by Test set',fontsize=20)
xlabel('Unfreeze layers',fontsize=18)
ylabel('Accuracy',fontsize=18)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(20, 9))

X = ['R1','top_conv','block7a_se_excite','block6a_se_excite','block5a_se_excite','block4a_se_excite','block3a_se_excite']

yfocal_val_be = [0.7887,0.83,0.84,0.91,0.89,0.91,0.89]
yfocal_val_af = [0.5,0.56,0.63,0.71,0.53,0.3,0.74]
yfocal_test_be = [0.8,0.86,0.88,0.91,0.91,0.91,0.9]
yfocal_test_af = [0.54,0.62,0.71,0.77,0.59,0.3,0.78]
ycross_val_be = [0.7887,0.91,0.91,0.95,0.94,0.94,0.95]
ycross_val_af = [0.5,0.59,0.59,0.3,0.3,0.3,0.74]
ycross_test_be = [0.8,0.6,0.78,0.73,0.86,0.75,0.84]
ycross_test_af = [0.54,0.66,0.67,0.3,0.3,0.3,0.81]

# setting x and y axis range 
plt.ylim(0.2,0.85) 

plt.plot(X,yfocal_test_af,color='#01ff07', linestyle='-', linewidth = 3, marker='o', markerfacecolor='#01ff07', markersize=8)
plt.plot(X,ycross_test_af,color='#ff81c0', linestyle='-', linewidth = 3, marker='o', markerfacecolor='#ff81c0', markersize=8)

#label
for x,y,z in zip(X,yfocal_test_af, ycross_test_af):
    label1 = "{:}".format(y)
    label2 = "{:}".format(z)
    plt.annotate(label1, (x,y),textcoords="offset points", xytext=(0,10), ha='center')
    plt.annotate(label2, (x,z),textcoords="offset points", xytext=(0,10), ha='center')
    
    
# Apply the legend to tell the graphs apart
legend(['FocalLoss-After','CrossLoss-After'], bbox_to_anchor=(1.0,0.148))

# Apply the TITLE, X-axis and Y-axis label
title(' After Treshold by Test set',fontsize=20)
xlabel('Unfreeze layers',fontsize=18)
ylabel('Accuracy',fontsize=18)

plt.show()

# %% [markdown]
# ### -Multi-task

# %%
fig, ax = plt.subplots(figsize=(16, 9))

X = ['(1) Data fold1','(2) Sampling  class balance data','(3) Sampling  class&AbnNor balance data']
anbnorFP_val =[0.81,0.8,0.82]
FP_val = [0.7,0.76,0.77]
anbnorV13_val = [0.79,0.81,0.8]
V13_val = [0.59,0.62,0.64]

# setting x and y axis range 
plt.ylim(0.55,0.85) 

plt.plot(X,anbnorFP_val,color='#80013f', linestyle='-', linewidth = 2, marker='o', markerfacecolor='#fd3c06', markersize=8)
plt.plot(X,FP_val,color='#80013f', linestyle='-', linewidth = 2, marker='*', markerfacecolor='#fd3c06', markersize=10)
plt.plot(X,anbnorV13_val,color='#1e488f', linestyle='-', linewidth = 2, marker='o', markerfacecolor='#0652ff', markersize=8)
plt.plot(X,V13_val,color='#1e488f', linestyle='-', linewidth = 2, marker='*', markerfacecolor='#0652ff', markersize=10)

#label
for x,y,z,a,b in zip(X,anbnorFP_val, FP_val,anbnorV13_val,V13_val):
    label1 = "{:}".format(y)
    label2 = "{:}".format(z)
    label3 = "{:}".format(a)
    label3 = "{:}".format(b)
    plt.annotate(label1, (x,y),textcoords="offset points", xytext=(0,10), ha='center')
    plt.annotate(label2, (x,z),textcoords="offset points", xytext=(0,10), ha='center')
    plt.annotate(label3, (x,a),textcoords="offset points", xytext=(0,10), ha='center')   
    plt.annotate(label3, (x,b),textcoords="offset points", xytext=(0,10), ha='center')   

# Apply the legend to tell the graphs apart
legend(['Abn&Nor of 5FP model','5FP of 5FP model','Abn&Nor of 13 Views model','13 Views of 13 Views model'], bbox_to_anchor=(1.0,0.148))

# Apply the TITLE, X-axis and Y-axis label
title(' Multi-task performance by Validation set',fontsize=20)
xlabel('Data',fontsize=18)
ylabel('Accuracy',fontsize=18)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(16, 9))

X = ['(1) Data fold1','(2) Sampling  class balance data','(3) Sampling  class&AbnNor balance data']
anbnorFP_val =[0.81,0.82,0.84]
FP_val = [0.74,0.79,0.75]
anbnorV13_val = [0.78,0.82,0.83]
V13_val = [0.61,0.63,0.65]

# setting x and y axis range 
plt.ylim(0.60,0.90) 

plt.plot(X,anbnorFP_val,color='#80013f', linestyle='-', linewidth = 2, marker='o', markerfacecolor='#fd3c06', markersize=8)
plt.plot(X,FP_val,color='#80013f', linestyle='-', linewidth = 2, marker='*', markerfacecolor='#fd3c06', markersize=10)
plt.plot(X,anbnorV13_val,color='#1e488f', linestyle='-', linewidth = 2, marker='o', markerfacecolor='#0652ff', markersize=8)
plt.plot(X,V13_val,color='#1e488f', linestyle='-', linewidth = 2, marker='*', markerfacecolor='#0652ff', markersize=10)

#label
for x,y,z,a,b in zip(X,anbnorFP_val, FP_val,anbnorV13_val,V13_val):
    label1 = "{:}".format(y)
    label2 = "{:}".format(z)
    label3 = "{:}".format(a)
    label3 = "{:}".format(b)
    plt.annotate(label1, (x,y),textcoords="offset points", xytext=(0,10), ha='center')
    plt.annotate(label2, (x,z),textcoords="offset points", xytext=(0,10), ha='center')
    plt.annotate(label3, (x,a),textcoords="offset points", xytext=(0,10), ha='center')   
    plt.annotate(label3, (x,b),textcoords="offset points", xytext=(0,10), ha='center')   

# Apply the legend to tell the graphs apart
legend(['Abn&Nor of 5FP model','5FP of 5FP model','Abn&Nor of 13 Views model','13 Views of 13 Views model'], bbox_to_anchor=(1.0,0.148))

# Apply the TITLE, X-axis and Y-axis label
title(' Multi-task performance by Test set',fontsize=20)
xlabel('Data',fontsize=18)
ylabel('Accuracy',fontsize=18)

plt.show()

# %%
val_multi3 = [0.82,0.77,0.8,0.64]
test_multi3 =[0.84,0.75,0.83,0.65]

# %%
fig, ax = plt.subplots(figsize=(16, 8))

X = ['AbnNor_5FP','5FP']
X2 = ['AbnNor_13views','13views']
val_multi1 = [0.81,0.7]
test_multi1 =[0.81,0.74]
val_multi2 = [0.79,0.59]
test_multi2 =[0.78,0.61]

val_multi12 = [0.8,0.76]
test_multi12 =[0.82,0.79]
val_multi22 = [0.81,0.62]
test_multi22 =[0.82,0.63]

val_multi13 = [0.82,0.77]
test_multi13 =[0.84,0.75]
val_multi23 = [0.8,0.64]
test_multi23 =[0.83,0.65]
# setting x and y axis range 
plt.ylim(0.55,0.85) 

plt.plot(X,val_multi1,color='#80013f', linestyle='-', linewidth = 2, marker='o', markerfacecolor='#fd3c06', markersize=8)
plt.plot(X2,val_multi2,color='#80013f', linestyle='-', linewidth = 2, marker='*', markerfacecolor='#fd3c06', markersize=10)
plt.plot(X,val_multi12,color='#1e488f', linestyle='-', linewidth = 2, marker='o', markerfacecolor='#0652ff', markersize=8)
plt.plot(X2,val_multi22,color='#1e488f', linestyle='-', linewidth = 2, marker='*', markerfacecolor='#0652ff', markersize=10)
plt.plot(X,val_multi13,color='#3f9b0b', linestyle='-', linewidth = 2, marker='o', markerfacecolor='#3f9b0b', markersize=8)
plt.plot(X2,val_multi23,color='#3f9b0b', linestyle='-', linewidth = 2, marker='*', markerfacecolor='#3f9b0b', markersize=10)
#label
for x,x2,y,z,a,b,c,d in zip(X,X2,val_multi1, val_multi2,val_multi12,val_multi22,val_multi13,val_multi23):
    label1 = "{:}".format(y)
    label2 = "{:}".format(z)
    label3 = "{:}".format(a)
    label3 = "{:}".format(b)
    plt.annotate(label1, (x,y),textcoords="offset points", xytext=(0,10), ha='center')
    plt.annotate(label2, (x2,z),textcoords="offset points", xytext=(0,10), ha='center')
    plt.annotate(label3, (x,a),textcoords="offset points", xytext=(0,10), ha='center')   
    plt.annotate(label3, (x2,b),textcoords="offset points", xytext=(0,10), ha='center')   
    plt.annotate(label3, (x,c),textcoords="offset points", xytext=(0,10), ha='center')   
    plt.annotate(label3, (x2,d),textcoords="offset points", xytext=(0,10), ha='center')   

# Apply the legend to tell the graphs apart
# legend(['Abn&Nor of 5FP model','5FP of 5FP model','Abn&Nor of 13 Views model','13 Views of 13 Views model'], bbox_to_anchor=(1.0,0.148))
legend(['5FP model(1)','13Views model(1)','5FP model(2)','13Views model(2)',
        '5FP model(3)','13Views model(3)'], bbox_to_anchor=(0.18,0.28))
# Apply the TITLE, X-axis and Y-axis label
title(' Multi-task performance by Validation set',fontsize=20)
xlabel('Prediction',fontsize=18)
ylabel('Accuracy',fontsize=18)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(16, 8))

X = ['AbnNor_5FP','5FP']
X2 = ['AbnNor_13views','13views']
val_multi1 = [0.81,0.7]
test_multi1 =[0.81,0.74]
val_multi2 = [0.79,0.59]
test_multi2 =[0.78,0.61]

val_multi12 = [0.8,0.76]
test_multi12 =[0.82,0.79]
val_multi22 = [0.81,0.62]
test_multi22 =[0.82,0.63]

val_multi13 = [0.82,0.77]
test_multi13 =[0.84,0.75]
val_multi23 = [0.8,0.64]
test_multi23 =[0.83,0.65]
# setting x and y axis range 
plt.ylim(0.55,0.85) 

plt.plot(X,test_multi1,color='#80013f', linestyle='-', linewidth = 2, marker='o', markerfacecolor='#fd3c06', markersize=8)
plt.plot(X2,test_multi2,color='#80013f', linestyle='-', linewidth = 2, marker='*', markerfacecolor='#fd3c06', markersize=10)
plt.plot(X,test_multi12,color='#1e488f', linestyle='-', linewidth = 2, marker='o', markerfacecolor='#0652ff', markersize=8)
plt.plot(X2,test_multi22,color='#1e488f', linestyle='-', linewidth = 2, marker='*', markerfacecolor='#0652ff', markersize=10)
plt.plot(X,test_multi13,color='#3f9b0b', linestyle='-', linewidth = 2, marker='o', markerfacecolor='#3f9b0b', markersize=8)
plt.plot(X2,test_multi23,color='#3f9b0b', linestyle='-', linewidth = 2, marker='*', markerfacecolor='#3f9b0b', markersize=10)
#label
for x,x2,y,z,a,b,c,d in zip(X,X2,test_multi1, test_multi2,test_multi12,test_multi22,test_multi13,test_multi23):
    label1 = "{:}".format(y)
    label2 = "{:}".format(z)
    label3 = "{:}".format(a)
    label3 = "{:}".format(b)
    plt.annotate(label1, (x,y),textcoords="offset points", xytext=(0,10), ha='center')
    plt.annotate(label2, (x2,z),textcoords="offset points", xytext=(0,10), ha='center')
    plt.annotate(label3, (x,a),textcoords="offset points", xytext=(0,10), ha='center')   
    plt.annotate(label3, (x2,b),textcoords="offset points", xytext=(0,10), ha='center')   
    plt.annotate(label3, (x,c),textcoords="offset points", xytext=(0,10), ha='center')   
    plt.annotate(label3, (x2,d),textcoords="offset points", xytext=(0,10), ha='center')   

# Apply the legend to tell the graphs apart
# legend(['Abn&Nor of 5FP model','5FP of 5FP model','Abn&Nor of 13 Views model','13 Views of 13 Views model'], bbox_to_anchor=(1.0,0.148))
legend(['5FP model(1)','13Views model(1)','5FP model(2)','13Views model(2)',
        '5FP model(3)','13Views model(3)'], bbox_to_anchor=(0.18,0.28))
# Apply the TITLE, X-axis and Y-axis label
title(' Multi-task performance by Test set',fontsize=20)
xlabel('Prediction',fontsize=18)
ylabel('Accuracy',fontsize=18)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(16, 9))

X = ['AbnNor_5FP','5FP','AbnNor_13views','13views']

val_multi1 = [0.81,0.7,0.79,0.59]
test_multi1 =[0.81,0.74,0.78,0.61]
val_multi2 = [0.8,0.76,0.81,0.62]
test_multi2 =[0.82,0.79,0.82,0.63]
val_multi3 = [0.82,0.77,0.8,0.64]
test_multi3 =[0.84,0.75,0.83,0.65]


# setting x and y axis range 
plt.ylim(0.60,0.90) 

plt.plot(X,test_multi1,color='w', linestyle = None, marker='o', markerfacecolor='#0343df', markersize=8)
plt.plot(X,test_multi2,color='w', linestyle= None,  marker='o', markerfacecolor='#ff028d', markersize=8)
plt.plot(X,test_multi3,color='w', linestyle= None,  marker='o', markerfacecolor='#3f9b0b', markersize=8)

#label
for x,y,z,a in zip(X,test_multi1, test_multi2,test_multi3):
    label1 = "{:}".format(y)
    label2 = "{:}".format(z)
    label3 = "{:}".format(a)
    plt.annotate(label1, (x,y),textcoords="offset points", xytext=(0,10), ha='center')
    plt.annotate(label2, (x,z),textcoords="offset points", xytext=(0,10), ha='center')
    plt.annotate(label3, (x,a),textcoords="offset points", xytext=(0,10), ha='center')    
    
# Apply the legend to tell the graphs apart
legend(['(1) Data fold1','(2) Sampling  class balance data','(3) Sampling  class&AbnNor balance data'], bbox_to_anchor=(0.3,0.148))

# Apply the TITLE, X-axis and Y-axis label
title(' Multi-task performance by Test set',fontsize=20)
xlabel('model',fontsize=18)
ylabel('Accuracy',fontsize=18)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(20, 9))

X = ['R1','top_conv','block7a_se_excite','block6a_se_excite','block5a_se_excite','block4a_se_excite','block3a_se_excite']

yfocal_val_be = [0.78,0.81]
yfocal_val_af = [0.3,0.3]
yfocal_test_be = [0.78
0.81
0.82
,0.78]
yfocal_test_af = [0.54,0.62,0.71,0.77,0.59,0.3,0.78]
ycross_val_be = [0.81,0.79]
ycross_val_af = [0.3,0.3]
ycross_test_be = [0.8,0.6,0.78,0.73,0.86,0.75,0.84]
ycross_test_af = [0.54,0.66,0.67,0.3,0.3,0.3,0.81]

# setting x and y axis range 
plt.ylim(0.2,0.85) 

plt.plot(X,yfocal_test_af,color='#01ff07', linestyle='-', linewidth = 3, marker='o', markerfacecolor='#01ff07', markersize=8)
plt.plot(X,ycross_test_af,color='#ff81c0', linestyle='-', linewidth = 3, marker='o', markerfacecolor='#ff81c0', markersize=8)

#label
for x,y,z in zip(X,yfocal_test_af, ycross_test_af):
    label1 = "{:}".format(y)
    label2 = "{:}".format(z)
    plt.annotate(label1, (x,y),textcoords="offset points", xytext=(0,10), ha='center')
    plt.annotate(label2, (x,z),textcoords="offset points", xytext=(0,10), ha='center')
    
    
# Apply the legend to tell the graphs apart
legend(['FocalLoss-After','CrossLoss-After'], bbox_to_anchor=(1.0,0.148))

# Apply the TITLE, X-axis and Y-axis label
title(' After Treshold by Test set',fontsize=20)
xlabel('Unfreeze layers',fontsize=18)
ylabel('Accuracy',fontsize=18)

plt.show()

# %%
# 'NASNetLarge','NASNetMobile'

# %%
    ##กำลังเพิ่มการเเก้ไข

    fig, ax = plt.subplots(figsize=(16, 9))
    
    #scores
    sc = [0.9629,0.8962,0.9308,0.9679,0.9802,0.9975,0.9901,0.9777]
    sc1 = [0.8962,0.9135,0.8987,0.8938,0.8938,0.8814,0.8049,0.8543]
    sc2 = [0.7580,0.6913,]
    sc3 = [0.9382,0.9012]
    sc4 = 0.9135
    sc5 = 0.8493
    sc6 = 0.9037
    sc7 = 0.8469
    #paremeter
    para = [5.3,7.8,9.2,12,19,30,43,66]
    para2 = [23.59,42.66]
    para3 = [23.56,42.63]
    para4 = 4.2
    para5 = 54
    para6 = 22
    para7 = 84.9
    #networks name
    nets = ['Eff-B0','Eff-B1','Eff-B2','Eff-B3','Eff-B4','Eff-B5','Eff-B6','Eff-B7']
    nets2 = ['ResNet-50','ResNet-101']
    nets3 = ['ResNet-50-V2','ResNet-101-V2']
    nets4='NASNetMobile'
    nets5='InceptionResNetV2'
    nets6='InceptionV3'
    nets7='NASNetLarge'
    # setting x and y axis range 
    plt.ylim(0.68,1.03) 
    plt.xlim(0.00,88.00) 
    # plotting the points  
    plt.plot(para, sc , color='#c65102', linestyle='-', linewidth = 2, marker='o', markerfacecolor='r', markersize=8) 
    plt.plot(para, sc1, color='#047495', linestyle='-', linewidth = 2, marker='o', markerfacecolor='#0165fc', markersize=8) 
    plt.plot(para2, sc2, color='#c65102', linestyle='dashed', linewidth = 2, marker='o', markerfacecolor='r', markersize=8) 
    plt.plot(para3, sc3, color='#c65102', linestyle='dashed', linewidth = 2, marker='o', markerfacecolor='r', markersize=8) 
    plt.plot(para4, sc4, color='#c65102', marker='o',linestyle=' ', markerfacecolor='r', markersize=8) 
    plt.plot(para5, sc5, color='#c65102', marker='o',linestyle=' ', markerfacecolor='r', markersize=8) 
    plt.plot(para6, sc6, color='#c65102', marker='o',linestyle=' ', markerfacecolor='r', markersize=8) 
    plt.plot(para7, sc7, color='#c65102', marker='o',linestyle=' ', markerfacecolor='r', markersize=8)     
    for i in range(0,6):
        label = "{:}".format(nets[i+2])
        plt.annotate(label, (para[i+2], sc[i+2]), textcoords="offset points", xytext=(0,10), ha='center')
        plt.annotate(label, (para[i+2], sc1[i+2]), textcoords="offset points", xytext=(0,-20), ha='center') 
    plt.annotate(nets[0], (para[0], sc[0]), textcoords="offset points", xytext=(0,10), ha='center')
    plt.annotate(nets[0], (para[0], sc1[0]), textcoords="offset points", xytext=(0,-20), ha='center')
    plt.annotate(nets[1], (para[1], sc[1]), textcoords="offset points", xytext=(0,10), ha='center')
    for i in range(0,len(para2)):
        label1 = "{:}".format(nets2[i])
        plt.annotate(label1, (para2[i], sc2[i]), textcoords="offset points", xytext=(0,10), ha='center')
    for i in range(0,len(para3)):
        label2= "{:}".format(nets3[i])
        plt.annotate(label2, (para3[i], sc3[i]), textcoords="offset points", xytext=(0,10), ha='center')    
    
    plt.annotate(nets4, (para4, sc4), textcoords="offset points", xytext=(0,10), ha='center')      
    plt.annotate(nets5, (para5, sc5), textcoords="offset points", xytext=(0,10), ha='center') 
    plt.annotate(nets6, (para6, sc6), textcoords="offset points", xytext=(0,10), ha='center') 
    plt.annotate(nets7, (para7, sc7), textcoords="offset points", xytext=(0,10), ha='center') 
    # Apply the legend to tell the graphs apart
       #legend(['EffNet(ImageNet)', 'EffNet(Noisy-Student)','ResNet(ImageNet)','ResNet-V2(ImageNet)'])
    legend(['ImageNet', 'Noisy-Student'], bbox_to_anchor=(0.15,0.12))

    # Apply the TITLE, X-axis and Y-axis label
    title(' Performance comparison',fontsize=20)
    xlabel('Number of Parameters(Millions)',fontsize=18)
    ylabel('Accuracy',fontsize=18)

    show()

# %%
    ladera_temp_1996 = [53.9, 56.3, 56.4, 53.4, 54.5, 55.8, 56.8, 55.0, 55.3, 54.0, 56.7, 56.4]
    ladera_temp_2006 = [43.9, 66.3, 46.4, 63.4, 34.5, 75.8, 46.8, 65.0, 75.3, 64.0, 56.7, 46.4]
    ladera_temp_2016 = [23.9, 26.3, 36.4, 33.4, 44.5, 55.8, 66.8, 75.0, 65.3, 54.0, 46.7, 36.4]

    months = range(1, 13)

    # Plot the line WITH dots and the LINE
    plot(months, ladera_temp_1996, months, ladera_temp_2006, months, ladera_temp_2016, marker='+')

    # OR you can plot separately like this and the final show() method will know that it needs to plot everything that is queued up.
    # plot(months, ladera_temp_1996, marker='o')
    # plot(months, ladera_temp_2006, marker='o')
    # plot(months, ladera_temp_2016, marker='o')

    # Apply the legend to tell the graphs apart
    legend([1996, 2006, 2016])

    # Apply the TITLE, X-axis and Y-axis label
    title('Average monthly temperature in Ladera Ranch town')
    xlabel('Month')
    ylabel('Temperature in F')

    show()

# %%
import matplotlib.pyplot as plt 
  
# line 1 points 
x1 = [1,2,3] 
y1 = [2,4,1] 
# plotting the line 1 points  
plt.plot(x1, y1, label = "line 1") 
  
# line 2 points 
x2 = [1,2,3] 
y2 = [4,1,3] 
# plotting the line 2 points  
plt.plot(x2, y2, label = "line 2") 
  
# naming the x axis 
plt.xlabel('x - axis') 
# naming the y axis 
plt.ylabel('y - axis') 
# giving a title to my graph 
plt.title('Two lines on same graph!') 
  
# show a legend on the plot 
plt.legend() 
  
# function to show the plot 
plt.show()

# %%
import matplotlib.pyplot as plt 
  
# x axis values 
x = [1,2,3,4,5,6] 
# corresponding y axis values 
y = [2,4,1,5,2,6] 
  
# plotting the points  
plt.plot(x, y, color='green', linestyle='dashed', linewidth = 3, 
         marker='o', markerfacecolor='blue', markersize=12) 
  
# setting x and y axis range 
plt.ylim(1,8) 
plt.xlim(1,8) 
  
# naming the x axis 
plt.xlabel('x - axis') 
# naming the y axis 
plt.ylabel('y - axis') 
  
# giving a title to my graph 
plt.title('Some cool customizations!') 
  
# function to show the plot 
plt.show()

# %%
from pylab import plot, show, title, xlabel, ylabel
from pylab import legend
from pylab import axis


def main():
    print("main program")
    while True:
        print_menu()

        choice = raw_input('Pick from the menu? ')

        if choice == '1':
            plotting_example01()
        elif choice == '2':
            plotting_example02()
        elif choice == '3':
            plotting_example03()
        elif choice == '4':
            plotting_example04()
        elif choice == '5':
            plotting_example05()
        elif choice == '6':
            plotting_example06()
        elif choice == '7':
            plotting_example07()
        elif choice == 'q':
            break

        print("")

def print_menu():
    print("=========================================================================")
    print('1. Plot a few points WITHOUT dots for the given point and connect as line')
    print('2. Plot a few points WITH dots for the given point and connect as line')
    print('3. Plot a few points WITH dots and WITHOUT the LINE')
    print('4. Plot Ladera Ranch town temperature with DOTS and LINE and NO X-Axis specific range')
    print('5. Plot Ladera Ranch town temperature with DOTS and LINE and X-AXIS range specified')
    print('6. Plot Ladera Ranch averages in 1996, 2006 and 2016 for 12 months. 3 graphs')
    print('7. Plot Ladera Ranch averages - Adjust AXIS based on min and max')
    print("q. QUIT")
    print("=========================================================================")

# %%
from pylab import plot, show, title, xlabel, ylabel
from pylab import legend
from pylab import axis

# %%
ladera_temp = [53.9, 56.3, 56.4, 53.4, 54.5, 55.8, 56.8, 55.0, 55.3, 54.0, 56.7, 56.4, 57.3]

    # Plot the line WITH dots and the LINE
plot(ladera_temp, marker='o')
show()

# %%
ladera_temp = [53.9, 56.3, 56.4, 53.4, 54.5, 55.8, 56.8, 55.0, 55.3, 54.0, 56.7, 56.4, 57.3]
    # years = range(2000, 2013)
years = range(2000, len(ladera_temp) + 2000)

    # Plot the line WITH dots and the LINE
plot(years, ladera_temp, marker='o')
show()

# %%
    ladera_temp_1996 = [53.9, 56.3, 56.4, 53.4, 54.5, 55.8, 56.8, 55.0, 55.3, 54.0, 56.7, 56.4]
    ladera_temp_2006 = [43.9, 66.3, 46.4, 63.4, 34.5, 75.8, 46.8, 65.0, 75.3, 64.0, 56.7, 46.4]
    ladera_temp_2016 = [23.9, 26.3, 36.4, 33.4, 44.5, 55.8, 66.8, 75.0, 65.3, 54.0, 46.7, 36.4]

    months = range(1, 13)

    # Plot the line WITH dots and the LINE
    plot(months, ladera_temp_1996, months, ladera_temp_2006, months, ladera_temp_2016, marker='+')

    # OR you can plot separately like this and the final show() method will know that it needs to plot everything that is queued up.
    # plot(months, ladera_temp_1996, marker='o')
    # plot(months, ladera_temp_2006, marker='o')
    # plot(months, ladera_temp_2016, marker='o')

    # Apply the legend to tell the graphs apart
    legend([1996, 2006, 2016])

    # Apply the TITLE, X-axis and Y-axis label
    title('Average monthly temperature in Ladera Ranch town')
    xlabel('Month')
    ylabel('Temperature in F')

    show()

# %%
    ladera_temp_1996 = [53.9, 56.3, 56.4, 53.4, 54.5, 55.8, 56.8, 55.0, 55.3, 54.0, 56.7, 56.4]
    ladera_temp_2006 = [43.9, 66.3, 46.4, 63.4, 34.5, 75.8, 46.8, 65.0, 75.3, 64.0, 56.7, 46.4]
    ladera_temp_2016 = [23.9, 26.3, 36.4, 33.4, 44.5, 55.8, 66.8, 75.0, 65.3, 54.0, 46.7, 36.4]

    months = range(1, 13)

    # Plot the line WITH dots and the LINE
    plot(months, ladera_temp_1996, months, ladera_temp_2006, months, ladera_temp_2016, marker='+')

    # OR you can plot separately like this and the final show() method will know that it needs to plot everything that is queued up.
    # plot(months, ladera_temp_1996, marker='o')
    # plot(months, ladera_temp_2006, marker='o')
    # plot(months, ladera_temp_2016, marker='o')

    # Figure out AXIS X and Y min and max and set it for the graphs.
    print(axis())
    xy_tuple = axis()   # returns tuple (x-min, x-max, y-min, y-max)
    my_ymin = xy_tuple[2]
    axis(ymin=my_ymin-20)
    axis(xmax=xy_tuple[1]+6)

    # Another way to set X-min, X-max, y-min, y-max
    # axis([xy_tuple[0], xy_tuple[1], xy_tuple[2], xy_tuple[3]])

    # Apply the legend to tell the graphs apart
    legend([1996, 2006, 2016])

    # Apply the TITLE, X-axis and Y-axis label
    title('Average monthly temperature in Ladera Ranch town')
    xlabel('Month')
    ylabel('Temperature in F')

    show()
# Out:
# (0.44999999999999996, 12.55, 21.305, 78.395)

# %%
x_numbers = [1, 2, 3]
y_numbers = [2, 4, 6]

# Plot the line WITHOUT dots for the given points
plot(x_numbers, y_numbers)
show()

# %%
def plotting_example01():
    print("Plotting example 1............")

    x_numbers = [1, 2, 3]
    y_numbers = [2, 4, 6]

    # Plot the line WITHOUT dots for the given points
    plot(x_numbers, y_numbers)
    show()


def plotting_example02():
    print("Plotting example 2............")

    x_numbers = [1, 2, 3]
    y_numbers = [2, 4, 6]

    # Plot the line WITH dots for the given points
    # Markers can be 'o' or '*' or 'x' or '+'
    plot(x_numbers, y_numbers, marker='o')
    show()


def plotting_example03():
    print("Plotting example 3............")

    x_numbers = [1, 2, 3]
    y_numbers = [2, 4, 6]

    # Plot the line WITH dots and WITHOUT LINE
    plot(x_numbers, y_numbers, 'o')
    show()


def plotting_example04():
    print("Plotting example 4............")

    ladera_temp = [53.9, 56.3, 56.4, 53.4, 54.5, 55.8, 56.8, 55.0, 55.3, 54.0, 56.7, 56.4, 57.3]

    # Plot the line WITH dots and the LINE
    plot(ladera_temp, marker='o')
    show()


def plotting_example05():
    print("Plotting example 5............")

    ladera_temp = [53.9, 56.3, 56.4, 53.4, 54.5, 55.8, 56.8, 55.0, 55.3, 54.0, 56.7, 56.4, 57.3]
    # years = range(2000, 2013)
    years = range(2000, len(ladera_temp) + 2000)

    # Plot the line WITH dots and the LINE
    plot(years, ladera_temp, marker='o')
    show()


def plotting_example06():
    print("Plotting example 6............")

    ladera_temp_1996 = [53.9, 56.3, 56.4, 53.4, 54.5, 55.8, 56.8, 55.0, 55.3, 54.0, 56.7, 56.4]
    ladera_temp_2006 = [43.9, 66.3, 46.4, 63.4, 34.5, 75.8, 46.8, 65.0, 75.3, 64.0, 56.7, 46.4]
    ladera_temp_2016 = [23.9, 26.3, 36.4, 33.4, 44.5, 55.8, 66.8, 75.0, 65.3, 54.0, 46.7, 36.4]

    months = range(1, 13)

    # Plot the line WITH dots and the LINE
    plot(months, ladera_temp_1996, months, ladera_temp_2006, months, ladera_temp_2016, marker='+')

    # OR you can plot separately like this and the final show() method will know that it needs to plot everything that is queued up.
    # plot(months, ladera_temp_1996, marker='o')
    # plot(months, ladera_temp_2006, marker='o')
    # plot(months, ladera_temp_2016, marker='o')

    # Apply the legend to tell the graphs apart
    legend([1996, 2006, 2016])

    # Apply the TITLE, X-axis and Y-axis label
    title('Average monthly temperature in Ladera Ranch town')
    xlabel('Month')
    ylabel('Temperature in F')

    show()


def plotting_example07():
    print("Plotting example 7............")

    ladera_temp_1996 = [53.9, 56.3, 56.4, 53.4, 54.5, 55.8, 56.8, 55.0, 55.3, 54.0, 56.7, 56.4]
    ladera_temp_2006 = [43.9, 66.3, 46.4, 63.4, 34.5, 75.8, 46.8, 65.0, 75.3, 64.0, 56.7, 46.4]
    ladera_temp_2016 = [23.9, 26.3, 36.4, 33.4, 44.5, 55.8, 66.8, 75.0, 65.3, 54.0, 46.7, 36.4]

    months = range(1, 13)

    # Plot the line WITH dots and the LINE
    plot(months, ladera_temp_1996, months, ladera_temp_2006, months, ladera_temp_2016, marker='+')

    # OR you can plot separately like this and the final show() method will know that it needs to plot everything that is queued up.
    # plot(months, ladera_temp_1996, marker='o')
    # plot(months, ladera_temp_2006, marker='o')
    # plot(months, ladera_temp_2016, marker='o')

    # Figure out AXIS X and Y min and max and set it for the graphs.
    print(axis())
    xy_tuple = axis()   # returns tuple (x-min, x-max, y-min, y-max)
    my_ymin = xy_tuple[2]
    axis(ymin=my_ymin-20)
    axis(xmax=xy_tuple[1]+6)

    # Another way to set X-min, X-max, y-min, y-max
    # axis([xy_tuple[0], xy_tuple[1], xy_tuple[2], xy_tuple[3]])

    # Apply the legend to tell the graphs apart
    legend([1996, 2006, 2016])

    # Apply the TITLE, X-axis and Y-axis label
    title('Average monthly temperature in Ladera Ranch town')
    xlabel('Month')
    ylabel('Temperature in F')

    show()
