# %%
import pandas as pd
df = pd.read_csv( '/home/yupaporn/CSV_file/result_BiTNet_FPScores.csv')#แก้

# %%
df
# Out:
#       Unnamed: 0     Case Abs Position Sub Position     Class  \
# 0              0  AB01_40           P1           P1  Abnormal
# 1              1  AB01_40           P2           P2  Abnormal
# 2              2  AB01_40           P4          P41  Abnormal
# 3              3  AB01_40           P5          P51  Abnormal
# 4              4  AB01_40           P3          P31  Abnormal
# ...          ...      ...          ...          ...       ...
# 1307        1307      350           P3          P32    Normal
# 1308        1308      350           P4          P42    Normal
# 1309        1309      350           P5          P52    Normal
# 1310        1310      350           P6          P61    Normal
# 1311        1311      350           P8           P8    Normal
#
#                                               Path Full  \
# 0     /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 1     /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# ...

# %%
# df = df.replace({'15AB': {'RenalParenchymalchange': 'RenalParenchymalChange', 'Renalstones': 'RenalStone', 'RenalstonesHydronephrosis': 'RenalstonesAndHydronephrosis'}})
# df.to_csv('/home/yupaporn/CSV_file/result_BiTNet_FPScores.csv', index=False)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Case', 'Abs Position', 'Sub Position', 'Class',
#        'Path Full', 'Path Crop', 'Views', 'fold', '15AB', 'originalImage',
#        'left', 'top', 'width', 'height', 'Rleft', 'Rtop', 'Rwidth', 'Rheight',
#        'Sub_class_New', 'tag_AjNit', 'tag_AjWan', 'Test150', 'Spilt',
#        '15AB_FPPred_3', 'Prob_FPPred_3', '15AB_pred', 'Prob_pred',
#        '15AB_FPAct_3', 'Prob_FPAct_3', '15AB_pred_', '15AB_FPPred_3_',
#        '15AB_FPAct_3_'],
#       dtype='object')

# %%
res = df

#None
AI_pred = res['15AB_pred'].tolist()
act = res['Sub_class_New'].tolist()
Acc  = []
Acc_  = []
for i in  range(len(AI_pred)):
    if act[i] == AI_pred[i]:
        Acc.append('Correct')
    else:
        Acc.append('Incorrect')

res['15AB_pred_'] =Acc

#None
AI_pred = res['15AB_FPPred_3'].tolist()
act = res['Sub_class_New'].tolist()
Acc  = []
Acc_  = []
for i in  range(len(AI_pred)):
    if act[i] == AI_pred[i]:
        Acc.append('Correct')
    else:
        Acc.append('Incorrect')

res['15AB_FPPred_3_'] =Acc

#None
AI_pred = res['15AB_FPAct_3'].tolist()
act = res['Sub_class_New'].tolist()
Acc  = []
Acc_  = []
for i in  range(len(AI_pred)):
    if act[i] == AI_pred[i]:
        Acc.append('Correct')
    else:
        Acc.append('Incorrect')

res['15AB_FPAct_3_'] =Acc

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Case', 'Abs Position', 'Sub Position', 'Class',
#        'Path Full', 'Path Crop', 'Views', 'fold', '15AB', 'originalImage',
#        'left', 'top', 'width', 'height', 'Rleft', 'Rtop', 'Rwidth', 'Rheight',
#        'Sub_class_New', 'tag_AjNit', 'tag_AjWan', 'Test150', 'Spilt',
#        '15AB_FPPred_3', 'Prob_FPPred_3', '15AB_pred', 'Prob_pred',
#        '15AB_FPAct_3', 'Prob_FPAct_3', '15AB_pred_', '15AB_FPPred_3_',
#        '15AB_FPAct_3_'],
#       dtype='object')

# %%
df[["Sub_class_New","15AB" ,"Case"]].groupby(['Sub_class_New',"15AB"]).count().reset_index()
# Out:
#    Sub_class_New                            15AB  Case
# 0           AB01                  MildFattyLiver    74
# 1           AB02              ModerateFattyLiver    59
# 2           AB03                SevereFattyLiver    19
# 3           AB04                       Cirrhosis    38
# 4           AB05                            PDF1    29
# 5           AB06                            PDF2    21
# 6           AB07                            PDF3    21
# 7          AB081                       Livermass    32
# 8          AB082                             BDD    28
# 9          AB083                 LivermassAndBDD    11
# 10          AB09                Gallbladderstone    26
# 11          AB10                 GallbladderMass     1
# 12          AB10                Gallbladderpolyp     9
# 13          AB11                  Hydronephrosis    18
# 14          AB11                       RenalCyst     2
# 15          AB11               RenalCystAndStone     1
# ...

# %% [markdown]
# # None

# %% [markdown]
# # ทำนายผิดเเค่ไหนหาสัดสัดอิงตามจำนวน class ที่ทำนาย

# %%
df.head()
# Out:
#    Unnamed: 0     Case Abs Position Sub Position     Class  \
# 0           0  AB01_40           P1           P1  Abnormal
# 1           1  AB01_40           P2           P2  Abnormal
# 2           2  AB01_40           P4          P41  Abnormal
# 3           3  AB01_40           P5          P51  Abnormal
# 4           4  AB01_40           P3          P31  Abnormal
#
#                                            Path Full  \
# 0  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 1  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 3  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 4  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
#
#                                            Path Crop Views  fold  \
# 0  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...  FP-A     2
# 1  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...  FP-A     2
# 2  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...  FP-B     2
# ...

# %%
df[["15AB_pred", "15AB_pred_", "Unnamed: 0"]].groupby(["15AB_pred", "15AB_pred_"]).count().reset_index()
# Out:
#    15AB_pred 15AB_pred_  Unnamed: 0
# 0       AB01    Correct          45
# 1       AB01  Incorrect          12
# 2       AB02    Correct          35
# 3       AB02  Incorrect          26
# 4       AB03    Correct           9
# 5       AB03  Incorrect           9
# 6       AB04    Correct          26
# 7       AB04  Incorrect           6
# 8       AB05    Correct          19
# 9       AB05  Incorrect           4
# 10      AB06    Correct          10
# 11      AB06  Incorrect           2
# 12      AB07    Correct          10
# 13      AB07  Incorrect           4
# 14     AB081    Correct          18
# 15     AB081  Incorrect           5
# 16     AB082    Correct          15
# 17     AB082  Incorrect           4
# 18     AB083    Correct           4
# 19     AB083  Incorrect           1
# 20      AB09    Correct          20
# 21      AB10    Correct           4
# 22      AB10  Incorrect           1
# 23      AB11    Correct          20
# 24      AB11  Incorrect           2
# ...

# %% [markdown]
# ## ทำนายผิดเเค่ไหนหาสัดสัดอิงตามจำนวน class จริง

# %%
Correct = df[df['15AB_pred_'] == 'Correct']
Incorrect = df[df['15AB_pred_'] == 'Incorrect']

# %%
Incorrect[['Sub_class_New', '15AB_pred']]
# Out:
#      Sub_class_New 15AB_pred
# 0             AB01    Normal
# 2             AB01      AB02
# 4             AB01      AB02
# 8             AB02      AB03
# 13            AB06    Normal
# ...            ...       ...
# 969         Normal      AB01
# 1117        Normal      AB05
# 1291        Normal      AB04
# 1294        Normal      AB05
# 1305        Normal      AB11
#
# [201 rows x 2 columns]

# %%
Incorrect[["Sub_class_New","15AB" ,"15AB_pred","Case"]].groupby(['Sub_class_New',"15AB","15AB_pred"]).count().reset_index()
# Out:
#    Sub_class_New                          15AB 15AB_pred  Case
# 0           AB01                MildFattyLiver      AB02    16
# 1           AB01                MildFattyLiver    Normal    13
# 2           AB02            ModerateFattyLiver      AB01     9
# 3           AB02            ModerateFattyLiver      AB03     9
# 4           AB02            ModerateFattyLiver      AB10     1
# 5           AB02            ModerateFattyLiver    Normal     5
# 6           AB03              SevereFattyLiver      AB02    10
# 7           AB04                     Cirrhosis      AB06     1
# 8           AB04                     Cirrhosis      AB07     1
# 9           AB04                     Cirrhosis     AB081     1
# 10          AB04                     Cirrhosis    Normal     9
# 11          AB05                          PDF1     AB081     1
# 12          AB05                          PDF1    Normal     9
# 13          AB06                          PDF2      AB05     1
# ...

# %% [markdown]
# # แบบที่ 3 +FPAct

# %% [markdown]
# ## ทำนายผิดเเค่ไหนหาสัดสัดอิงตามจำนวน class ที่ทำนาย

# %%
df[["15AB_FPAct_3", "15AB_FPAct_3_", "Unnamed: 0"]].groupby(["15AB_FPAct_3", "15AB_FPAct_3_"]).count().reset_index()
# Out:
#    15AB_FPAct_3 15AB_FPAct_3_  Unnamed: 0
# 0          AB01       Correct          45
# 1          AB01     Incorrect          13
# 2          AB02       Correct          35
# 3          AB02     Incorrect          26
# 4          AB03       Correct           9
# 5          AB03     Incorrect          10
# 6          AB04       Correct          26
# 7          AB04     Incorrect           6
# 8          AB05       Correct          19
# 9          AB05     Incorrect           5
# 10         AB06       Correct          11
# 11         AB06     Incorrect           1
# 12         AB07       Correct          11
# 13         AB07     Incorrect           3
# 14        AB081       Correct          19
# 15        AB081     Incorrect           6
# 16        AB082       Correct          16
# 17        AB082     Incorrect           4
# 18        AB083       Correct           3
# 19         AB09       Correct          21
# 20         AB10       Correct           4
# ...

# %% [markdown]
# ## ทำนายผิดเเค่ไหนหาสัดสัดอิงตามจำนวน class จริง

# %%
Correct = df[df['15AB_FPAct_3_'] == 'Correct']
Incorrect = df[df['15AB_FPAct_3_'] == 'Incorrect']

# %%
Incorrect[["Sub_class_New","15AB" ,"15AB_FPAct_3","Case"]].groupby(['Sub_class_New',"15AB","15AB_FPAct_3"]).count().reset_index()
# Out:
#    Sub_class_New                          15AB 15AB_FPAct_3  Case
# 0           AB01                MildFattyLiver         AB02    16
# 1           AB01                MildFattyLiver       Normal    13
# 2           AB02            ModerateFattyLiver         AB01    10
# 3           AB02            ModerateFattyLiver         AB03     9
# 4           AB02            ModerateFattyLiver       Normal     5
# 5           AB03              SevereFattyLiver         AB02    10
# 6           AB04                     Cirrhosis         AB06     1
# 7           AB04                     Cirrhosis         AB07     1
# 8           AB04                     Cirrhosis        AB081     1
# 9           AB04                     Cirrhosis       Normal     9
# 10          AB05                          PDF1        AB081     1
# 11          AB05                          PDF1       Normal     9
# 12          AB06                          PDF2         AB05     1
# ...

# %% [markdown]
# # แบบที่ 3 +FPPred

# %%
df
# Out:
#       Unnamed: 0     Case Abs Position Sub Position     Class  \
# 0              0  AB01_40           P1           P1  Abnormal
# 1              1  AB01_40           P2           P2  Abnormal
# 2              2  AB01_40           P4          P41  Abnormal
# 3              3  AB01_40           P5          P51  Abnormal
# 4              4  AB01_40           P3          P31  Abnormal
# ...          ...      ...          ...          ...       ...
# 1307        1307      350           P3          P32    Normal
# 1308        1308      350           P4          P42    Normal
# 1309        1309      350           P5          P52    Normal
# 1310        1310      350           P6          P61    Normal
# 1311        1311      350           P8           P8    Normal
#
#                                               Path Full  \
# 0     /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 1     /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# ...

# %%
Correct = df[df['15AB_FPPred_3_'] == 'Correct']
Incorrect = df[df['15AB_FPPred_3_'] == 'Incorrect']

# %%
Incorrect[["Sub_class_New","15AB" ,"15AB_FPPred_3","Case"]].groupby(['Sub_class_New',"15AB","15AB_FPPred_3"]).count().reset_index()
# Out:
#    Sub_class_New                          15AB 15AB_FPPred_3  Case
# 0           AB01                MildFattyLiver          AB02    16
# 1           AB01                MildFattyLiver        Normal    13
# 2           AB02            ModerateFattyLiver          AB01    10
# 3           AB02            ModerateFattyLiver          AB03     9
# 4           AB02            ModerateFattyLiver        Normal     5
# 5           AB03              SevereFattyLiver          AB02     9
# 6           AB03              SevereFattyLiver        Normal     1
# 7           AB04                     Cirrhosis          AB06     1
# 8           AB04                     Cirrhosis          AB07     1
# 9           AB04                     Cirrhosis         AB081     1
# 10          AB04                     Cirrhosis        Normal     9
# 11          AB05                          PDF1         AB081     1
# 12          AB05                          PDF1        Normal     9
# ...

# %% [markdown]
# # รายเคส

# %%
import pandas as pd
df = pd.read_csv( '/home/yupaporn/CSV_file/result_BiTNet_FPScores.csv')#แก้

# %%
df
# Out:
#       Unnamed: 0     Case Abs Position Sub Position     Class  \
# 0              0  AB01_40           P1           P1  Abnormal
# 1              1  AB01_40           P2           P2  Abnormal
# 2              2  AB01_40           P4          P41  Abnormal
# 3              3  AB01_40           P5          P51  Abnormal
# 4              4  AB01_40           P3          P31  Abnormal
# ...          ...      ...          ...          ...       ...
# 1307        1307      350           P3          P32    Normal
# 1308        1308      350           P4          P42    Normal
# 1309        1309      350           P5          P52    Normal
# 1310        1310      350           P6          P61    Normal
# 1311        1311      350           P8           P8    Normal
#
#                                               Path Full  \
# 0     /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 1     /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Case', 'Abs Position', 'Sub Position', 'Class',
#        'Path Full', 'Path Crop', 'Views', 'fold', '15AB', 'originalImage',
#        'left', 'top', 'width', 'height', 'Rleft', 'Rtop', 'Rwidth', 'Rheight',
#        'Sub_class_New', 'tag_AjNit', 'tag_AjWan', 'Test150', 'Spilt',
#        '15AB_FPPred_3', 'Prob_FPPred_3', '15AB_pred', 'Prob_pred',
#        '15AB_FPAct_3', 'Prob_FPAct_3', '15AB_pred_', '15AB_FPPred_3_',
#        '15AB_FPAct_3_'],
#       dtype='object')

# %% [markdown]
# ### Abn&Normal

# %%
dff.columns
# Out:
# Index(['Unnamed: 0', 'Case', 'Abs Position', 'Sub Position', 'Class',
#        'Path Full', 'Path Crop', 'Views', 'fold', '15AB', 'originalImage',
#        'left', 'top', 'width', 'height', 'Rleft', 'Rtop', 'Rwidth', 'Rheight',
#        'Sub_class_New', 'tag_AjNit', 'tag_AjWan', 'Test150', 'Spilt',
#        '15AB_FPPred_3', 'Prob_FPPred_3', '15AB_pred', 'Prob_pred',
#        '15AB_FPAct_3', 'Prob_FPAct_3', '15AB_pred_', '15AB_FPPred_3_',
#        '15AB_FPAct_3_', 'Act_Predic_CCA', '15AB_pred_CCA', '15AB_FPAct_3_CCA',
#        'AI_Pred_CCA', 'AI_Pred_CCAAct_3', 'Act_Predic_CCA_', '15AB_pred_CCA_',
#        'Sub_class_New_'],
#       dtype='object')

# %%
dff['Sub_class_New_'] = dff['Sub_class_New'].map({'AB12':1, 'AB04':1, 'AB06':1, 'Normal':0, 'AB081':1, 'AB10':1, 'AB03':1, 'AB02':1, 'AB083':1, 'AB11':1, 'AB01':1, 'AB09':1, 'AB07':1, 'AB082':1, 'AB05':1}).array
dff['15AB_pred_'] =  dff['15AB_pred'].map({'AB12':1, 'AB04':1, 'AB06':1, 'Normal':0, 'AB081':1, 'AB10':1, 'AB03':1, 'AB02':1, 'AB083':1, 'AB11':1, 'AB01':1, 'AB09':1, 'AB07':1, 'AB082':1, 'AB05':1}).array
dff['15AB_FPAct_3_'] =  dff['15AB_FPAct_3'].map({'AB12':1, 'AB04':1, 'AB06':1, 'Normal':0, 'AB081':1, 'AB10':1, 'AB03':1, 'AB02':1, 'AB083':1, 'AB11':1, 'AB01':1, 'AB09':1, 'AB07':1, 'AB082':1, 'AB05':1}).array

# %%
a = dff['Sub_class_New_'].tolist()
b = dff['15AB_pred_'].tolist()

res =[]
for  i in range(len(a)):
    if a[i] == b[i]:
        res.append('Correct')
    else:
        res.append('Incorrect')
dff['AI_Pred_AN']  = res

a = dff['Sub_class_New_'].tolist()
b = dff['15AB_FPAct_3_'].tolist()

res =[]
for  i in range(len(a)):
    if a[i] == b[i]:
        res.append('Correct')
    else:
        res.append('Incorrect')
dff['AI_Pred_ANAct_3']  = res

# %%
#Recall
#รายรูป#BiTNeT
Correct = dff[dff['AI_Pred_AN'] == 'Correct']
Incorrect = dff[dff['AI_Pred_AN'] == 'Incorrect']
Incorrect[["Sub_class_New_","15AB_pred_" ,"Unnamed: 0"]].groupby(['Sub_class_New_',"15AB_pred_"]).count().reset_index()
# Out:
#    Sub_class_New_  15AB_pred_  Unnamed: 0
# 0               0           1           5
# 1               1           0          92

# %%
#Recall
#รายรูป#BiTNeT+FP
Correct = dff[dff['AI_Pred_ANAct_3'] == 'Correct']
Incorrect = dff[dff['AI_Pred_ANAct_3'] == 'Incorrect']
Incorrect[["Sub_class_New_","15AB_FPAct_3_" ,"Unnamed: 0"]].groupby(['Sub_class_New_',"15AB_FPAct_3_"]).count().reset_index()
# Out:
#    Sub_class_New_  15AB_FPAct_3_  Unnamed: 0
# 0               0              1           4
# 1               1              0          92

# %%
len(dff[dff['Sub_class_New_']==0])
# Out:
# 857

# %%
len(dff[dff['Sub_class_New_']!=0])
# Out:
# 455

# %%
#Precision
#รายรูป#BiTNeT
dff[["15AB_pred_", "AI_Pred_AN", "Case"]].groupby(["15AB_pred_", "AI_Pred_AN"]).count().reset_index()
# Out:
#    15AB_pred_ AI_Pred_AN  Case
# 0           0    Correct   852
# 1           0  Incorrect    92
# 2           1    Correct   363
# 3           1  Incorrect     5

# %%
#Precision
#รายรูป#BiTNeT+FP
dff[["15AB_FPAct_3_", "AI_Pred_ANAct_3", "Case"]].groupby(["15AB_FPAct_3_", "AI_Pred_ANAct_3"]).count().reset_index()
# Out:
#    15AB_FPAct_3_ AI_Pred_ANAct_3  Case
# 0              0         Correct   853
# 1              0       Incorrect    92
# 2              1         Correct   363
# 3              1       Incorrect     4

# %%
col_name = ['Case', 'AN_Case_Act', 'AN_Case_AI','AN_Case_AIAct_3', 'Set_Case_AI' ,'Set_Case_AIAct_3', 'Set_Case_Act', 'Num_Case']
dff2 = pd.DataFrame(columns = col_name)

case = list(set(df['Case']))
AN_15AB_case = []
num_case = []
set_case = []
for i in case:
    cas = set(df[df['Case'] == i]['15AB_pred'])
    set_case.append(list(cas))
    num_case.append(len(cas))
    if cas == {'Normal'}:
        AN_15AB_case.append('Normal')
        # print(cas)
    else:
        AN_15AB_case.append('Abnormal')
dff2['AN_Case_AI'] = AN_15AB_case
dff2['Case'] = case
dff2['Num_Case'] = num_case
dff2['Set_Case_AI'] = set_case

case = list(set(df['Case']))
AN_15AB_case = []
set_case = []
for i in case:
    cas = set(df[df['Case'] == i]['Sub_class_New'])
    set_case.append(list(cas))
    if cas == {'Normal'}:
        AN_15AB_case.append('Normal')
        # print(cas)
    else:
        AN_15AB_case.append('Abnormal')
dff2['AN_Case_Act'] = AN_15AB_case
dff2['Set_Case_Act'] = set_case

# %%
case = list(set(df['Case']))
AN_15AB_case = []
num_case = []
set_case = []
for i in case:
    cas = set(df[df['Case'] == i]['15AB_FPAct_3'])
    set_case.append(list(cas))
    num_case.append(len(cas))
    if cas == {'Normal'}:
        AN_15AB_case.append('Normal')
        # print(cas)
    else:
        AN_15AB_case.append('Abnormal')
dff2['AN_Case_AIAct_3'] = AN_15AB_case
dff2['Set_Case_AIAct_3'] = set_case

# %%
dff2
# Out:
#          Case AN_Case_Act AN_Case_AI AN_Case_AIAct_3     Set_Case_AI  \
# 0           1      Normal     Normal          Normal        [Normal]
# 1    AB081_65    Abnormal   Abnormal        Abnormal         [AB081]
# 2     AB02_30    Abnormal   Abnormal        Abnormal  [AB02, Normal]
# 3      AB10_9    Abnormal   Abnormal        Abnormal          [AB10]
# 4     AB02_90    Abnormal   Abnormal        Abnormal          [AB03]
# ..        ...         ...        ...             ...             ...
# 368   Ab3_136    Abnormal   Abnormal        Abnormal          [AB02]
# 369       150      Normal     Normal          Normal        [Normal]
# 370  AB09_101    Abnormal   Abnormal        Abnormal          [AB07]
# 371    AB05_2    Abnormal     Normal          Normal        [Normal]
# 372       141      Normal     Normal          Normal        [Normal]
#
#     Set_Case_AIAct_3 Set_Case_Act  Num_Case
# 0           [Normal]     [Normal]         1
# 1            [AB081]      [AB081]         1
# ...

# %%
a = dff2['AN_Case_Act'].tolist()
b = dff2['AN_Case_AI'].tolist()

res =[]
for  i in range(len(a)):
    if a[i] == b[i]:
        res.append('Correct')
    else:
        res.append('Incorrect')
dff2['AI_Pred_AN']  = res

a = dff2['AN_Case_Act'].tolist()
b = dff2['AN_Case_AIAct_3'].tolist()

res =[]
for  i in range(len(a)):
    if a[i] == b[i]:
        res.append('Correct')
    else:
        res.append('Incorrect')
dff2['AI_Pred_ANAct_3']  = res

# %%
dff2
# Out:
#          Case AN_Case_Act AN_Case_AI AN_Case_AIAct_3     Set_Case_AI  \
# 0           1      Normal     Normal          Normal        [Normal]
# 1    AB081_65    Abnormal   Abnormal        Abnormal         [AB081]
# 2     AB02_30    Abnormal   Abnormal        Abnormal  [AB02, Normal]
# 3      AB10_9    Abnormal   Abnormal        Abnormal          [AB10]
# 4     AB02_90    Abnormal   Abnormal        Abnormal          [AB03]
# ..        ...         ...        ...             ...             ...
# 368   Ab3_136    Abnormal   Abnormal        Abnormal          [AB02]
# 369       150      Normal     Normal          Normal        [Normal]
# 370  AB09_101    Abnormal   Abnormal        Abnormal          [AB07]
# 371    AB05_2    Abnormal     Normal          Normal        [Normal]
# 372       141      Normal     Normal          Normal        [Normal]
#
#     Set_Case_AIAct_3 Set_Case_Act  Num_Case AI_Pred_AN AI_Pred_ANAct_3
# ...

# %% [markdown]
# #### Recall

# %%
#BiTNeT
Correct = dff2[dff2['AI_Pred_AN'] == 'Correct']
Incorrect = dff2[dff2['AI_Pred_AN'] == 'Incorrect']
Incorrect[["AN_Case_Act","AN_Case_AI" ,"Case"]].groupby(['AN_Case_Act',"AN_Case_AI"]).count().reset_index()
# Out:
#   AN_Case_Act AN_Case_AI  Case
# 0    Abnormal     Normal    50
# 1      Normal   Abnormal     4

# %%
#BiTNeT+5FP_3
Correct = dff2[dff2['AI_Pred_ANAct_3'] == 'Correct']
Incorrect = dff2[dff2['AI_Pred_ANAct_3'] == 'Incorrect']
Incorrect[["AN_Case_Act","AN_Case_AIAct_3" ,"Case"]].groupby(['AN_Case_Act',"AN_Case_AIAct_3"]).count().reset_index()
# Out:
#   AN_Case_Act AN_Case_AIAct_3  Case
# 0    Abnormal          Normal    50
# 1      Normal        Abnormal     3

# %%
len(set(dff2[dff2['AN_Case_Act'] == 'Normal']['Case']))
# Out:
# 71

# %%
len(set(dff2[dff2['AN_Case_Act'] == 'Abnormal']['Case']))
# Out:
# 302

# %%
train_df = pd.read_csv( '/home/yupaporn/codes/USAI/Traindf.csv')
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'Case', 'Abs Position', 'Sub Position',
#        'Class', 'Sub_class', 'Path Full', 'Path Crop', 'Views', 'fold',
#        'tagName', 'originalImage', 'left', 'top', 'width', 'height', 'Rleft',
#        'Rtop', 'Rwidth', 'Rheight', 'filename'],
#       dtype='object')

# %%
len(set(train_df[train_df['Sub_class']== 'Normal']['Case']))
# Out:
# 289

# %%
train_df[train_df['Sub_class']!= 'Normal']['Case']
# Out:
# 0        15
# 1        15
# 2        15
# 3        15
# 4        15
#        ...
# 1818    326
# 1819    330
# 1820    331
# 1821    358
# 1822    373
# Name: Case, Length: 1823, dtype: int64

# %% [markdown]
# #### Precision

# %%
#BiTNeT
dff2[["AN_Case_AI", "AI_Pred_AN", "Case"]].groupby(["AN_Case_AI", "AI_Pred_AN"]).count().reset_index()
# Out:
#   AN_Case_AI AI_Pred_AN  Case
# 0   Abnormal    Correct   252
# 1   Abnormal  Incorrect     4
# 2     Normal    Correct    67
# 3     Normal  Incorrect    50

# %%
#BiTNeT+5FP_3
dff2[["AN_Case_AIAct_3", "AI_Pred_ANAct_3", "Case"]].groupby(["AN_Case_AIAct_3", "AI_Pred_ANAct_3"]).count().reset_index()
# Out:
#   AN_Case_AIAct_3 AI_Pred_ANAct_3  Case
# 0        Abnormal         Correct   252
# 1        Abnormal       Incorrect     3
# 2          Normal         Correct    68
# 3          Normal       Incorrect    50

# %% [markdown]
# ### Suspect&Non-Suspect

# %%
Suspected_CCA = ['AB05', 'AB06', 'AB07', 'AB081', 'AB082', 'AB083']

# %%
dff = df

# %%
dff.columns
# Out:
# Index(['Unnamed: 0', 'Case', 'Abs Position', 'Sub Position', 'Class',
#        'Path Full', 'Path Crop', 'Views', 'fold', '15AB', 'originalImage',
#        'left', 'top', 'width', 'height', 'Rleft', 'Rtop', 'Rwidth', 'Rheight',
#        'Sub_class_New', 'tag_AjNit', 'tag_AjWan', 'Test150', 'Spilt',
#        '15AB_FPPred_3', 'Prob_FPPred_3', '15AB_pred', 'Prob_pred',
#        '15AB_FPAct_3', 'Prob_FPAct_3', '15AB_pred_', '15AB_FPPred_3_',
#        '15AB_FPAct_3_', 'Act_Predic_CCA', '15AB_pred_CCA', '15AB_FPAct_3_CCA',
#        'AI_Pred_CCA', 'AI_Pred_CCAAct_3'],
#       dtype='object')

# %%
a_ = dff['Sub_class_New'].tolist()
Act_Predic =[]
for  i in range(len(a_)):
    if a_[i] in Suspected_CCA:
        a = 'SuspectedCCA'
        Act_Predic.append(a)
    else:
        a = 'Non_SuspectedCCA'
        Act_Predic.append(a) 

dff['Act_Predic_CCA'] = Act_Predic

# %%
a_ = dff['15AB_pred'].tolist()
AI_Predic =[]
for  i in range(len(a_)):
    if a_[i] in Suspected_CCA:
        a = 'SuspectedCCA'
        AI_Predic.append(a)
    else:
        a = 'Non_SuspectedCCA'
        AI_Predic.append(a)
        
dff['15AB_pred_CCA'] = AI_Predic        

a_ = dff['15AB_FPAct_3'].tolist()
AI_Predic =[]
for  i in range(len(a_)):
    if a_[i] in Suspected_CCA:
        a = 'SuspectedCCA'
        AI_Predic.append(a)
    else:
        a = 'Non_SuspectedCCA'
        AI_Predic.append(a)
        
dff['15AB_FPAct_3_CCA'] = AI_Predic

# %%
dff.head()
# Out:
#    Unnamed: 0     Case Abs Position Sub Position     Class  \
# 0           0  AB01_40           P1           P1  Abnormal
# 1           1  AB01_40           P2           P2  Abnormal
# 2           2  AB01_40           P4          P41  Abnormal
# 3           3  AB01_40           P5          P51  Abnormal
# 4           4  AB01_40           P3          P31  Abnormal
#
#                                            Path Full  \
# 0  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 1  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 3  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 4  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
#
#                                            Path Crop Views  fold  \
# 0  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...  FP-A     2
# 1  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...  FP-A     2
# 2  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...  FP-B     2
# ...

# %%
a = dff['Act_Predic_CCA'].tolist()
b = dff['15AB_pred_CCA'].tolist()

res =[]
for  i in range(len(a)):
    if a[i] == b[i]:
        res.append('Correct')
    else:
        res.append('Incorrect')
dff['AI_Pred_CCA']  = res

a = dff['Act_Predic_CCA'].tolist()
b = dff['15AB_FPAct_3_CCA'].tolist()

res =[]
for  i in range(len(a)):
    if a[i] == b[i]:
        res.append('Correct')
    else:
        res.append('Incorrect')
dff['AI_Pred_CCAAct_3']  = res

# %%
#Recall
#รายรูป#BiTNeT
Correct = dff[dff['AI_Pred_CCA'] == 'Correct']
Incorrect = dff[dff['AI_Pred_CCA'] == 'Incorrect']
Incorrect[["Act_Predic_CCA","15AB_pred_CCA" ,"Unnamed: 0"]].groupby(['Act_Predic_CCA',"15AB_pred_CCA"]).count().reset_index()
# Out:
#      Act_Predic_CCA     15AB_pred_CCA  Unnamed: 0
# 0  Non_SuspectedCCA      SuspectedCCA           6
# 1      SuspectedCCA  Non_SuspectedCCA          52

# %%
#Recall
#รายรูป#BiTNeT+FP
Correct = dff[dff['AI_Pred_CCAAct_3'] == 'Correct']
Incorrect = dff[dff['AI_Pred_CCAAct_3'] == 'Incorrect']
Incorrect[["Act_Predic_CCA","15AB_FPAct_3_CCA" ,"Unnamed: 0"]].groupby(['Act_Predic_CCA',"15AB_FPAct_3_CCA"]).count().reset_index()
# Out:
#      Act_Predic_CCA  15AB_FPAct_3_CCA  Unnamed: 0
# 0  Non_SuspectedCCA      SuspectedCCA           6
# 1      SuspectedCCA  Non_SuspectedCCA          50

# %%
dff
# Out:
#       Unnamed: 0     Case Abs Position Sub Position     Class  \
# 0              0  AB01_40           P1           P1  Abnormal
# 1              1  AB01_40           P2           P2  Abnormal
# 2              2  AB01_40           P4          P41  Abnormal
# 3              3  AB01_40           P5          P51  Abnormal
# 4              4  AB01_40           P3          P31  Abnormal
# ...          ...      ...          ...          ...       ...
# 1307        1307      350           P3          P32    Normal
# 1308        1308      350           P4          P42    Normal
# 1309        1309      350           P5          P52    Normal
# 1310        1310      350           P6          P61    Normal
# 1311        1311      350           P8           P8    Normal
#
#                                               Path Full  \
# 0     /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 1     /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# ...

# %%
#Precision
#รายรูป#BiTNeT
dff[["15AB_pred_CCA", "AI_Pred_CCA", "Case"]].groupby(["15AB_pred_CCA", "AI_Pred_CCA"]).count().reset_index()
# Out:
#       15AB_pred_CCA AI_Pred_CCA  Case
# 0  Non_SuspectedCCA     Correct  1164
# 1  Non_SuspectedCCA   Incorrect    52
# 2      SuspectedCCA     Correct    90
# 3      SuspectedCCA   Incorrect     6

# %%
#Precision
#รายรูป#BiTNeT+FP
dff[["15AB_FPAct_3_CCA", "AI_Pred_CCAAct_3", "Case"]].groupby(["15AB_FPAct_3_CCA", "AI_Pred_CCAAct_3"]).count().reset_index()
# Out:
#    15AB_FPAct_3_CCA AI_Pred_CCAAct_3  Case
# 0  Non_SuspectedCCA          Correct  1164
# 1  Non_SuspectedCCA        Incorrect    50
# 2      SuspectedCCA          Correct    92
# 3      SuspectedCCA        Incorrect     6

# %%
dff.columns
# Out:
# Index(['Unnamed: 0', 'Case', 'Abs Position', 'Sub Position', 'Class',
#        'Path Full', 'Path Crop', 'Views', 'fold', '15AB', 'originalImage',
#        'left', 'top', 'width', 'height', 'Rleft', 'Rtop', 'Rwidth', 'Rheight',
#        'Sub_class_New', 'tag_AjNit', 'tag_AjWan', 'Test150', 'Spilt',
#        '15AB_FPPred_3', 'Prob_FPPred_3', '15AB_pred', 'Prob_pred',
#        '15AB_FPAct_3', 'Prob_FPAct_3', '15AB_pred_', '15AB_FPPred_3_',
#        '15AB_FPAct_3_', 'Act_Predic_CCA', '15AB_pred_CCA', '15AB_FPAct_3_CCA',
#        'AI_Pred_CCA', 'AI_Pred_CCAAct_3'],
#       dtype='object')

# %%
len(dff[dff['Act_Predic_CCA']=='SuspectedCCA'])
# Out:
# 142

# %%
len(dff[dff['Act_Predic_CCA']!='SuspectedCCA'])
# Out:
# 1170

# %%
col_name = ['Case', 'CCA_Case_Act', 'CCA_Case_AI','CCA_Case_AIAct_3']
dff2 = pd.DataFrame(columns = col_name)

case = list(set(dff['Case']))
result_pre = []
# set_case = []

for i in range(len(case)):
    a = dff[dff['Case'] ==case[i]]
    res_ = set(a['Act_Predic_CCA'])
    if len(res_) == 1:
        m = a['Act_Predic_CCA'].tolist()
        aa = m[0]
        result_pre.append(aa)
    elif res_ =={'Non_SuspectedCCA', 'SuspectedCCA'}:
        aa = 'SuspectedCCA'
        result_pre.append(aa)
dff2['CCA_Case_Act'] = result_pre
        
case = list(set(dff['Case']))
result_pre = []
for i in range(len(case)):
    a = dff[dff['Case'] ==case[i]]
    res_ = set(a['15AB_pred_CCA'])
    if len(res_) == 1:
        m = a['15AB_pred_CCA'].tolist()
        aa = m[0]
        result_pre.append(aa)
    elif res_ =={'Non_SuspectedCCA', 'SuspectedCCA'}:
        aa = 'SuspectedCCA'
        result_pre.append(aa)
dff2['CCA_Case_AI'] = result_pre
        
result_pre = []
for i in range(len(case)):
    a = dff[dff['Case'] ==case[i]]
    res_ = set(a['15AB_FPAct_3_CCA'])
    if len(res_) == 1:
        m = a['15AB_FPAct_3_CCA'].tolist()
        aa = m[0]
        result_pre.append(aa)
    elif res_ =={'Non_SuspectedCCA', 'SuspectedCCA'}:
        aa = 'SuspectedCCA'
        result_pre.append(aa)
dff2['CCA_Case_AIAct_3'] = result_pre
dff2['Case'] = case

# %%
dff2
# Out:
#          Case      CCA_Case_Act       CCA_Case_AI  CCA_Case_AIAct_3
# 0           1  Non_SuspectedCCA  Non_SuspectedCCA  Non_SuspectedCCA
# 1    AB081_65      SuspectedCCA      SuspectedCCA      SuspectedCCA
# 2     AB02_30  Non_SuspectedCCA  Non_SuspectedCCA  Non_SuspectedCCA
# 3      AB10_9  Non_SuspectedCCA  Non_SuspectedCCA  Non_SuspectedCCA
# 4     AB02_90  Non_SuspectedCCA  Non_SuspectedCCA  Non_SuspectedCCA
# ..        ...               ...               ...               ...
# 368   Ab3_136  Non_SuspectedCCA  Non_SuspectedCCA  Non_SuspectedCCA
# 369       150  Non_SuspectedCCA  Non_SuspectedCCA  Non_SuspectedCCA
# 370  AB09_101  Non_SuspectedCCA      SuspectedCCA      SuspectedCCA
# 371    AB05_2      SuspectedCCA  Non_SuspectedCCA  Non_SuspectedCCA
# 372       141  Non_SuspectedCCA  Non_SuspectedCCA  Non_SuspectedCCA
#
# [373 rows x 4 columns]

# %%
a = dff2['CCA_Case_Act'].tolist()
b = dff2['CCA_Case_AI'].tolist()

res =[]
for  i in range(len(a)):
    if a[i] == b[i]:
        res.append('Correct')
    else:
        res.append('Incorrect')
dff2['AI_Pred_CCA']  = res

a = dff2['CCA_Case_Act'].tolist()
b = dff2['CCA_Case_AIAct_3'].tolist()

res =[]
for  i in range(len(a)):
    if a[i] == b[i]:
        res.append('Correct')
    else:
        res.append('Incorrect')
dff2['AI_Pred_CCAAct_3']  = res

# %%
dff2
# Out:
#          Case      CCA_Case_Act       CCA_Case_AI  CCA_Case_AIAct_3  \
# 0           1  Non_SuspectedCCA  Non_SuspectedCCA  Non_SuspectedCCA
# 1    AB081_65      SuspectedCCA      SuspectedCCA      SuspectedCCA
# 2     AB02_30  Non_SuspectedCCA  Non_SuspectedCCA  Non_SuspectedCCA
# 3      AB10_9  Non_SuspectedCCA  Non_SuspectedCCA  Non_SuspectedCCA
# 4     AB02_90  Non_SuspectedCCA  Non_SuspectedCCA  Non_SuspectedCCA
# ..        ...               ...               ...               ...
# 368   Ab3_136  Non_SuspectedCCA  Non_SuspectedCCA  Non_SuspectedCCA
# 369       150  Non_SuspectedCCA  Non_SuspectedCCA  Non_SuspectedCCA
# 370  AB09_101  Non_SuspectedCCA      SuspectedCCA      SuspectedCCA
# 371    AB05_2      SuspectedCCA  Non_SuspectedCCA  Non_SuspectedCCA
# 372       141  Non_SuspectedCCA  Non_SuspectedCCA  Non_SuspectedCCA
#
#     AI_Pred_CCA AI_Pred_CCAAct_3
# 0       Correct          Correct
# 1       Correct          Correct
# 2       Correct          Correct
# ...

# %% [markdown]
# #### Recall

# %%
#BiTNeT
Correct = dff2[dff2['AI_Pred_CCA'] == 'Correct']
Incorrect = dff2[dff2['AI_Pred_CCA'] == 'Incorrect']
Incorrect[["CCA_Case_Act","CCA_Case_AI" ,"Case"]].groupby(['CCA_Case_Act',"CCA_Case_AI"]).count().reset_index()
# Out:
#        CCA_Case_Act       CCA_Case_AI  Case
# 0  Non_SuspectedCCA      SuspectedCCA     5
# 1      SuspectedCCA  Non_SuspectedCCA    35

# %%
#BiTNeT+FP
Correct = dff2[dff2['AI_Pred_CCAAct_3'] == 'Correct']
Incorrect = dff2[dff2['AI_Pred_CCAAct_3'] == 'Incorrect']
Incorrect[["CCA_Case_Act","CCA_Case_AIAct_3" ,"Case"]].groupby(['CCA_Case_Act',"CCA_Case_AIAct_3"]).count().reset_index()
# Out:
#        CCA_Case_Act  CCA_Case_AIAct_3  Case
# 0  Non_SuspectedCCA      SuspectedCCA     5
# 1      SuspectedCCA  Non_SuspectedCCA    33

# %% [markdown]
# #### Precision

# %%
#BiTNeT
dff2[["CCA_Case_AI", "AI_Pred_CCA", "Case"]].groupby(["CCA_Case_AI", "AI_Pred_CCA"]).count().reset_index()
# Out:
#         CCA_Case_AI AI_Pred_CCA  Case
# 0  Non_SuspectedCCA     Correct   254
# 1  Non_SuspectedCCA   Incorrect    35
# 2      SuspectedCCA     Correct    79
# 3      SuspectedCCA   Incorrect     5

# %%
#BiTNeT+FP
dff2[["CCA_Case_AI", "AI_Pred_CCAAct_3", "Case"]].groupby(["CCA_Case_AI", "AI_Pred_CCAAct_3"]).count().reset_index()
# Out:
#         CCA_Case_AI AI_Pred_CCAAct_3  Case
# 0  Non_SuspectedCCA          Correct   256
# 1  Non_SuspectedCCA        Incorrect    33
# 2      SuspectedCCA          Correct    79
# 3      SuspectedCCA        Incorrect     5

# %%
len(set(dff2[dff2['CCA_Case_Act'] == 'SuspectedCCA']['Case']))
# Out:
# 114

# %%
len(set(dff2[dff2['CCA_Case_Act'] != 'SuspectedCCA']['Case']))
# Out:
# 259

# %%
259+114
# Out:
# 373

# %% [markdown]
# ## Suspect , Non-Suspect and Normal

# %%
Suspected_CCA = ['AB05', 'AB06', 'AB07', 'AB081', 'AB082', 'AB083']

# %%
Normal = ['Normal']

# %%
dff = df

# %%
dff.columns
# Out:
# Index(['Unnamed: 0', 'Case', 'Abs Position', 'Sub Position', 'Class',
#        'Path Full', 'Path Crop', 'Views', 'fold', '15AB', 'originalImage',
#        'left', 'top', 'width', 'height', 'Rleft', 'Rtop', 'Rwidth', 'Rheight',
#        'Sub_class_New', 'tag_AjNit', 'tag_AjWan', 'Test150', 'Spilt',
#        '15AB_FPPred_3', 'Prob_FPPred_3', '15AB_pred', 'Prob_pred',
#        '15AB_FPAct_3', 'Prob_FPAct_3', '15AB_pred_', '15AB_FPPred_3_',
#        '15AB_FPAct_3_', 'Act_Predic_CCA', '15AB_pred_CCA', '15AB_FPAct_3_CCA',
#        'AI_Pred_CCA', 'AI_Pred_CCAAct_3'],
#       dtype='object')

# %%
a_ = dff['Sub_class_New'].tolist()
Act_Predic =[]
for  i in range(len(a_)):
    if a_[i] in Suspected_CCA:
        a = 'SuspectedCCA'
        Act_Predic.append(a)
    elif a_[i] in Normal:
        a = 'Normal'
        Act_Predic.append(a)
    else:
        a = 'Non_SuspectedCCA'
        Act_Predic.append(a) 

dff['Act_Predic_CCA'] = Act_Predic

# %%
a_ = dff['15AB_pred'].tolist()
AI_Predic =[]
for  i in range(len(a_)):
    if a_[i] in Suspected_CCA:
        a = 'SuspectedCCA'
        AI_Predic.append(a)
    elif a_[i] in Normal:
        a = 'Normal'
        AI_Predic.append(a)
    else:
        a = 'Non_SuspectedCCA'
        AI_Predic.append(a) 
        
dff['15AB_pred_CCA'] = AI_Predic        

a_ = dff['15AB_FPAct_3'].tolist()
AI_Predic =[]
for  i in range(len(a_)):
    if a_[i] in Suspected_CCA:
        a = 'SuspectedCCA'
        AI_Predic.append(a)
    elif a_[i] in Normal:
        a = 'Normal'
        AI_Predic.append(a)
    else:
        a = 'Non_SuspectedCCA'
        AI_Predic.append(a) 
        
dff['15AB_FPAct_3_CCA'] = AI_Predic

# %%
set(dff['15AB_FPAct_3_CCA'])
# Out:
# {'Non_SuspectedCCA', 'Normal', 'SuspectedCCA'}

# %%
dff.head()
# Out:
#    Unnamed: 0     Case Abs Position Sub Position     Class  \
# 0           0  AB01_40           P1           P1  Abnormal
# 1           1  AB01_40           P2           P2  Abnormal
# 2           2  AB01_40           P4          P41  Abnormal
# 3           3  AB01_40           P5          P51  Abnormal
# 4           4  AB01_40           P3          P31  Abnormal
#
#                                            Path Full  \
# 0  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 1  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 3  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 4  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
#
#                                            Path Crop Views  fold  \
# 0  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...  FP-A     2
# 1  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...  FP-A     2
# 2  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...  FP-B     2
# ...

# %%
a = dff['Act_Predic_CCA'].tolist()
b = dff['15AB_pred_CCA'].tolist()

res =[]
for  i in range(len(a)):
    if a[i] == b[i]:
        res.append('Correct')
    else:
        res.append('Incorrect')
dff['AI_Pred_CCA']  = res

a = dff['Act_Predic_CCA'].tolist()
b = dff['15AB_FPAct_3_CCA'].tolist()

res =[]
for  i in range(len(a)):
    if a[i] == b[i]:
        res.append('Correct')
    else:
        res.append('Incorrect')
dff['AI_Pred_CCAAct_3']  = res

# %%
dff.head()
# Out:
#    Unnamed: 0     Case Abs Position Sub Position     Class  \
# 0           0  AB01_40           P1           P1  Abnormal
# 1           1  AB01_40           P2           P2  Abnormal
# 2           2  AB01_40           P4          P41  Abnormal
# 3           3  AB01_40           P5          P51  Abnormal
# 4           4  AB01_40           P3          P31  Abnormal
#
#                                            Path Full  \
# 0  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 1  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 3  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 4  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
#
#                                            Path Crop Views  fold  \
# 0  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...  FP-A     2
# 1  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...  FP-A     2
# 2  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...  FP-B     2
# ...

# %%
#Recall
#รายรูป#BiTNeT
Correct = dff[dff['AI_Pred_CCA'] == 'Correct']
Incorrect = dff[dff['AI_Pred_CCA'] == 'Incorrect']
Incorrect[["Act_Predic_CCA","15AB_pred_CCA" ,"Case"]].groupby(['Act_Predic_CCA',"15AB_pred_CCA"]).count().reset_index()
# Out:
#      Act_Predic_CCA     15AB_pred_CCA  Case
# 0  Non_SuspectedCCA            Normal    46
# 1  Non_SuspectedCCA      SuspectedCCA     4
# 2            Normal  Non_SuspectedCCA     3
# 3            Normal      SuspectedCCA     2
# 4      SuspectedCCA  Non_SuspectedCCA     6
# 5      SuspectedCCA            Normal    46

# %%
#Recall
#รายรูป#BiTNeT+แบบที่3
Correct = dff[dff['AI_Pred_CCAAct_3'] == 'Correct']
Incorrect = dff[dff['AI_Pred_CCAAct_3'] == 'Incorrect']
Incorrect[["Act_Predic_CCA","15AB_FPAct_3_CCA" ,"Case"]].groupby(['Act_Predic_CCA',"15AB_FPAct_3_CCA"]).count().reset_index()
# Out:
#      Act_Predic_CCA  15AB_FPAct_3_CCA  Case
# 0  Non_SuspectedCCA            Normal    46
# 1  Non_SuspectedCCA      SuspectedCCA     4
# 2            Normal  Non_SuspectedCCA     2
# 3            Normal      SuspectedCCA     2
# 4      SuspectedCCA  Non_SuspectedCCA     4
# 5      SuspectedCCA            Normal    46

# %%
len(dff[dff['Act_Predic_CCA']=='SuspectedCCA'])
# Out:
# 142

# %%
len(dff[dff['Act_Predic_CCA']=='Non_SuspectedCCA'])
# Out:
# 313

# %%
len(dff[dff['Act_Predic_CCA']=='Normal'])
# Out:
# 857

# %%
dff
# Out:
#       Unnamed: 0     Case Abs Position Sub Position     Class  \
# 0              0  AB01_40           P1           P1  Abnormal
# 1              1  AB01_40           P2           P2  Abnormal
# 2              2  AB01_40           P4          P41  Abnormal
# 3              3  AB01_40           P5          P51  Abnormal
# 4              4  AB01_40           P3          P31  Abnormal
# ...          ...      ...          ...          ...       ...
# 1307        1307      350           P3          P32    Normal
# 1308        1308      350           P4          P42    Normal
# 1309        1309      350           P5          P52    Normal
# 1310        1310      350           P6          P61    Normal
# 1311        1311      350           P8           P8    Normal
#
#                                               Path Full  \
# 0     /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 1     /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# ...

# %%
#Precision
#รายรูป#BiTNeT
dff[["15AB_pred_CCA", "AI_Pred_CCA", "Case"]].groupby(["15AB_pred_CCA", "AI_Pred_CCA"]).count().reset_index()
# Out:
#       15AB_pred_CCA AI_Pred_CCA  Case
# 0  Non_SuspectedCCA     Correct   263
# 1  Non_SuspectedCCA   Incorrect     9
# 2            Normal     Correct   852
# 3            Normal   Incorrect    92
# 4      SuspectedCCA     Correct    90
# 5      SuspectedCCA   Incorrect     6

# %%
#Precision
#รายรูป#BiTNeT+แบบที่3
dff[["15AB_FPAct_3_CCA", "AI_Pred_CCAAct_3", "Case"]].groupby(["15AB_FPAct_3_CCA", "AI_Pred_CCAAct_3"]).count().reset_index()
# Out:
#    15AB_FPAct_3_CCA AI_Pred_CCAAct_3  Case
# 0  Non_SuspectedCCA          Correct   263
# 1  Non_SuspectedCCA        Incorrect     6
# 2            Normal          Correct   853
# 3            Normal        Incorrect    92
# 4      SuspectedCCA          Correct    92
# 5      SuspectedCCA        Incorrect     6

# %%
dff

# %%
col_name = ['Case', 'CCA_Case_Act', 'CCA_Case_AI','CCA_Case_AIAct_3']
dff2 = pd.DataFrame(columns = col_name)

case = list(set(dff['Case']))
result_pre = []
# set_case = []

for i in range(len(case)):
    a = dff[dff['Case'] ==case[i]]
    res_ = set(a['Act_Predic_CCA'])
    if len(res_) == 1:
        m = a['Act_Predic_CCA'].tolist()
        aa = m[0]
        result_pre.append(aa)
    elif  res_ =={'Non_SuspectedCCA', 'SuspectedCCA'}:
        aa = 'SuspectedCCA'
        result_pre.append(aa)
    elif  res_ =={'Normal', 'SuspectedCCA'}:
        aa = 'SuspectedCCA'
        result_pre.append(aa)
    elif  res_ =={'Non_SuspectedCCA', 'Normal'}:
        aa = 'Non_SuspectedCCA'
        result_pre.append(aa)
    elif res_ =={'Non_SuspectedCCA', 'Normal', 'SuspectedCCA'}:
        aa = 'SuspectedCCA'
        result_pre.append(aa)
        
dff2['CCA_Case_Act'] = result_pre

# %%
case = list(set(dff['Case']))
result_pre = []
for i in range(len(case)):
    a = dff[dff['Case'] ==case[i]]
    res_ = set(a['15AB_pred_CCA'])
#     result_pre.append(res_)
    if len(res_) == 1:
        m = a['15AB_pred_CCA'].tolist()
        aa = m[0]
        result_pre.append(aa)
    elif  res_ =={'Non_SuspectedCCA', 'SuspectedCCA'}:
        aa = 'SuspectedCCA'
        result_pre.append(aa)
    elif  res_ =={'Normal', 'SuspectedCCA'}:
        aa = 'SuspectedCCA'
        result_pre.append(aa)
    elif  res_ =={'Non_SuspectedCCA', 'Normal'}:
        aa = 'Non_SuspectedCCA'
        result_pre.append(aa)
    elif res_ =={'Non_SuspectedCCA', 'Normal', 'SuspectedCCA'}:
        aa = 'SuspectedCCA'
        result_pre.append(aa)
        
dff2['CCA_Case_AI'] = result_pre

# %%
result_pre = []
for i in range(len(case)):
    a = dff[dff['Case'] ==case[i]]
    res_ = set(a['15AB_FPAct_3_CCA'])
    if len(res_) == 1:
        m = a['15AB_FPAct_3_CCA'].tolist()
        aa = m[0]
        result_pre.append(aa)
    elif  res_ =={'Non_SuspectedCCA', 'SuspectedCCA'}:
        aa = 'SuspectedCCA'
        result_pre.append(aa)
    elif  res_ =={'Normal', 'SuspectedCCA'}:
        aa = 'SuspectedCCA'
        result_pre.append(aa)
    elif  res_ =={'Non_SuspectedCCA', 'Normal'}:
        aa = 'Non_SuspectedCCA'
        result_pre.append(aa)
    elif res_ =={'Non_SuspectedCCA', 'Normal', 'SuspectedCCA'}:
        aa = 'SuspectedCCA'
        result_pre.append(aa)
        
dff2['CCA_Case_AIAct_3'] = result_pre
dff2['Case'] = case

# %%
dff2
# Out:
#          Case      CCA_Case_Act       CCA_Case_AI  CCA_Case_AIAct_3
# 0           1            Normal            Normal            Normal
# 1    AB081_65      SuspectedCCA      SuspectedCCA      SuspectedCCA
# 2     AB02_30  Non_SuspectedCCA  Non_SuspectedCCA  Non_SuspectedCCA
# 3      AB10_9  Non_SuspectedCCA  Non_SuspectedCCA  Non_SuspectedCCA
# 4     AB02_90  Non_SuspectedCCA  Non_SuspectedCCA  Non_SuspectedCCA
# ..        ...               ...               ...               ...
# 368   Ab3_136  Non_SuspectedCCA  Non_SuspectedCCA  Non_SuspectedCCA
# 369       150            Normal            Normal            Normal
# 370  AB09_101  Non_SuspectedCCA      SuspectedCCA      SuspectedCCA
# 371    AB05_2      SuspectedCCA            Normal            Normal
# 372       141            Normal            Normal            Normal
#
# [373 rows x 4 columns]

# %%
a = dff2['CCA_Case_Act'].tolist()
b = dff2['CCA_Case_AI'].tolist()

res =[]
for  i in range(len(a)):
    if a[i] == b[i]:
        res.append('Correct')
    else:
        res.append('Incorrect')
dff2['AI_Pred_CCA']  = res

a = dff2['CCA_Case_Act'].tolist()
b = dff2['CCA_Case_AIAct_3'].tolist()

res =[]
for  i in range(len(a)):
    if a[i] == b[i]:
        res.append('Correct')
    else:
        res.append('Incorrect')
dff2['AI_Pred_CCAAct_3']  = res

# %% [markdown]
# #### Recall

# %%
#BiTNeT
Correct = dff2[dff2['AI_Pred_CCA'] == 'Correct']
Incorrect = dff2[dff2['AI_Pred_CCA'] == 'Incorrect']
Incorrect[["CCA_Case_Act","CCA_Case_AI" ,"Case"]].groupby(['CCA_Case_Act',"CCA_Case_AI"]).count().reset_index()
# Out:
#        CCA_Case_Act       CCA_Case_AI  Case
# 0  Non_SuspectedCCA            Normal    21
# 1  Non_SuspectedCCA      SuspectedCCA     3
# 2            Normal  Non_SuspectedCCA     2
# 3            Normal      SuspectedCCA     2
# 4      SuspectedCCA  Non_SuspectedCCA     6
# 5      SuspectedCCA            Normal    29

# %%
#BiTNeT+FP
Correct = dff2[dff2['AI_Pred_CCAAct_3'] == 'Correct']
Incorrect = dff2[dff2['AI_Pred_CCAAct_3'] == 'Incorrect']
Incorrect[["CCA_Case_Act","CCA_Case_AIAct_3" ,"Case"]].groupby(['CCA_Case_Act',"CCA_Case_AIAct_3"]).count().reset_index()
# Out:
#        CCA_Case_Act  CCA_Case_AIAct_3  Case
# 0  Non_SuspectedCCA            Normal    21
# 1  Non_SuspectedCCA      SuspectedCCA     3
# 2            Normal  Non_SuspectedCCA     1
# 3            Normal      SuspectedCCA     2
# 4      SuspectedCCA  Non_SuspectedCCA     4
# 5      SuspectedCCA            Normal    29

# %% [markdown]
# #### Precision

# %%
#BiTNeT
dff2[["CCA_Case_AI", "AI_Pred_CCA", "Case"]].groupby(["CCA_Case_AI", "AI_Pred_CCA"]).count().reset_index()
# Out:
#         CCA_Case_AI AI_Pred_CCA  Case
# 0  Non_SuspectedCCA     Correct   164
# 1  Non_SuspectedCCA   Incorrect     8
# 2            Normal     Correct    67
# 3            Normal   Incorrect    50
# 4      SuspectedCCA     Correct    79
# 5      SuspectedCCA   Incorrect     5

# %%
#BiTNeT+FP
dff2[["CCA_Case_AI", "AI_Pred_CCAAct_3", "Case"]].groupby(["CCA_Case_AI", "AI_Pred_CCAAct_3"]).count().reset_index()
# Out:
#         CCA_Case_AI AI_Pred_CCAAct_3  Case
# 0  Non_SuspectedCCA          Correct   167
# 1  Non_SuspectedCCA        Incorrect     5
# 2            Normal          Correct    67
# 3            Normal        Incorrect    50
# 4      SuspectedCCA          Correct    79
# 5      SuspectedCCA        Incorrect     5

# %%
len(set(dff2[dff2['CCA_Case_Act'] == 'SuspectedCCA']['Case']))
# Out:
# 114

# %%
len(set(dff2[dff2['CCA_Case_Act'] == 'Normal']['Case']))
# Out:
# 71

# %%
len(set(dff2[dff2['CCA_Case_Act'] == 'Non_SuspectedCCA']['Case']))
# Out:
# 188
