# %%
import os
import pandas as pd
import cv2

# %%
os.environ["CUDA_VISIBLE_DEVICES"]="0"

# %%
df = pd.read_csv (r'/home/yupaporn/CSV_file/Dataset_CCA_case_all6628.csv')
df
# Out:
#       Unnamed: 0     Case Abs Position Sub Position     Class  \
# 0              0  AB01_15           P3          P31  Abnormal
# 1              1  AB01_15           P1           P1  Abnormal
# 2              2  AB01_15           P2           P2  Abnormal
# 3              3  AB01_15           P4          P42  Abnormal
# 4              4  AB01_15           P4          P41  Abnormal
# ...          ...      ...          ...          ...       ...
# 6623          54  AB17_20          NaN          NaN  Abnormal
# 6624          55  AB17_09          NaN          NaN  Abnormal
# 6625          56  AB17_01          NaN          NaN  Abnormal
# 6626          57  AB17_07          NaN          NaN  Abnormal
# 6627          58  AB17_15          NaN          NaN  Abnormal
#
#                                               Path Full  \
# 0     /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 1     /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# ...

# %%
import requests
from azure.storage.blob import BlobServiceClient

connect_str="DefaultEndpointsProtocol=https;AccountName=fanpics;AccountKey=8XYaGSztvUqMKmsBQ9pG5lVu4Gf/eHvE4YbKvwzTbJORIieevaXzOBL6KZck4PDxD42iRzrbQTbi5B3jfXv0XQ==;EndpointSuffix=core.windows.net"
container_name="fan"

blob_service_client = BlobServiceClient.from_connection_string(connect_str)
# blob_client = blob_service_client.get_blob_client(container=container_name, blob=filen)

# %%
path = list(df['Path Full'])
# Spath = '/media/tohn/HDD/VISION_dataset/USAI/CCA_UI_corped_YOLOV2'
Spath ='/media/tohn/HDD/VISION_dataset/USAI/CCA_UI_Corped_YOLOV2'

# %%
# Opath = path[10]
# filen = Opath.split('/')[-1]

# %%
# path[0]

# %%
# for i in range

# %%
# blob_client = blob_service_client.get_blob_client(container=container_name, blob=filen)
# with open(os.path.join(Opath), "rb") as data:
#     blob_client.upload_blob(data,overwrite=True)
    
# path_images = filen
# pred = requests.post("http://20.198.218.137:5006/predictFanDetect", data={'path_images': path_images})
# result = pred.json()

# %%
# result['Confidence']

# %%
# Opath = path[i]
# filen = Opath.split('/')[-1]

# %%
# res_conf =[]

# %%
#     i = 0
#     Opath = path[0]
#     filen = str(i)+'_'+Opath.split('/')[-1]
#     filen

# %%
nodec, nodec_=[], []

# %%
for i in range(len(path)):

    Opath = path[i]
    filen = Opath.split('/')[-1]
    filen2 = str(i)+'_'+Opath.split('/')[-1]

    blob_client = blob_service_client.get_blob_client(container=container_name, blob=filen)
    with open(os.path.join(Opath), "rb") as data:
        blob_client.upload_blob(data,overwrite=True)
    try:  
        path_images = filen
        pred = requests.post("http://20.198.218.137:5006/predictFanDetect", data={'path_images': path_images})
        result = pred.json()
        
        im_res = cv2.imread(os.path.join(Opath))
        prediction = result['Confidence']
        # if prediction > 0.30:
        #     print('a')
        #     res.append({'prop':prediction ,'left':result['xmin'].left,'up':result['ymin'],'right':result['xmax'],'down':result['ymax']})
        res_conf =[]
        if prediction > 0.60: 
            conf = True
            print('True')
            res_conf.append({'prop':prediction ,'left':result['xmin'],'up':result['ymin'],'right':result['xmax'],'down':result['ymax']})
        try:   
            #use the most confidence box
            img_in_mem = im_res[int(im_res.shape[0]*res_conf[0]['up']):int(im_res.shape[0]*res_conf[0]['down']),int(im_res.shape[1]*res_conf[0]['left']):int(im_res.shape[1]*res_conf[0]['right'])]
            cv2.imwrite(os.path.join(Spath,filen2),img_in_mem)
        except:
            nodec.append(path[i])
            print(filen)
            print(prediction)
    except:
        nodec_.append(path[i])
        print(Opath)
        print(filen)
        


#     im_res = cv2.imread(os.path.join(Opath))
#     prediction = result['Confidence']
#     # if prediction > 0.30:
#     #     print('a')
#     #     res.append({'prop':prediction ,'left':result['xmin'].left,'up':result['ymin'],'right':result['xmax'],'down':result['ymax']})
#     res_conf =[]
#     if prediction > 0.60: 
#         conf = True
#         print('True')
#         res_conf.append({'prop':prediction ,'left':result['xmin'],'up':result['ymin'],'right':result['xmax'],'down':result['ymax']})
#     try:   
#         #use the most confidence box
#         img_in_mem = im_res[int(im_res.shape[0]*res_conf[0]['up']):int(im_res.shape[0]*res_conf[0]['down']),int(im_res.shape[1]*res_conf[0]['left']):int(im_res.shape[1]*res_conf[0]['right'])]
#         cv2.imwrite(os.path.join(Spath,filen),img_in_mem)
#     except:
#         print(filen)
#         print(prediction)
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# ...

# %%
print(len(nodec))
print(len(nodec_))
# Out:
# 1
# 2

# %%
if conf:
    #use the most confidence box
    img_in_mem = im_res[int(im_res.shape[0]*res_conf[0]['up']):int(im_res.shape[0]*res_conf[0]['down']),int(im_res.shape[1]*res_conf[0]['left']):int(im_res.shape[1]*res_conf[0]['right'])]
    cv2.imwrite(os.path.join(Spath,filen),img_in_mem)
else:
    #use the largest box that cover every box
    box = find_largest_box(res)
    img_in_mem = im_res[int(im_res.shape[0]*box['up']):int(im_res.shape[0]*box['down']),int(im_res.shape[1]*box['left']):int(im_res.shape[1]*box['right'])]
    cv2.imwrite(os.path.join(Spath,filen),img_in_mem)

# %%
try:
    if conf:
        #use the most confidence box
        img_in_mem = im_res[int(im_res.shape[0]*res_conf[0]['up']):int(im_res.shape[0]*res_conf[0]['down']),int(im_res.shape[1]*res_conf[0]['left']):int(im_res.shape[1]*res_conf[0]['right'])]
        cv2.imwrite(os.path.join(Spath,filen),img_in_mem)
    else:
        #use the largest box that cover every box
        box = find_largest_box(res)
        img_in_mem = im_res[int(im_res.shape[0]*box['up']):int(im_res.shape[0]*box['down']),int(im_res.shape[1]*box['left']):int(im_res.shape[1]*box['right'])]
        cv2.imwrite(os.path.join(Spath,filen),img_in_mem)
except:
    print(filen)
    print(prediction)

# %%
#Import library
from IPython.display import Image
Image(filename =os.path.join(Spath,filen), width = 600, height = 300)

# %% [markdown]
# # Checking images do not detected

# %%
print(len(nodec))
print(len(nodec_))
# Out:
# 1
# 2

# %%
nodec
# Out:
# ['/media/tohn/HDD/VISION_dataset/USAI/CCA_US_Dataset09122564/IntrahepaticDuctStones/Case03.JPG']

# %%
nodec_
# Out:
# ['/media/tohn/HDD/VISION_dataset/USAI/ABnormal01/8.2,8.3 ABNORMAL/8-3 ABNORMAL/AB083 P5-1 C017.JPG',
#  '/media/tohn/HDD/VISION_dataset/USAI/FPD JULY 2020/FPD P7/FP D P7 Case 018.JPG.png']

# %%
#Import library
from IPython.display import Image
Image(filename ='/media/tohn/HDD/VISION_dataset/USAI/CCA_US_Dataset09122564/IntrahepaticDuctStones/Case03.JPG', width = 600, height = 300)

# %%
df0[df0['Path Full'] == '/media/tohn/HDD/VISION_dataset/USAI/CCA_US_Dataset09122564/IntrahepaticDuctStones/Case03.JPG']
# Out:
#       Unnamed: 0     Case Abs Position Sub Position     Class  \
# 6601          32  AB16_03          NaN          NaN  Abnormal
#
#                                               Path Full  \
# 6601  /media/tohn/HDD/VISION_dataset/USAI/CCA_US_Dat...
#
#                                               Path Crop Views  fold  \
# 6601  /media/tohn/HDD/VISION_dataset/USAI/CCA_US_Dat...   NaN     3
#
#                         15AB  ... height Rleft Rtop Rwidth Rheight  \
# 6601  IntrahepaticDuctStones  ...    NaN   NaN  NaN    NaN     NaN
#
#      Sub_class_New tag_AjNit tag_AjWan Test150  Spilt
# 6601          AB16       NaN       NaN     NaN  Train
#
# [1 rows x 24 columns]

# %%
#ย้านไปที่ Folder เลย
# im_res = cv2.imread('/media/tohn/HDD/VISION_dataset/USAI/CCA_US_Dataset09122564/IntrahepaticDuctStones/Case03.JPG')

# filen2 = '6601_Case03.JPG'
# Spath = '/media/tohn/HDD/VISION_dataset/USAI/CCA_UI_Corped_YOLOV2'
# cv2.imwrite(os.path.join(Spath,filen2),im_res)
# Image(filename =os.path.join(Spath,filen2), width = 600, height = 300)

# %%
#Import library
from IPython.display import Image
Image(filename ='/media/tohn/HDD/VISION_dataset/USAI/CCA_US_Dataset09122564/IntrahepaticDuctStones/Case08.JPG', width = 600, height = 300)

# %%
df0[df0['Path Full'] == '/media/tohn/HDD/VISION_dataset/USAI/CCA_US_Dataset09122564/IntrahepaticDuctStones/Case08.JPG']
# Out:
#       Unnamed: 0     Case Abs Position Sub Position     Class  \
# 6628        6627  AB16_08          NaN          NaN  Abnormal
#
#                                               Path Full  \
# 6628  /media/tohn/HDD/VISION_dataset/USAI/CCA_US_Dat...
#
#                                               Path Crop Views  fold  \
# 6628  /media/tohn/HDD/VISION_dataset/USAI/CCA_US_Dat...   NaN     3
#
#                         15AB  ... height Rleft Rtop Rwidth Rheight  \
# 6628  IntrahepaticDuctStones  ...    NaN   NaN  NaN    NaN     NaN
#
#      Sub_class_New tag_AjNit tag_AjWan Test150  Spilt
# 6628          AB16       NaN       NaN     NaN  Train
#
# [1 rows x 24 columns]

# %%
#ย้านไปที่ Folder เลย
# im_res = cv2.imread('/media/tohn/HDD/VISION_dataset/USAI/CCA_US_Dataset09122564/IntrahepaticDuctStones/Case08.JPG')

# filen2 = '6628_Case08.JPG'
# Spath = '/media/tohn/HDD/VISION_dataset/USAI/CCA_UI_Corped_YOLOV2'
# cv2.imwrite(os.path.join(Spath,filen2),im_res)
# Image(filename =os.path.join(Spath,filen2), width = 600, height = 300)

# %%
# case08 ={'Unnamed: 0':6627,
#  'Case':'AB16_08',
#  'Abs Position':'NaN',
#  'Sub Position':'NaN',
#  'Class':'Abnormal',
#  'Path Full': '/media/tohn/HDD/VISION_dataset/USAI/CCA_US_Dataset09122564/IntrahepaticDuctStones/Case08.JPG',
#  'Path Crop':'/media/tohn/HDD/VISION_dataset/USAI/CCA_US_Dataset09122564/IntrahepaticDuctStones/Case08.JPG',
#  'Views':'NaN',
#  'fold':3,
#  '15AB':'IntrahepaticDuctStones',
#  'originalImage':'NaN',
#  'left':'NaN',
#  'top':'NaN',
#  'width':'NaN',
#  'height':'NaN',
#  'Rleft':'NaN',
#  'Rtop':'NaN',
#  'Rwidth':'NaN',
#  'Rheight':'NaN',
#  'Sub_class_New':'AB16',
#  'tag_AjNit':'NaN',
#  'tag_AjWan':'NaN',
#  'Test150':'NaN',
#  'Spilt':'Train'}

# %%
# df0 = df.append(case08, ignore_index=True)
# df0

# %%
# df0.to_csv(r'/home/yupaporn/CSV_file/Dataset_CCA_case_all6629.csv')

# %%
# df02 = df0[df0['Spilt'] == 'Train']
# df02

# %%
# df02.to_csv(r'/home/yupaporn/CSV_file/Train_Dataset_CCA_5301.csv')

# %%
df0[df0['Path Full'] == '/media/tohn/HDD/VISION_dataset/USAI/ABnormal01/8.2,8.3 ABNORMAL/8-3 ABNORMAL/AB083 P5-1 C017.JPG']
# Out:
#      Unnamed: 0      Case Abs Position Sub Position     Class  \
# 408         408  AB083_17           P5          P51  Abnormal
#
#                                              Path Full  \
# 408  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
#
#                                              Path Crop Views  fold  \
# 408  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...  FP-C     7
#
#                 15AB  ... height     Rleft      Rtop    Rwidth   Rheight  \
# 408  LivermassAndBDD  ...    595  0.210425  0.107041  0.646718  0.661355
#
#     Sub_class_New tag_AjNit tag_AjWan Test150  Spilt
# 408         AB083       NaN       NaN   False  Train
#
# [1 rows x 24 columns]

# %% [markdown]
# # Detect อีกรอบ

# %%
path = ['/media/tohn/HDD/VISION_dataset/USAI/ABnormal01/8.2,8.3 ABNORMAL/8-3 ABNORMAL/AB083 P5-1 C017.JPG',
 '/media/tohn/HDD/VISION_dataset/USAI/FPD JULY 2020/FPD P7/FP D P7 Case 018.JPG.png']

# %%
nodec, nodec_ = [], []

# %%
for i in range(len(path)):

    Opath = path[i]
    filen = Opath.split('/')[-1]
    filen2 = str(i)+'_'+Opath.split('/')[-1]

    blob_client = blob_service_client.get_blob_client(container=container_name, blob=filen)
    with open(os.path.join(Opath), "rb") as data:
        blob_client.upload_blob(data,overwrite=True)
    try:  
        path_images = filen
        pred = requests.post("http://20.198.218.137:5006/predictFanDetect", data={'path_images': path_images})
        result = pred.json()
        
        im_res = cv2.imread(os.path.join(Opath))
        prediction = result['Confidence']
        # if prediction > 0.30:
        #     print('a')
        #     res.append({'prop':prediction ,'left':result['xmin'].left,'up':result['ymin'],'right':result['xmax'],'down':result['ymax']})
        res_conf =[]
        if prediction > 0.60: 
            conf = True
            print('True')
            res_conf.append({'prop':prediction ,'left':result['xmin'],'up':result['ymin'],'right':result['xmax'],'down':result['ymax']})
        try:   
            #use the most confidence box
            img_in_mem = im_res[int(im_res.shape[0]*res_conf[0]['up']):int(im_res.shape[0]*res_conf[0]['down']),int(im_res.shape[1]*res_conf[0]['left']):int(im_res.shape[1]*res_conf[0]['right'])]
            cv2.imwrite(os.path.join(Spath,filen2),img_in_mem)
        except:
            nodec.append(path[i])
            print(filen)
            print(prediction)
    except:
        nodec_.append(path[i])
        print(Opath)
        print(filen)
# Out:
# /media/tohn/HDD/VISION_dataset/USAI/ABnormal01/8.2,8.3 ABNORMAL/8-3 ABNORMAL/AB083 P5-1 C017.JPG
# AB083 P5-1 C017.JPG
# /media/tohn/HDD/VISION_dataset/USAI/FPD JULY 2020/FPD P7/FP D P7 Case 018.JPG.png
# FP D P7 Case 018.JPG.png

# %%
i=0
Opath = path[i]
filen = Opath.split('/')[-1]
filen2 = str(i)+'_'+Opath.split('/')[-1]

blob_client = blob_service_client.get_blob_client(container=container_name, blob=filen)
with open(os.path.join(Opath), "rb") as data:
    blob_client.upload_blob(data,overwrite=True)
    
path_images = filen
pred = requests.post("http://20.198.218.137:5006/predictFanDetect", data={'path_images': path_images})
result = pred.json()

im_res = cv2.imread(os.path.join(Opath))
prediction = result['Confidence']
# if prediction > 0.30:
#     print('a')
#     res.append({'prop':prediction ,'left':result['xmin'].left,'up':result['ymin'],'right':result['xmax'],'down':result['ymax']})
res_conf =[]
if prediction > 0.60: 
    conf = True
    print('True')
    res_conf.append({'prop':prediction ,'left':result['xmin'],'up':result['ymin'],'right':result['xmax'],'down':result['ymax']})
try:   
    #use the most confidence box
    img_in_mem = im_res[int(im_res.shape[0]*res_conf[0]['up']):int(im_res.shape[0]*res_conf[0]['down']),int(im_res.shape[1]*res_conf[0]['left']):int(im_res.shape[1]*res_conf[0]['right'])]
    cv2.imwrite(os.path.join(Spath,filen2),img_in_mem)
except:
    nodec.append(path[i])
    print(filen)
    print(prediction)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-21-2c291ffd45c1> in <module>
#      10 path_images = filen
#      11 pred = requests.post("http://20.198.218.137:5006/predictFanDetect", data={'path_images': path_images})
# ---> 12 result = pred.json()
#      13
#      14 im_res = cv2.imread(os.path.join(Opath))
#
# ~/miniconda3/envs/USAI3/lib/python3.6/site-packages/requests/models.py in json(self, **kwargs)
#     898                     # used.
#     899                     pass
# --> 900         return complexjson.loads(self.text, **kwargs)
#     901
#     902     @property
#
# ~/miniconda3/envs/USAI3/lib/python3.6/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     352             parse_int is None and parse_float is None and
# ...

# %%
0.75*0.75*0.75*0.75*0.75*0.75
# Out:
# 0.177978515625

# %%
0.140625/(1-0.177978515625)
# Out:
# 0.17107217107217107

# %%
(1-0.177978515625)
# Out:
# 0.822021484375

# %%
#Import library
from IPython.display import Image
Image(filename ='/media/tohn/HDD/VISION_dataset/USAI/ABnormal01/8.2,8.3 ABNORMAL/8-3 ABNORMAL/AB083 P5-1 C017.JPG', width = 600, height = 300)

# %%
df0[df0['Path Full'] == '/media/tohn/HDD/VISION_dataset/USAI/FPD JULY 2020/FPD P7/FP D P7 Case 018.JPG.png']
# Out:
#       Unnamed: 0      Case Abs Position Sub Position     Class  \
# 1981        1981  AB12_176           P7          P71  Abnormal
#
#                                               Path Full  \
# 1981  /media/tohn/HDD/VISION_dataset/USAI/FPD JULY 2...
#
#                                               Path Crop Views  fold  \
# 1981  /media/tohn/HDD/VISION_dataset/USAI/FPD JULY 2...  FP-D     5
#
#               15AB  ... height      Rleft      Rtop    Rwidth   Rheight  \
# 1981  Splenomegaly  ...    519  0.0728972  0.130945  0.637383  0.577689
#
#      Sub_class_New tag_AjNit tag_AjWan Test150  Spilt
# 1981          AB12       NaN       NaN   False  Train
#
# [1 rows x 24 columns]

# %%
#Import library
from IPython.display import Image
Image(filename = '/media/tohn/HDD/VISION_dataset/USAI/FPD JULY 2020/FPD P7/FP D P7 Case 018.JPG.png', width = 600, height = 300)

# %%
import pandas as pd

df = pd.read_csv (r'/home/yupaporn/CSV_file/Dataset_CCA_case_all6628.csv')
df

# %%
path = list(df['Path Full'])
len(path)

# %%
len(set(path))#หายไปสอง

# %%
path = list(df['Path Full'])
filen_ = []
for i in range(len(path)):
    filen = path[i].split('/')[-1]
    filen_.append(filen)

# %%
import glob
import os
import numpy as np

# %%
Spath = '/media/tohn/HDD/VISION_dataset/USAI/CCA_UI_corped_YOLOV2'
os.chdir(Spath)

# %%
a = glob.glob('*')
print(len(a))

# %%
len(a)

# %%
len(set(a))

# %%
len(filen_)

# %%
len(set(filen_) )

# %%
set(a) - set(filen_)

# %%
no_detect = list(set(filen_) - set(a))
no_detect

# %%
path = list(df['Path Full'])
filen_ = []
nodetect_path =[]
for i in range(len(path)):
    filen = path[i].split('/')[-1]
    if filen in no_detect :
        print(path[i])
        nodetect_path.append(path[i])

# %%
nodetect_path

# %%
df[df['Path Full'] =='/media/tohn/HDD/VISION_dataset/USAI/ABnormal01/8.2,8.3 ABNORMAL/8-3 ABNORMAL/AB083 P5-1 C017.JPG']

# %%
df[df['Path Full'] =='/media/tohn/HDD/VISION_dataset/USAI/FPD JULY 2020/FPD P7/FP D P7 Case 018.JPG.png']
