# %%
import pandas as pd
exp= pd.read_csv( '/home/yupaporn/codes/USAI/testset_random2.csv')
exp
# Out:
#      num            FileName  \
# 0     15  AB05 P5-1 C058.JPG
# 1     99     P6.Case 327.JPG
# 2     76   P4-2.Case 251.JPG
# 3     17    AB06 P2 C054.JPG
# 4    132     P8.Case 296.JPG
# ..   ...                 ...
# 145  134     P8.Case 310.JPG
# 146  138          P8C068.jpg
# 147   73   P4-1.Case 329.JPG
# 148  141          P8C140.jpg
# 149   38   AB081 P1 C067.JPG
#
#                                               img_path  \
# 0    /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 1    /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 2    /media/tohn/HDD/VISION_dataset/USAI/USimages20...
# 3    /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 4    /media/tohn/HDD/VISION_dataset/USAI/USimages20...
# ..                                                 ...
# 145  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 146  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 147  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# ...

# %%
import pandas as pd
df = pd.read_csv( '/home/yupaporn/codes/USAI/ExperimentNew3.csv')
df
# Out:
#      Unnamed: 0  num            FileName sub_class views  \
# 0             0    1    AB01 P1 C100.JPG      AB01  FP-A
# 1             1    2  AB01 P4-2 C050.JPG      AB01  FP-B
# 2             2    3  AB01 P5-2 C004.JPG      AB01  FP-C
# 3             3    4    AB02 P1 C001.JPG      AB02  FP-A
# 4             4    5  AB02 P3-1 C001.JPG      AB02  FP-B
# ..          ...  ...                 ...       ...   ...
# 145         145  146          P8C193.jpg    Normal  FP-E
# 146         146  147     P8_Case_007.jpg    Normal  FP-E
# 147         147  148     P8_Case_025.jpg    Normal  FP-E
# 148         148  149     P8_Case_029.jpg    Normal  FP-E
# 149         149  150     P8_Case_032.jpg    Normal  FP-E
#
#                                              Path Crop  \
# 0    /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 1    /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2    /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# ...

# %%
exp0 =exp[['num','U10_Pred2','U11_Pred2','U30_Pred2','U41_Pred2','U31_Pred2','U40_Pred2','U20_Pred2','U21_Pred2']]

# %%
U10 = exp0['U10_Pred2'].tolist()
Table = list()
for j in U10 :
    A = j.replace(' ','')
    a = A.split(':')
    Num = a[0]
    Table.append({'U10_Pred2':Num})
    
U11 = exp0['U11_Pred2'].tolist()
Table1 = list()
for j in U11 :
    A = j.replace(' ','')
    a = A.split(':')
    Num = a[0]
    Table1.append({'U11_Pred2':Num})
    
Table_1 = pd.DataFrame(Table)
Table_2 = pd.DataFrame(Table1)
exp0['U10_Pred2'] = Table_1
exp0['U11_Pred2'] = Table_2
# Out:
# /home/yupaporn/.local/lib/python3.6/site-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/yupaporn/.local/lib/python3.6/site-packages/ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
U10 = exp0['U30_Pred2'].tolist()
Table = list()
for j in U10 :
    A = j.replace(' ','')
    a = A.split(':')
    Num = a[0]
    Table.append({'U30_Pred2':Num})
    
U11 = exp0['U41_Pred2'].tolist()
Table1 = list()
for j in U11 :
    A = j.replace(' ','')
    a = A.split(':')
    Num = a[0]
    Table1.append({'U41_Pred2':Num})
    
Table_1 = pd.DataFrame(Table)
Table_2 = pd.DataFrame(Table1)
exp0['U30_Pred2'] = Table_1
exp0['U41_Pred2'] = Table_2
# Out:
# /home/yupaporn/.local/lib/python3.6/site-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/yupaporn/.local/lib/python3.6/site-packages/ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
U10 = exp0['U31_Pred2'].tolist()
Table = list()
for j in U10 :
    A = j.replace(' ','')
    a = A.split(':')
    Num = a[0]
    Table.append({'U31_Pred2':Num})
    
U11 = exp0['U40_Pred2'].tolist()
Table1 = list()
for j in U11 :
    A = j.replace(' ','')
    a = A.split(':')
    Num = a[0]
    Table1.append({'U40_Pred2':Num})
    
Table_1 = pd.DataFrame(Table)
Table_2 = pd.DataFrame(Table1)
exp0['U31_Pred2'] = Table_1
exp0['U40_Pred2'] = Table_2
# Out:
# /home/yupaporn/.local/lib/python3.6/site-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/yupaporn/.local/lib/python3.6/site-packages/ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
U10 = exp0['U31_Pred2'].tolist()
Table = list()
for j in U10 :
    A = j.replace(' ','')
    a = A.split(':')
    Num = a[0]
    Table.append({'U31_Pred2':Num})
    
U11 = exp0['U40_Pred2'].tolist()
Table1 = list()
for j in U11 :
    A = j.replace(' ','')
    a = A.split(':')
    Num = a[0]
    Table1.append({'U40_Pred2':Num})
    
Table_1 = pd.DataFrame(Table)
Table_2 = pd.DataFrame(Table1)
exp0['U31_Pred2'] = Table_1
exp0['U40_Pred2'] = Table_2
# Out:
# /home/yupaporn/.local/lib/python3.6/site-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/yupaporn/.local/lib/python3.6/site-packages/ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
U10 = exp0['U20_Pred2'].tolist()
Table = list()
for j in U10 :
    A = j.replace(' ','')
    a = A.split(':')
    Num = a[0]
    Table.append({'U20_Pred2':Num})
    
U11 = exp0['U21_Pred2'].tolist()
Table1 = list()
for j in U11 :
    A = j.replace(' ','')
    a = A.split(':')
    Num = a[0]
    Table1.append({'U21_Pred2':Num})
    
Table_1 = pd.DataFrame(Table)
Table_2 = pd.DataFrame(Table1)
exp0['U20_Pred2'] = Table_1
exp0['U21_Pred2'] = Table_2
# Out:
# /home/yupaporn/.local/lib/python3.6/site-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/yupaporn/.local/lib/python3.6/site-packages/ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
result = pd.merge(df, exp0, how='left', on=['num'])
result
# Out:
#      Unnamed: 0  num            FileName sub_class views  \
# 0             0    1    AB01 P1 C100.JPG      AB01  FP-A
# 1             1    2  AB01 P4-2 C050.JPG      AB01  FP-B
# 2             2    3  AB01 P5-2 C004.JPG      AB01  FP-C
# 3             3    4    AB02 P1 C001.JPG      AB02  FP-A
# 4             4    5  AB02 P3-1 C001.JPG      AB02  FP-B
# ..          ...  ...                 ...       ...   ...
# 145         145  146          P8C193.jpg    Normal  FP-E
# 146         146  147     P8_Case_007.jpg    Normal  FP-E
# 147         147  148     P8_Case_025.jpg    Normal  FP-E
# 148         148  149     P8_Case_029.jpg    Normal  FP-E
# 149         149  150     P8_Case_032.jpg    Normal  FP-E
#
#                                              Path Crop  \
# 0    /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 1    /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2    /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# ...

# %%
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 150 entries, 0 to 149
# Data columns (total 39 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     150 non-null    int64
#  1   num            150 non-null    int64
#  2   FileName       150 non-null    object
#  3   sub_class      150 non-null    object
#  4   views          150 non-null    object
#  5   Path Crop      150 non-null    object
#  6   originalImage  150 non-null    object
#  7   tagName1       150 non-null    object
#  8   tagName2       150 non-null    object
#  9   Class          150 non-null    object
#  10  Case           150 non-null    int64
#  11  Abs Position   150 non-null    object
#  12  Sub_class      150 non-null    object
#  13  Path Full      150 non-null    object
#  14  fold           150 non-null    int64
#  15  AI_Pred        150 non-null    object
#  16  U10_Pred       150 non-null    object
# ...

# %%
import os
os.chdir( '/home/yupaporn/codes/USAI/')
result.to_csv('Experiment2.csv')

# %% [markdown]
# # performance คุณหมอ

# %%
import numpy as np
from sklearn.metrics import confusion_matrix
act = result['category'].array
pred = result['U10_Pred2'].array

cmat = confusion_matrix(act, pred)
print('classifier accuracy = {}%'.format((100.*np.trace(cmat))/(np.sum(cmat))))

#Marking the Confusion Matrix
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(act, pred))#performance
# Out:
# classifier accuracy = 64.0%
#               precision    recall  f1-score   support
#
#         AB01       0.29      1.00      0.44         2
#         AB02       0.23      0.60      0.33         5
#         AB03       0.25      0.50      0.33         2
#         AB04       0.50      0.50      0.50         4
#         AB05       0.00      0.00      0.00         3
#         AB06       0.50      1.00      0.67         1
#        AB081       0.50      0.40      0.44         5
#        AB082       0.80      1.00      0.89         4
#        AB083       0.00      0.00      0.00         1
#         AB09       1.00      0.67      0.80         3
#         AB10       0.20      0.50      0.29         2
#         AB11       0.00      0.00      0.00         1
#         AB12       0.00      0.00      0.00         4
#       Normal       0.93      0.69      0.79       113
#
#     accuracy                           0.64       150
#    macro avg       0.37      0.49      0.39       150
# ...

# %%
act= result['category'].map({'AB12':1, 'AB04':1, 'AB05':1, 'Normal':0, 'AB02':1, 'AB11':1, 'AB082':1, 'AB06':1,'AB07':1, 'AB081':1, 'AB09':1, 'AB03':1, 'AB10':1, 'AB01':1, 'AB083':1}).values
pred = result['U10_Pred2'].map({'AB12':1, 'AB04':1, 'AB05':1, 'Normal':0, 'AB02':1, 'AB11':1, 'AB082':1, 'AB06':1,'AB07':1, 'AB081':1, 'AB09':1, 'AB03':1, 'AB10':1, 'AB01':1, 'AB083':1}).values
cmat = confusion_matrix(act, pred)
print('classifier accuracy = {}%'.format((100.*np.trace(cmat))/(np.sum(cmat))))

#Marking the Confusion Matrix
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(act, pred))#performance
# Out:
# classifier accuracy = 72.66666666666667%
#               precision    recall  f1-score   support
#
#            0       0.93      0.69      0.79       113
#            1       0.47      0.84      0.60        37
#
#     accuracy                           0.73       150
#    macro avg       0.70      0.76      0.70       150
# weighted avg       0.82      0.73      0.75       150

# %% [markdown]
# # U10ass.

# %%
import numpy as np
from sklearn.metrics import confusion_matrix
act = result['Sub_class_New'].array
pred = result['U10_Pred2'].array

cmat = confusion_matrix(act, pred)
print('classifier accuracy = {}%'.format((100.*np.trace(cmat))/(np.sum(cmat))))

#Marking the Confusion Matrix
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(act, pred))#performance
# Out:
# classifier accuracy = 63.333333333333336%
#               precision    recall  f1-score   support
#
#         AB01       0.14      0.33      0.20         3
#         AB02       0.08      0.33      0.12         3
#         AB03       0.25      0.33      0.29         3
#         AB04       0.50      0.67      0.57         3
#         AB05       0.20      0.33      0.25         3
#         AB06       0.50      0.33      0.40         3
#         AB07       0.00      0.00      0.00         3
#        AB081       0.75      1.00      0.86         3
#        AB082       0.20      0.33      0.25         3
#        AB083       0.00      0.00      0.00         3
#         AB09       1.00      0.67      0.80         3
#         AB10       0.40      0.67      0.50         3
#         AB11       0.25      0.67      0.36         3
#         AB12       0.14      0.33      0.20         3
#       Normal       0.92      0.71      0.80       108
#
#     accuracy                           0.63       150
# ...

# %%
#create CF 
data = {'Actual': act,'Predicted' : pred,}
df = pd.DataFrame(data, columns=['Actual','Predicted'])
conf_mat = pd.crosstab(df['Actual'],df['Predicted'],rownames=['Actual'],colnames=['Predicted'])

#Confusion matrix
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
cm = confusion_matrix(act, pred)

#plot Confusion matrix
import seaborn as sns
sns.set()
fig, ax = plt.subplots(figsize=(8, 5))

ax = sns.heatmap(conf_mat, annot=True, fmt="d", cmap="YlGnBu") #Blues,Oranges,Reds
ax.set_title('Confusion matrix',fontsize=20)
ax.set_ylabel('AI label',fontsize=18)
ax.set_xlabel('U11 label',fontsize=18)
# Out:
# Text(0.5, 21.5, 'U11 label')

# %%
act= result['Class'].map({'Normal':0,'Abnormal':1}).values
pred = result['U10_Pred2'].map({'AB12':1, 'AB04':1, 'AB05':1, 'Normal':0, 'AB02':1, 'AB11':1, 'AB082':1, 'AB06':1, 'AB081':1, 'AB09':1, 'AB03':1, 'AB10':1, 'AB01':1, 'AB083':1}).values
cmat = confusion_matrix(act, pred)
print('classifier accuracy = {}%'.format((100.*np.trace(cmat))/(np.sum(cmat))))

#Marking the Confusion Matrix
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(act, pred))#performance
# Out:
# classifier accuracy = 74.66666666666667%
#               precision    recall  f1-score   support
#
#            0       0.92      0.71      0.80       108
#            1       0.53      0.83      0.65        42
#
#     accuracy                           0.75       150
#    macro avg       0.72      0.77      0.73       150
# weighted avg       0.81      0.75      0.76       150

# %%
#create CF 
data = {'Actual': act,'Predicted' : pred,}
df = pd.DataFrame(data, columns=['Actual','Predicted'])
conf_mat = pd.crosstab(df['Actual'],df['Predicted'],rownames=['Actual'],colnames=['Predicted'])

#Confusion matrix
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
cm = confusion_matrix(act, pred)
TN, FP, FN, TP = confusion_matrix(act, pred).ravel()
print(TN, FP, FN, TP)

#plot Confusion matrix
import seaborn as sns
sns.set()
fig, ax = plt.subplots(figsize=(8, 5))
ax = sns.heatmap(conf_mat, annot=True, fmt="d", cmap="YlGnBu") #Blues,Oranges,Reds
ax.set_title('Confusion matrix',fontsize=20)
ax.set_ylabel('True label',fontsize=18)
ax.set_xlabel('Predicted label',fontsize=18)
# Out:
# 77 31 7 35
# Text(0.5, 21.5, 'Predicted label')

# %% [markdown]
# # U11

# %%
import numpy as np
from sklearn.metrics import confusion_matrix
act = result['Sub_class_New'].array
pred = result['U11_Pred2'].array

cmat = confusion_matrix(act, pred)
print('classifier accuracy = {}%'.format((100.*np.trace(cmat))/(np.sum(cmat))))

#Marking the Confusion Matrix
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(act, pred))#performance
# Out:
# classifier accuracy = 69.33333333333333%
#               precision    recall  f1-score   support
#
#         AB01       0.25      0.33      0.29         3
#         AB02       0.17      0.33      0.22         3
#         AB03       0.67      0.67      0.67         3
#         AB04       0.33      0.33      0.33         3
#         AB05       0.10      0.33      0.15         3
#         AB06       0.00      0.00      0.00         3
#         AB07       0.00      0.00      0.00         3
#        AB081       0.40      0.67      0.50         3
#        AB082       0.20      0.33      0.25         3
#        AB083       0.20      0.33      0.25         3
#         AB09       0.75      1.00      0.86         3
#         AB10       0.75      1.00      0.86         3
#         AB11       0.60      1.00      0.75         3
#         AB12       0.00      0.00      0.00         3
#       Normal       0.91      0.79      0.85       108
#
#     accuracy                           0.69       150
# ...

# %%
#create CF 
data = {'Actual': act,'Predicted' : pred,}
df = pd.DataFrame(data, columns=['Actual','Predicted'])
conf_mat = pd.crosstab(df['Actual'],df['Predicted'],rownames=['Actual'],colnames=['Predicted'])

#Confusion matrix
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
cm = confusion_matrix(act, pred)

#plot Confusion matrix
import seaborn as sns
sns.set()
fig, ax = plt.subplots(figsize=(8, 5))

ax = sns.heatmap(conf_mat, annot=True, fmt="d", cmap="YlGnBu") #Blues,Oranges,Reds
ax.set_title('Confusion matrix',fontsize=20)
ax.set_ylabel('AI label',fontsize=18)
ax.set_xlabel('U11 label',fontsize=18)
# Out:
# Text(0.5, 21.5, 'U11 label')

# %%
act= result['Class'].map({'Normal':0,'Abnormal':1}).values
pred = result['U31_Pred'].map({'AB12':1, 'AB04':1, 'AB05':1, 'Normal':0, 'AB02':1, 'AB11':1, 'AB082':1, 'AB06':1,'AB07':1, 'AB081':1, 'AB09':1, 'AB03':1, 'AB10':1, 'AB01':1, 'AB083':1}).values
cmat = confusion_matrix(act, pred)
print('classifier accuracy = {}%'.format((100.*np.trace(cmat))/(np.sum(cmat))))

#Marking the Confusion Matrix
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(act, pred))#performance
# Out:
# classifier accuracy = 85.33333333333333%
#               precision    recall  f1-score   support
#
#            0       1.00      0.80      0.89       108
#            1       0.66      1.00      0.79        42
#
#     accuracy                           0.85       150
#    macro avg       0.83      0.90      0.84       150
# weighted avg       0.90      0.85      0.86       150

# %%
#create CF 
data = {'Actual': act,'Predicted' : pred,}
df = pd.DataFrame(data, columns=['Actual','Predicted'])
conf_mat = pd.crosstab(df['Actual'],df['Predicted'],rownames=['Actual'],colnames=['Predicted'])

#Confusion matrix
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
cm = confusion_matrix(act, pred)
TN, FP, FN, TP = confusion_matrix(act, pred).ravel()
print(TN, FP, FN, TP)

#plot Confusion matrix
import seaborn as sns
sns.set()
fig, ax = plt.subplots(figsize=(8, 5))
ax = sns.heatmap(conf_mat, annot=True, fmt="d", cmap="YlGnBu") #Blues,Oranges,Reds
ax.set_title('Confusion matrix',fontsize=20)
ax.set_ylabel('True label',fontsize=18)
ax.set_xlabel('Predicted label',fontsize=18)
# Out:
# 86 22 0 42
# Text(0.5, 21.5, 'Predicted label')

# %% [markdown]
# # U30

# %%
import numpy as np
from sklearn.metrics import confusion_matrix
act = result['Sub_class_New'].array
pred = result['U30_Pred2'].array

cmat = confusion_matrix(act, pred)
print('classifier accuracy = {}%'.format((100.*np.trace(cmat))/(np.sum(cmat))))

#Marking the Confusion Matrix
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(act, pred))#performance
# Out:
# classifier accuracy = 82.66666666666667%
#               precision    recall  f1-score   support
#
#         AB01       0.17      0.33      0.22         3
#         AB02       0.25      0.33      0.29         3
#         AB03       0.60      1.00      0.75         3
#         AB04       1.00      1.00      1.00         3
#         AB05       1.00      1.00      1.00         3
#         AB06       1.00      0.67      0.80         3
#         AB07       0.00      0.00      0.00         3
#        AB081       0.75      1.00      0.86         3
#        AB082       0.33      0.33      0.33         3
#        AB083       0.67      0.67      0.67         3
#         AB09       1.00      1.00      1.00         3
#         AB10       0.67      0.67      0.67         3
#         AB11       0.67      0.67      0.67         3
#         AB12       0.33      0.33      0.33         3
#       Normal       0.93      0.90      0.92       108
#
#     accuracy                           0.83       150
# ...

# %%
act = result['Sub_class_New'].map({'AB12':1, 'AB04':1, 'AB05':1, 'Normal':0, 'AB02':1, 'AB11':1, 'AB082':1, 'AB06':1,'AB07':1, 'AB081':1, 'AB09':1, 'AB03':1, 'AB10':1, 'AB01':1, 'AB083':1}).values
pred = result['U30_Pred2'].map({'AB12':1, 'AB04':1, 'AB05':1, 'Normal':0, 'AB02':1, 'AB11':1, 'AB082':1, 'AB06':1,'AB07':1, 'AB081':1, 'AB09':1, 'AB03':1, 'AB10':1, 'AB01':1, 'AB083':1}).values
cmat = confusion_matrix(act, pred)
print('classifier accuracy = {}%'.format((100.*np.trace(cmat))/(np.sum(cmat))))

#Marking the Confusion Matrix
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(act, pred))#performance
# Out:
# classifier accuracy = 88.0%
#               precision    recall  f1-score   support
#
#            0       0.93      0.90      0.92       108
#            1       0.76      0.83      0.80        42
#
#     accuracy                           0.88       150
#    macro avg       0.85      0.87      0.86       150
# weighted avg       0.88      0.88      0.88       150

# %% [markdown]
# # U41

# %%
import numpy as np
from sklearn.metrics import confusion_matrix
act = result['Sub_class_New'].array
pred = result['U41_Pred2'].array

cmat = confusion_matrix(act, pred)
print('classifier accuracy = {}%'.format((100.*np.trace(cmat))/(np.sum(cmat))))

#Marking the Confusion Matrix
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(act, pred))#performance
# Out:
# classifier accuracy = 80.0%
#               precision    recall  f1-score   support
#
#         AB01       0.33      0.33      0.33         3
#         AB02       0.29      0.67      0.40         3
#         AB03       1.00      1.00      1.00         3
#         AB04       1.00      1.00      1.00         3
#         AB05       0.50      0.67      0.57         3
#         AB06       1.00      0.33      0.50         3
#         AB07       0.00      0.00      0.00         3
#        AB081       0.75      1.00      0.86         3
#        AB082       0.50      0.67      0.57         3
#        AB083       0.00      0.00      0.00         3
#         AB09       1.00      1.00      1.00         3
#         AB10       0.67      0.67      0.67         3
#         AB11       0.33      0.67      0.44         3
#         AB12       0.00      0.00      0.00         3
#       Normal       0.91      0.89      0.90       108
#
#     accuracy                           0.80       150
# ...

# %%
act= result['Class'].map({'Normal':0,'Abnormal':1}).values
pred = result['U41_Pred2'].map({'AB12':1, 'AB04':1, 'AB05':1, 'Normal':0, 'AB02':1, 'AB11':1, 'AB082':1, 'AB06':1,'AB07':1, 'AB081':1, 'AB09':1, 'AB03':1, 'AB10':1, 'AB01':1, 'AB083':1}).values
cmat = confusion_matrix(act, pred)
print('classifier accuracy = {}%'.format((100.*np.trace(cmat))/(np.sum(cmat))))

#Marking the Confusion Matrix
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(act, pred))#performance
# Out:
# classifier accuracy = 86.0%
#               precision    recall  f1-score   support
#
#            0       0.91      0.89      0.90       108
#            1       0.73      0.79      0.76        42
#
#     accuracy                           0.86       150
#    macro avg       0.82      0.84      0.83       150
# weighted avg       0.86      0.86      0.86       150

# %% [markdown]
# # U31

# %%
import numpy as np
from sklearn.metrics import confusion_matrix
act = result['Sub_class_New'].array
pred = result['U31_Pred2'].array

cmat = confusion_matrix(act, pred)
print('classifier accuracy = {}%'.format((100.*np.trace(cmat))/(np.sum(cmat))))

#Marking the Confusion Matrix
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(act, pred))#performance
# Out:
# classifier accuracy = 68.66666666666667%
#               precision    recall  f1-score   support
#
#         AB01       0.00      0.00      0.00         3
#         AB02       0.33      0.67      0.44         3
#         AB03       0.60      1.00      0.75         3
#         AB04       0.50      0.67      0.57         3
#         AB05       0.25      0.33      0.29         3
#         AB06       0.33      0.33      0.33         3
#         AB07       0.25      0.33      0.29         3
#        AB081       0.29      0.67      0.40         3
#        AB082       0.75      1.00      0.86         3
#        AB083       0.00      0.00      0.00         3
#         AB09       1.00      0.67      0.80         3
#         AB10       0.60      1.00      0.75         3
#         AB11       0.23      1.00      0.38         3
#         AB12       1.00      1.00      1.00         3
#       Normal       0.99      0.71      0.83       108
#
#     accuracy                           0.69       150
# ...

# %%
act= result['Class'].map({'Normal':0,'Abnormal':1}).values
pred = result['U31_Pred'].map({'AB12':1, 'AB04':1, 'AB05':1, 'Normal':0, 'AB02':1, 'AB11':1, 'AB082':1, 'AB06':1,'AB07':1, 'AB081':1, 'AB09':1, 'AB03':1, 'AB10':1, 'AB01':1, 'AB083':1}).values
cmat = confusion_matrix(act, pred)
print('classifier accuracy = {}%'.format((100.*np.trace(cmat))/(np.sum(cmat))))

#Marking the Confusion Matrix
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(act, pred))#performance
# Out:
# classifier accuracy = 85.33333333333333%
#               precision    recall  f1-score   support
#
#            0       1.00      0.80      0.89       108
#            1       0.66      1.00      0.79        42
#
#     accuracy                           0.85       150
#    macro avg       0.83      0.90      0.84       150
# weighted avg       0.90      0.85      0.86       150

# %% [markdown]
# # U40

# %%
import numpy as np
from sklearn.metrics import confusion_matrix
act = result['Sub_class_New'].array
pred = result['U40_Pred2'].array

cmat = confusion_matrix(act, pred)
print('classifier accuracy = {}%'.format((100.*np.trace(cmat))/(np.sum(cmat))))

#Marking the Confusion Matrix
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(act, pred))#performance
# Out:
# classifier accuracy = 80.66666666666667%
#               precision    recall  f1-score   support
#
#         AB01       0.00      0.00      0.00         3
#         AB02       0.25      0.33      0.29         3
#         AB03       0.75      1.00      0.86         3
#         AB04       0.50      0.67      0.57         3
#         AB05       0.33      0.33      0.33         3
#         AB06       0.25      0.33      0.29         3
#         AB07       0.33      0.33      0.33         3
#        AB081       1.00      1.00      1.00         3
#        AB082       1.00      0.67      0.80         3
#        AB083       0.75      1.00      0.86         3
#         AB09       1.00      0.67      0.80         3
#         AB10       0.75      1.00      0.86         3
#         AB11       0.43      1.00      0.60         3
#         AB12       1.00      0.67      0.80         3
#       Normal       0.97      0.87      0.92       108
#
#     accuracy                           0.81       150
# ...

# %%
act= result['Class'].map({'Normal':0,'Abnormal':1}).values
pred = result['U40_Pred2'].map({'AB12':1, 'AB04':1, 'AB05':1, 'Normal':0, 'AB02':1, 'AB11':1, 'AB082':1, 'AB06':1,'AB07':1, 'AB081':1, 'AB09':1, 'AB03':1, 'AB10':1, 'AB01':1, 'AB083':1}).values
cmat = confusion_matrix(act, pred)
print('classifier accuracy = {}%'.format((100.*np.trace(cmat))/(np.sum(cmat))))

#Marking the Confusion Matrix
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(act, pred))#performance
# Out:
# classifier accuracy = 88.66666666666667%
#               precision    recall  f1-score   support
#
#            0       0.97      0.87      0.92       108
#            1       0.74      0.93      0.82        42
#
#     accuracy                           0.89       150
#    macro avg       0.85      0.90      0.87       150
# weighted avg       0.90      0.89      0.89       150

# %% [markdown]
# # U20

# %%
import numpy as np
from sklearn.metrics import confusion_matrix
act = result['Sub_class_New'].array
pred = result['U20_Pred2'].array

cmat = confusion_matrix(act, pred)
print('classifier accuracy = {}%'.format((100.*np.trace(cmat))/(np.sum(cmat))))

#Marking the Confusion Matrix
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(act, pred))#performance
# Out:
# classifier accuracy = 44.666666666666664%
#               precision    recall  f1-score   support
#
#         AB01       0.13      0.67      0.22         3
#         AB02       0.17      0.33      0.22         3
#         AB03       0.60      1.00      0.75         3
#         AB04       0.00      0.00      0.00         3
#         AB05       0.60      1.00      0.75         3
#         AB06       0.00      0.00      0.00         3
#         AB07       0.00      0.00      0.00         3
#        AB081       0.17      1.00      0.29         3
#        AB082       0.20      0.67      0.31         3
#        AB083       0.00      0.00      0.00         3
#         AB09       1.00      1.00      1.00         3
#         AB10       0.60      1.00      0.75         3
#         AB11       0.17      1.00      0.29         3
#         AB12       1.00      1.00      1.00         3
#       Normal       0.98      0.38      0.55       108
#
#     accuracy                           0.45       150
# ...

# %%
act= result['Class'].map({'Normal':0,'Abnormal':1}).values
pred = result['U20_Pred2'].map({'AB12':1, 'AB04':1, 'AB05':1, 'Normal':0, 'AB02':1, 'AB11':1, 'AB082':1, 'AB06':1,'AB07':1, 'AB081':1, 'AB09':1, 'AB03':1, 'AB10':1, 'AB01':1, 'AB083':1}).values
cmat = confusion_matrix(act, pred)
print('classifier accuracy = {}%'.format((100.*np.trace(cmat))/(np.sum(cmat))))

#Marking the Confusion Matrix
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(act, pred))#performance
# Out:
# classifier accuracy = 54.666666666666664%
#               precision    recall  f1-score   support
#
#            0       0.98      0.38      0.55       108
#            1       0.38      0.98      0.55        42
#
#     accuracy                           0.55       150
#    macro avg       0.68      0.68      0.55       150
# weighted avg       0.81      0.55      0.55       150

# %% [markdown]
# # U21

# %%
import numpy as np
from sklearn.metrics import confusion_matrix
act = result['Sub_class_New'].array
pred = result['U21_Pred2'].array

cmat = confusion_matrix(act, pred)
print('classifier accuracy = {}%'.format((100.*np.trace(cmat))/(np.sum(cmat))))

#Marking the Confusion Matrix
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(act, pred))#performance
# Out:
# classifier accuracy = 68.66666666666667%
#               precision    recall  f1-score   support
#
#         AB01       0.09      0.33      0.14         3
#         AB02       0.14      0.33      0.20         3
#         AB03       0.75      1.00      0.86         3
#         AB04       0.38      1.00      0.55         3
#         AB05       0.00      0.00      0.00         3
#         AB06       0.00      0.00      0.00         3
#         AB07       0.00      0.00      0.00         3
#        AB081       0.43      1.00      0.60         3
#        AB082       0.33      0.33      0.33         3
#        AB083       0.40      0.67      0.50         3
#         AB09       1.00      1.00      1.00         3
#         AB10       0.67      0.67      0.67         3
#         AB11       0.40      0.67      0.50         3
#         AB12       0.50      0.33      0.40         3
#       Normal       0.94      0.75      0.84       108
#
#     accuracy                           0.69       150
# ...

# %%
act= result['Class'].map({'Normal':0,'Abnormal':1}).values
pred = result['U21_Pred2'].map({'AB12':1, 'AB04':1, 'AB05':1, 'Normal':0, 'AB02':1, 'AB11':1, 'AB082':1, 'AB06':1,'AB07':1, 'AB081':1, 'AB09':1, 'AB03':1, 'AB10':1, 'AB01':1, 'AB083':1}).values
cmat = confusion_matrix(act, pred)
print('classifier accuracy = {}%'.format((100.*np.trace(cmat))/(np.sum(cmat))))

#Marking the Confusion Matrix
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(act, pred))#performance
# Out:
# classifier accuracy = 78.66666666666667%
#               precision    recall  f1-score   support
#
#            0       0.94      0.75      0.84       108
#            1       0.58      0.88      0.70        42
#
#     accuracy                           0.79       150
#    macro avg       0.76      0.82      0.77       150
# weighted avg       0.84      0.79      0.80       150
