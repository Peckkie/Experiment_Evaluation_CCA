# %%
import pandas as pd
df = pd.read_csv( '/home/kannika/code/FeaturesVector_Testset_preds_RF.csv')#แก้
df
# Out:
#       Unnamed: 0         0         1         2         3         4         5  \
# 0              0 -0.107832  0.312149  0.017342 -0.183515  0.575329 -0.173988
# 1              1  0.410584  0.660918 -0.136561 -0.185142  0.411921 -0.167172
# 2              2 -0.017507  0.345107  0.225857 -0.165460  0.779620 -0.193235
# 3              3 -0.020903  0.117676 -0.082830 -0.135977  0.282654 -0.220009
# 4              4  0.064264  0.339072  0.294476 -0.157963  0.194470 -0.202357
# ...          ...       ...       ...       ...       ...       ...       ...
# 1307        1307  0.744561  1.183853 -0.053521 -0.201384  0.486397 -0.161738
# 1308        1308  0.002655 -0.022164 -0.106891 -0.050455  0.119427  0.226081
# 1309        1309  0.311478  0.809876 -0.182767 -0.104543  0.685962  0.047534
# 1310        1310  0.273307 -0.022791  0.022112 -0.126591 -0.079219 -0.175265
# 1311        1311  0.182392  0.162891 -0.162713 -0.201793 -0.062425 -0.029388
#
# ...

# %%
df0 = pd.read_csv( '/home/yupaporn/CSV_file/result_BiTNet_FPScores.csv')
df0
# Out:
#       Unnamed: 0     Case Abs Position Sub Position     Class  \
# 0              0  AB01_40           P1           P1  Abnormal
# 1              1  AB01_40           P2           P2  Abnormal
# 2              2  AB01_40           P4          P41  Abnormal
# 3              3  AB01_40           P5          P51  Abnormal
# 4              4  AB01_40           P3          P31  Abnormal
# ...          ...      ...          ...          ...       ...
# 1307        1307      350           P3          P32    Normal
# 1308        1308      350           P4          P42    Normal
# 1309        1309      350           P5          P52    Normal
# 1310        1310      350           P6          P61    Normal
# 1311        1311      350           P8           P8    Normal
#
#                                               Path Full  \
# 0     /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 1     /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# ...

# %%
df['Sub_class_New'] = df0['Sub_class_New'].tolist()
df['15AB'] = df0['15AB'].tolist()

# %%
res = df

#None
AI_pred = res['RF_preds15AB'].tolist()
act = res['Sub_class_New'].tolist()
Acc  = []
Acc_  = []
for i in  range(len(AI_pred)):
    if act[i] == AI_pred[i]:
        Acc.append('Correct')
    else:
        Acc.append('Incorrect')

res['15AB_pred_'] =Acc

# %%
df
# Out:
#       Unnamed: 0         0         1         2         3         4         5  \
# 0              0 -0.107832  0.312149  0.017342 -0.183515  0.575329 -0.173988
# 1              1  0.410584  0.660918 -0.136561 -0.185142  0.411921 -0.167172
# 2              2 -0.017507  0.345107  0.225857 -0.165460  0.779620 -0.193235
# 3              3 -0.020903  0.117676 -0.082830 -0.135977  0.282654 -0.220009
# 4              4  0.064264  0.339072  0.294476 -0.157963  0.194470 -0.202357
# ...          ...       ...       ...       ...       ...       ...       ...
# 1307        1307  0.744561  1.183853 -0.053521 -0.201384  0.486397 -0.161738
# 1308        1308  0.002655 -0.022164 -0.106891 -0.050455  0.119427  0.226081
# 1309        1309  0.311478  0.809876 -0.182767 -0.104543  0.685962  0.047534
# 1310        1310  0.273307 -0.022791  0.022112 -0.126591 -0.079219 -0.175265
# 1311        1311  0.182392  0.162891 -0.162713 -0.201793 -0.062425 -0.029388
#
# ...

# %% [markdown]
# # ทำนายผิดเเค่ไหนหาสัดสัดอิงตามจำนวน class ที่ทำนาย

# %%
df[["RF_preds15AB", "15AB_pred_", "Unnamed: 0"]].groupby(["RF_preds15AB", "15AB_pred_"]).count().reset_index()
# Out:
#    RF_preds15AB 15AB_pred_  Unnamed: 0
# 0          AB01    Correct          44
# 1          AB01  Incorrect          10
# 2          AB02    Correct          41
# 3          AB02  Incorrect          28
# 4          AB03    Correct           9
# 5          AB03  Incorrect           5
# 6          AB04    Correct          26
# 7          AB04  Incorrect           5
# 8          AB05    Correct          21
# 9          AB05  Incorrect           5
# 10         AB06    Correct          13
# 11         AB06  Incorrect           2
# 12         AB07    Correct          13
# 13         AB07  Incorrect           5
# 14        AB081    Correct          20
# 15        AB081  Incorrect           4
# 16        AB082    Correct          17
# 17        AB082  Incorrect           4
# 18        AB083    Correct           3
# 19        AB083  Incorrect           1
# 20         AB09    Correct          22
# 21         AB09  Incorrect           1
# 22         AB10    Correct           4
# ...

# %%
df[["Sub_class_New","15AB" ,"Unnamed: 0"]].groupby(['Sub_class_New',"15AB"]).count().reset_index()
# Out:
#    Sub_class_New                            15AB  Unnamed: 0
# 0           AB01                  MildFattyLiver          74
# 1           AB02              ModerateFattyLiver          59
# 2           AB03                SevereFattyLiver          19
# 3           AB04                       Cirrhosis          38
# 4           AB05                            PDF1          29
# 5           AB06                            PDF2          21
# 6           AB07                            PDF3          21
# 7          AB081                       Livermass          32
# 8          AB082                             BDD          28
# 9          AB083                 LivermassAndBDD          11
# 10          AB09                Gallbladderstone          26
# 11          AB10                 GallbladderMass           1
# 12          AB10                Gallbladderpolyp           9
# 13          AB11                  Hydronephrosis          18
# ...

# %% [markdown]
# # ทำนายผิดเเค่ไหนหาสัดสัดอิงตามจำนวน class จริง

# %%
Correct = df[df['15AB_pred_'] == 'Correct']
Incorrect = df[df['15AB_pred_'] == 'Incorrect']

# %%
Incorrect[["Sub_class_New","15AB" ,"RF_preds15AB","Unnamed: 0"]].groupby(['Sub_class_New',"15AB","RF_preds15AB"]).count().reset_index()
# Out:
#    Sub_class_New                            15AB RF_preds15AB  Unnamed: 0
# 0           AB01                  MildFattyLiver         AB02          16
# 1           AB01                  MildFattyLiver       Normal          14
# 2           AB02              ModerateFattyLiver         AB01           6
# 3           AB02              ModerateFattyLiver         AB03           5
# 4           AB02              ModerateFattyLiver       Normal           7
# 5           AB03                SevereFattyLiver         AB02          10
# 6           AB04                       Cirrhosis         AB06           1
# 7           AB04                       Cirrhosis         AB07           1
# 8           AB04                       Cirrhosis       Normal          10
# 9           AB05                            PDF1       Normal           8
# 10          AB06                            PDF2         AB07           2
# 11          AB06                            PDF2       Normal           6
# ...

# %%
Correct[["Sub_class_New","15AB" ,"RF_preds15AB","Unnamed: 0"]].groupby(['Sub_class_New',"15AB","RF_preds15AB"]).count().reset_index()
# Out:
#    Sub_class_New                            15AB RF_preds15AB  Unnamed: 0
# 0           AB01                  MildFattyLiver         AB01          44
# 1           AB02              ModerateFattyLiver         AB02          41
# 2           AB03                SevereFattyLiver         AB03           9
# 3           AB04                       Cirrhosis         AB04          26
# 4           AB05                            PDF1         AB05          21
# 5           AB06                            PDF2         AB06          13
# 6           AB07                            PDF3         AB07          13
# 7          AB081                       Livermass        AB081          20
# 8          AB082                             BDD        AB082          17
# 9          AB083                 LivermassAndBDD        AB083           3
# 10          AB09                Gallbladderstone         AB09          22
# 11          AB10                Gallbladderpolyp         AB10           4
# ...
