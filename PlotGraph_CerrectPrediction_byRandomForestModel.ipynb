# %%
AB15 = ['AB01'
,'AB02'
,'AB03'
,'AB04'
,'AB05'
,'AB06'
,'AB07'
,'AB081'
,'AB082'
,'AB083'
,'AB09'
,'AB10'
,'AB11'
,'AB12'
,'Normal']

# %%
cerrect_none = [0.6081
,0.5932
,0.4737
,0.6842
,0.6552
,0.4762
,0.4762
,0.5625
,0.5357
,0.3636
,0.7692
,0.4000
,0.3636
,0.7500
,0.9942]

# %%
cerrect_random = [0.5946
,0.6949
,0.4737
,0.6842
,0.7241
,0.6190
,0.6190
,0.6250
,0.6071
,0.2727
,0.8462
,0.4000
,0.3455
,0.7500
,0.9907]

# %%
cerrect_logis = [0.6216
,0.7627
,0.4211
,0.6842
,0.8621
,0.6667
,0.6667
,0.6250
,0.6429
,0.4545
,0.8846
,0.5000
,0.3455
,0.7813
,0.9848]

# %%
font = {'family': 'serif',
        'color':  'black',
        'weight': 'normal'}
hfont = {'fontname':'serif'}

# %%
import matplotlib.pyplot as plt
import numpy as np

labels = AB15
none = cerrect_none
act = cerrect_random
x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots(figsize=(10, 5))
rects1 = ax.bar(x - width/2, none, width, color=['#75bbfd'], label='BiTNet') #color= '#75bbfd'
rects2 = ax.bar(x + width/2, act, width, color=['#fdaa48'], label='Random Forest (Position prior)') #color= '#ffb07c'

ax.set_xticks(x)
# ax.set_xticklabels(labels)
ax.set_xticklabels(labels, fontdict=font)

plt.title('The predicted proportional graph of the cerrect predicted model (15AB class)',fontsize=18, fontdict=font, pad=15)
ax.legend()
fig.tight_layout()

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

labels = AB15
none = cerrect_none
random = cerrect_random
logis = cerrect_logis
x = np.arange(len(labels))  # the label locations
width = 0.25  # the width of the bars

fig, ax = plt.subplots(figsize=(15, 6))
rects1 = ax.bar(x - width, none, width, color=['#738595'], label='BiTNet') #color= '#75bbfd'
rects2 = ax.bar(x , random, width, color=['#2976bb'], label='Random Forest (Position prior)') #color= '#ffb07c'
rects2 = ax.bar(x + width, logis, width, color=['#75bbfd'], label='Logistics Regression (Position prior)') #color= '#ffb07c'

ax.set_xticks(x)
# ax.set_xticklabels(labels)
ax.set_xticklabels(labels, fontdict=font, rotation=25)
plt.title('The predicted proportional graph of the cerrect predicted model (15AB class)',fontsize=18, fontdict=font, pad=15)
ax.legend()
fig.tight_layout()

plt.show()

# %%
sub_class = ['MildFattyLiver'
,'ModerateFattyLiver'
,'SevereFattyLiver'
,'Cirrhosis'
,'PDF1'
,'PDF2'
,'PDF3'
,'Livermass'
,'BDD'
,'LivermassAndBDD'
,'Gallbladderstone'
,'GallbladderMass'
,'Gallbladderpolyp'
,'Hydronephrosis'
,'RenalCyst'
,'RenalCystAndStone'
,'RenalMass'
,'RenalStone'
,'RenalstoneAndParenchymalChange'
,'RenalstonesAndHydronephrosis'
,'Splenomegaly'
,'Normal']

# %%
MildFattyLiver	0.5946
ModerateFattyLiver	0.6949
SevereFattyLiver	0.4737
Cirrhosis	0.6842
PDF1	0.7241
PDF2	0.6190
PDF3	0.6190
Livermass	0.6250
BDD	0.6071
LivermassAndBDD	0.2727
Gallbladderstone	0.8462
GallbladderMass	0.0000
Gallbladderpolyp	0.4444
Hydronephrosis	0.3889
RenalCyst	0.5000
RenalCystAndStone	0.0000
RenalMass	1.0000
RenalStone	0.1579
RenalstoneAndParenchymalChange	0.5000
RenalstonesAndHydronephrosis	0.5000
Splenomegaly	0.7500
Normal	0.9907

# %%
sub_class = ['MildFL', 'ModerateFL', 'SevereFL', 'Cirrhosis', 'PDF1', 'PDF2', 'PDF3', 'Livermass', 'BDD', 'Lmass&BDD', 'Gall.stone', 'Gall.Mass', 'Gall.polyp',
          'Hydronephrosis', 'RenalCyst', 'RenalCyst&Stone',   'RenalMass', 'RenalStone', 'RenalS&Paren.', 'RenalS&Hydro.', 'Splenomegaly', 'Normal']

# %%
cerrect_none = [0.6081
,0.5932
,0.4737
,0.6842
,0.6552
,0.4762
,0.4762
,0.5625
,0.5357
,0.3636
,0.7692
,0.0000
,0.4444
,0.2222
,0.5000
,1.0000 #
,1.0000
,0.2105
,1.0000
,0.5833
,0.7500
,0.9942]

# %%
cerrect_random = [0.5946
,0.6949
,0.4737
,0.6842
,0.7241
,0.6190
,0.6190
,0.6250
,0.6071
,0.2727
,0.8462
,0.0000
,0.4444
,0.3889
,0.5000
,0.0000 #
,1.0000
,0.1579
,0.5000
,0.5000
,0.7500
,0.9907]

# %%
cerrect_logis = [0.6216
,0.7627
,0.4211
,0.6842
,0.8621
,0.6667
,0.6667
,0.6250
,0.6429
,0.4545
,0.8846
,0.0000
,0.5556
,0.3889
,0.5000
,0.0000
,1.0000#
,0.1579
,0.5000
,0.5000
,0.7813
,0.9848]

# %%
import matplotlib.pyplot as plt
import numpy as np

labels = sub_class
none = cerrect_none
act = cerrect_random
x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots(figsize=(13, 6))
rects1 = ax.bar(x - width/2, none, width, color=['#75bbfd'], label='BiTNet') #color= '#75bbfd'
rects2 = ax.bar(x + width/2, act, width, color=['#fdaa48'], label='Random Forest (Position prior)') #color= '#ffb07c'

ax.set_xticks(x)
# ax.set_xticklabels(labels)
ax.set_xticklabels(labels, fontdict=font, rotation=25)
plt.title('The predicted proportional graph of the cerrect predicted model (sub.15AB class)',fontsize=18, fontdict=font, pad=15)
ax.legend()
fig.tight_layout()

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

labels = sub_class
none = cerrect_none
random = cerrect_random
logis = cerrect_logis
x = np.arange(len(labels))  # the label locations
width = 0.25  # the width of the bars

fig, ax = plt.subplots(figsize=(15, 6))
rects1 = ax.bar(x - width, none, width, color=['#738595'], label='BiTNet') #color= '#75bbfd'
rects2 = ax.bar(x , random, width, color=['#2976bb'], label='Random Forest (Position prior)') #color= '#ffb07c'
rects2 = ax.bar(x + width, logis, width, color=['#75bbfd'], label='Logistics Regression (Position prior)') #color= '#ffb07c'

ax.set_xticks(x)
# ax.set_xticklabels(labels)
ax.set_xticklabels(labels, fontdict=font, rotation=25)
plt.title('The predicted proportional graph of the cerrect predicted model (sub.15AB class)',fontsize=18, fontdict=font, pad=15)
ax.legend()
fig.tight_layout()

plt.show()
