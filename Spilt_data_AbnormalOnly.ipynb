# %%
import pandas as pd
Traindf = pd.read_csv('/home/yupaporn/codes/USAI/Traindf_fold1_3.csv')
Traindf
# Out:
#       Unnamed: 0  Unnamed: 0.1  Case Abs Position Sub Position     Class  \
# 0              0             1    42           P1           P1  Abnormal
# 1              1             6    42           P1           P1  Abnormal
# 2              2            10    42           P1           P1  Abnormal
# 3              3            20    22           P1           P1  Abnormal
# 4              4            29    22           P1           P1  Abnormal
# ...          ...           ...   ...          ...          ...       ...
# 7387        7387          2370    82           P8           P8    Normal
# 7388        7388          3411   209           P8           P8    Normal
# 7389        7389          3112   197           P8           P8    Normal
# 7390        7390          3821   292           P8           P8    Normal
# 7391        7391          4174   255           P8           P8    Normal
#
#      Sub_class                                          Path Full  \
# ...

# %%
Traindf.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'Case', 'Abs Position', 'Sub Position',
#        'Class', 'Sub_class', 'Path Full', 'Path Crop', 'Views', 'fold',
#        'tagName', 'originalImage', 'left', 'top', 'width', 'height', 'Rleft',
#        'Rtop', 'Rwidth', 'Rheight', 'filename'],
#       dtype='object')

# %%
Traindf1 = Traindf[Traindf['Sub_class']!='Normal']
Traindf1
# Out:
#       Unnamed: 0  Unnamed: 0.1  Case Abs Position Sub Position     Class  \
# 0              0             1    42           P1           P1  Abnormal
# 1              1             6    42           P1           P1  Abnormal
# 2              2            10    42           P1           P1  Abnormal
# 3              3            20    22           P1           P1  Abnormal
# 4              4            29    22           P1           P1  Abnormal
# ...          ...           ...   ...          ...          ...       ...
# 6967        6967           696    41           P7          P72  Abnormal
# 6968        6968          1513   445           P7          P72  Abnormal
# 6969        6969          1512   352           P7          P72  Abnormal
# 6970        6970          1586   431           P7          P72  Abnormal
# 6971        6971          1595   373           P7          P72  Abnormal
#
#      Sub_class                                          Path Full  \
# ...

# %%
# Traindf1.to_csv('/home/yupaporn/CSV_file/Traindf_fold1_3_NoNormal.csv')

# %%
Traindf1 = Traindf[Traindf['Sub_class']!='Normal']
Traindf1
# Out:
#       Unnamed: 0  Unnamed: 0.1  Case Abs Position Sub Position     Class  \
# 0              0             1    42           P1           P1  Abnormal
# 1              1             6    42           P1           P1  Abnormal
# 2              2            10    42           P1           P1  Abnormal
# 3              3            20    22           P1           P1  Abnormal
# 4              4            29    22           P1           P1  Abnormal
# ...          ...           ...   ...          ...          ...       ...
# 6967        6967           696    41           P7          P72  Abnormal
# 6968        6968          1513   445           P7          P72  Abnormal
# 6969        6969          1512   352           P7          P72  Abnormal
# 6970        6970          1586   431           P7          P72  Abnormal
# 6971        6971          1595   373           P7          P72  Abnormal
#
#      Sub_class                                          Path Full  \
# ...

# %%
nor = pd.read_csv('/home/yupaporn/CSV_file/Traindf_Hard_normal_80.csv')
nor
# Out:
#       Unnamed: 0  level_0  index  Unnamed: 0.1  Unnamed: 0.1.1  Case  \
# 0              2        2    235           235            1621     6
# 1              4        4    237           237            1646    39
# 2              5        5    238           238            1657    54
# 3              6        6    239           239            1669    37
# 4              7        7    240           240            1680    57
# ...          ...      ...    ...           ...             ...   ...
# 2675        3994     3994   7382          7382            3528   239
# 2676        3997     3997   7385          7385            3196   152
# 2677        3998     3998   7386          7386            1679    37
# 2678        4002     4002   7390          7390            3821   292
# 2679        4003     4003   7391          7391            4174   255
#
#      Abs Position Sub Position   Class Sub_class  ... width height Rleft  \
# ...

# %%
dff = Traindf1.append(nor)
dff
# Out:
#       Unnamed: 0  Unnamed: 0.1  Case Abs Position Sub Position     Class  \
# 0              0             1    42           P1           P1  Abnormal
# 1              1             6    42           P1           P1  Abnormal
# 2              2            10    42           P1           P1  Abnormal
# 3              3            20    22           P1           P1  Abnormal
# 4              4            29    22           P1           P1  Abnormal
# ...          ...           ...   ...          ...          ...       ...
# 2675        3994          7382   239           P8           P8    Normal
# 2676        3997          7385   152           P8           P8    Normal
# 2677        3998          7386    37           P8           P8    Normal
# 2678        4002          7390   292           P8           P8    Normal
# 2679        4003          7391   255           P8           P8    Normal
#
#      Sub_class                                          Path Full  \
# ...

# %%
dff = dff[[ 'Case', 'Abs Position', 'Sub Position',
       'Class', 'Sub_class', 'Path Full', 'Path Crop', 'Views', 'fold',
       'tagName', 'originalImage', 'left', 'top', 'width', 'height', 'Rleft',
       'Rtop', 'Rwidth', 'Rheight', 'filename',]]

# %%
# dff.to_csv('/home/yupaporn/CSV_file/Traindf_Hard_train.csv')

# %%
import pandas as pd
Validationdf = pd.read_csv('/home/yupaporn/codes/USAI/Validationdf_fold1_3.csv')
Validationdf
# Out:
#       Unnamed: 0  Unnamed: 0.1  Case Abs Position Sub Position     Class  \
# 0              0             1    15           P1           P1  Abnormal
# 1              1            11    15           P1           P1  Abnormal
# 2              2            17    15           P1           P1  Abnormal
# 3              3            21    15           P1           P1  Abnormal
# 4              4            23    15           P1           P1  Abnormal
# ...          ...           ...   ...          ...          ...       ...
# 1027        1027           308    95           P8           P8    Normal
# 1028        1028           655   349           P8           P8    Normal
# 1029        1029           543   288           P8           P8    Normal
# 1030        1030           380   119           P8           P8    Normal
# 1031        1031           344    71           P8           P8    Normal
#
#      Sub_class                                          Path Full  \
# ...

# %%
Validationdf1 = Validationdf[Validationdf['Sub_class']!='Normal']
Validationdf1
# Out:
#      Unnamed: 0  Unnamed: 0.1  Case Abs Position Sub Position     Class  \
# 0             0             1    15           P1           P1  Abnormal
# 1             1            11    15           P1           P1  Abnormal
# 2             2            17    15           P1           P1  Abnormal
# 3             3            21    15           P1           P1  Abnormal
# 4             4            23    15           P1           P1  Abnormal
# ..          ...           ...   ...          ...          ...       ...
# 968         968           212   444           P7          P72  Abnormal
# 969         969           220   383           P7          P72  Abnormal
# 970         970           156    95           P7          P72  Abnormal
# 971         971           217   379           P7          P72  Abnormal
# 972         972           116    91           P7          P72  Abnormal
#
#     Sub_class                                          Path Full  \
# ...

# %%
# Validationdf1.to_csv('/home/yupaporn/CSV_file/Validationdf_fold1_3_NoNormal.csv')
