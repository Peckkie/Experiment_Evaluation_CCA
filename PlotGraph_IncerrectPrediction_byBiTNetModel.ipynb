# %%
# Probpotion_IncerrectPredictionByBiTNetModel.csv

# %% [markdown]
# # สัดส่วนการทำนายผิดของโมเดลเเยกตาม Actual class

# %%
import pandas as pd
df = pd.read_csv( '/home/yupaporn/CSV_file/Probpotion_IncerrectPredictionByBiTNetModel.csv')#แก้

# %%
df
# Out:
#    15AB_Class                Sub_15AB_Class     None      Act
# 0        AB01                MildFattyLiver  0.39189  0.39189
# 1        AB02            ModerateFattyLiver  0.40678  0.40678
# 2        AB03              SevereFattyLiver  0.52632  0.52632
# 3        AB04                     Cirrhosis  0.31579  0.31579
# 4        AB05                          PDF1  0.34483  0.34483
# 5        AB06                          PDF2  0.52381  0.47619
# 6        AB07                          PDF3  0.52381  0.47619
# 7       AB081                     Livermass  0.43750  0.40625
# 8       AB082                           BDD  0.46429  0.42857
# 9       AB083               LivermassAndBDD  0.63636  0.72727
# 10       AB09              Gallbladderstone  0.23077  0.19231
# 11       AB10               GallbladderMass  1.00000  1.00000
# 12       AB10              Gallbladderpolyp  0.55556  0.55556
# 13       AB11                Hydronephrosis  0.77778  0.66667
# ...

# %%
aa = df[["15AB_Class","None"]].groupby(['15AB_Class']).mean().reset_index()
none = aa['None'].tolist()

# %%
aa = df[["15AB_Class","Act"]].groupby(['15AB_Class']).mean().reset_index()
act = aa['Act'].tolist()

# %%
import matplotlib.pyplot as plt

# %%
font = {'family': 'serif',
        'color':  'black',
        'weight': 'normal'}
hfont = {'fontname':'serif'}

# %%
import seaborn as sns

fig, ax = plt.subplots(figsize=(10, 5))
# plt.ylim(0.,8)
plt.xlim(0,1)  
# plt.subplots(figsize=(7,6), dpi=100)
sns.distplot( none , color="dodgerblue", label="BiTNet")
sns.distplot( act , color="orange", label="BiTNet+5FPact")

plt.title('Histogram of incorrect model prediction (propotion) \n by 15AB class',fontsize=18, fontdict=font, pad=15)
plt.legend();
# Out:
# /home/yupaporn/miniconda3/envs/USAI3/lib/python3.6/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/yupaporn/miniconda3/envs/USAI3/lib/python3.6/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
import seaborn as sns

fig, ax = plt.subplots(figsize=(10, 5))
# plt.ylim(0.,8)
plt.xlim(0,1)  
# plt.subplots(figsize=(7,6), dpi=100)
sns.distplot( act , color="orange", label="BiTNet+5FPact")

# plt.title('Histogram of incorrect model prediction (propotion) \n by 15AB class',fontsize=18, fontdict=font, pad=15)
plt.legend();
# Out:
# /home/yupaporn/miniconda3/envs/USAI3/lib/python3.6/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
import seaborn as sns

fig, ax = plt.subplots(figsize=(10, 5))
# plt.ylim(0.,8)
plt.xlim(0,1)  
# plt.subplots(figsize=(7,6), dpi=100)
sns.distplot( none , color="dodgerblue", label="BiTNet")

# plt.title('Histogram of incorrect model prediction (propotion) \n by 15AB class',fontsize=18, fontdict=font, pad=15)
plt.legend();
# Out:
# /home/yupaporn/miniconda3/envs/USAI3/lib/python3.6/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
aa = df[["15AB_Class","Act"]].groupby(['15AB_Class']).mean().reset_index()
act = aa['Act'].tolist()

# %%
aa = df[["15AB_Class","None"]].groupby(['15AB_Class']).mean().reset_index()
none = aa['None'].tolist()

# %%
class_ = aa['15AB_Class'].tolist()

# %%
none_cerrect =[]
for i in none:
    none_cerrect.append(1-i)
    
act_cerrect =[]
for i in act:
    act_cerrect.append(1-i)

# %%
import matplotlib.pyplot as plt
import numpy as np

labels = class_
none = none
act = act
x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots(figsize=(10, 5))
rects1 = ax.bar(x - width/2, none, width, color=['#75bbfd'], label='BiTNet') #color= '#75bbfd'
rects2 = ax.bar(x + width/2, act, width, color=['#fdaa48'], label='BiTNet+5FPact') #color= '#ffb07c'

ax.set_xticks(x)
# ax.set_xticklabels(labels)
ax.set_xticklabels(labels, fontdict=font)

plt.title('The predicted proportional graph of the wrong predicted model (15AB class)',fontsize=18, fontdict=font, pad=15)
ax.legend()
fig.tight_layout()

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

labels = class_
none = none_cerrect
act = act_cerrect
x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots(figsize=(10, 5))
rects1 = ax.bar(x - width/2, none, width, color=['#75bbfd'], label='BiTNet') #color= '#75bbfd'
rects2 = ax.bar(x + width/2, act, width, color=['#fdaa48'], label='BiTNet+5FPact') #color= '#ffb07c'

ax.set_xticks(x)
# ax.set_xticklabels(labels)
ax.set_xticklabels(labels, fontdict=font)

plt.title('The predicted proportional graph of the cerrect predicted model (15AB class)',fontsize=18, fontdict=font, pad=15)
ax.legend()
fig.tight_layout()

plt.show()

# %%
df
# Out:
#    15AB_Class                Sub_15AB_Class     None      Act
# 0        AB01                MildFattyLiver  0.39189  0.39189
# 1        AB02            ModerateFattyLiver  0.40678  0.40678
# 2        AB03              SevereFattyLiver  0.52632  0.52632
# 3        AB04                     Cirrhosis  0.31579  0.31579
# 4        AB05                          PDF1  0.34483  0.34483
# 5        AB06                          PDF2  0.52381  0.47619
# 6        AB07                          PDF3  0.52381  0.47619
# 7       AB081                     Livermass  0.43750  0.40625
# 8       AB082                           BDD  0.46429  0.42857
# 9       AB083               LivermassAndBDD  0.63636  0.72727
# 10       AB09              Gallbladderstone  0.23077  0.19231
# 11       AB10               GallbladderMass  1.00000  1.00000
# 12       AB10              Gallbladderpolyp  0.55556  0.55556
# 13       AB11                Hydronephrosis  0.77778  0.66667
# ...

# %%
none = df['None'].tolist()
act = df['Act'].tolist()

# %%
import seaborn as sns

fig, ax = plt.subplots(figsize=(10, 5))
# plt.ylim(0.,8)
plt.xlim(0,1)  
# plt.subplots(figsize=(7,6), dpi=100)
sns.distplot( none , color="dodgerblue", label="BiTNet")
sns.distplot( act , color="orange", label="BiTNet+5FPact")

plt.title('Histogram of incorrect model prediction (propotion) \n by sub. 15AB class',fontsize=18, fontdict=font, pad=15)
plt.legend();
# Out:
# /home/yupaporn/miniconda3/envs/USAI3/lib/python3.6/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/yupaporn/miniconda3/envs/USAI3/lib/python3.6/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
import seaborn as sns

fig, ax = plt.subplots(figsize=(10, 5))
# plt.ylim(0.,8)
plt.xlim(0,1)  
# plt.subplots(figsize=(7,6), dpi=100)
sns.distplot( none , color="dodgerblue", label="BiTNet")
# sns.distplot( act , color="orange", label="BiTNet+5FPact")

# plt.title('Histogram of incorrect model prediction (propotion) \n by sub. 15AB class',fontsize=18, fontdict=font, pad=15)
plt.legend();
# Out:
# /home/yupaporn/miniconda3/envs/USAI3/lib/python3.6/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
import seaborn as sns

fig, ax = plt.subplots(figsize=(10, 5))
# plt.ylim(0.,8)
plt.xlim(0,1)  
# plt.subplots(figsize=(7,6), dpi=100)
# sns.distplot( none , color="dodgerblue", label="BiTNet")
sns.distplot( act , color="orange", label="BiTNet+5FPact")

# plt.title('Histogram of incorrect model prediction (propotion) \n by sub. 15AB class',fontsize=18, fontdict=font, pad=15)
plt.legend();
# Out:
# /home/yupaporn/miniconda3/envs/USAI3/lib/python3.6/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df
# Out:
#    15AB_Class                Sub_15AB_Class     None      Act
# 0        AB01                MildFattyLiver  0.39189  0.39189
# 1        AB02            ModerateFattyLiver  0.40678  0.40678
# 2        AB03              SevereFattyLiver  0.52632  0.52632
# 3        AB04                     Cirrhosis  0.31579  0.31579
# 4        AB05                          PDF1  0.34483  0.34483
# 5        AB06                          PDF2  0.52381  0.47619
# 6        AB07                          PDF3  0.52381  0.47619
# 7       AB081                     Livermass  0.43750  0.40625
# 8       AB082                           BDD  0.46429  0.42857
# 9       AB083               LivermassAndBDD  0.63636  0.72727
# 10       AB09              Gallbladderstone  0.23077  0.19231
# 11       AB10               GallbladderMass  1.00000  1.00000
# 12       AB10              Gallbladderpolyp  0.55556  0.55556
# 13       AB11                Hydronephrosis  0.77778  0.66667
# ...

# %%
class_ = df['Sub_15AB_Class'].tolist()
none = df['None'].tolist()
act = df['Act'].tolist()

# %%
none_cerrect =[]
for i in none:
    none_cerrect.append(1-i)
    
act_cerrect =[]
for i in act:
    act_cerrect.append(1-i)

# %%
font = {'family': 'serif',
        'color':  'black',
        'weight': 'normal'}
hfont = {'fontname':'serif'}

# %%
print(class_)
# Out:
# ['MildFattyLiver', 'ModerateFattyLiver', 'SevereFattyLiver', 'Cirrhosis', 'PDF1', 'PDF2', 'PDF3', 'Livermass', 'BDD', 'LivermassAndBDD', 'Gallbladderstone', 'GallbladderMass', 'Gallbladderpolyp', 'Hydronephrosis', 'RenalCyst', 'RenalStone', 'RenalstonesAndHydronephrosis', 'Splenomegaly', 'Normal']

# %%
print(len(none))
# Out:
# 19

# %%
class_ = ['MildFL', 'ModerateFL', 'SevereFL', 'Cirrhosis', 'PDF1', 'PDF2', 'PDF3', 'Livermass', 'BDD', 'Lmass&BDD', 'Gal.stone', 'Gall.rMass', 'Gall.polyp', 'Hydronephrosis', 'RenalCyst', 'RenalStone', 'RenalS&Hydro.', 'Splenomegaly', 'Normal']

# %%
import matplotlib.pyplot as plt
import numpy as np

labels = class_
none = none
act = act
x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots(figsize=(10, 5))
rects1 = ax.bar(x - width/2, none, width, color=['#75bbfd'], label='BiTNet') #color= '#75bbfd'
rects2 = ax.bar(x + width/2, act, width, color=['#fdaa48'], label='BiTNet+5FPact') #color= '#ffb07c'

ax.set_xticks(x)
# ax.set_xticklabels(labels)
ax.set_xticklabels(labels, fontdict=font, rotation=25)
plt.title('The predicted proportional graph of the wrong predicted model (sub.15AB class)',fontsize=18, fontdict=font, pad=15)
ax.legend()
fig.tight_layout()

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

labels = class_
none = none_cerrect
act = act_cerrect
x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots(figsize=(10, 5))
rects1 = ax.bar(x - width/2, none, width, color=['#75bbfd'], label='BiTNet') #color= '#75bbfd'
rects2 = ax.bar(x + width/2, act, width, color=['#fdaa48'], label='BiTNet+5FPact') #color= '#ffb07c'

ax.set_xticks(x)
# ax.set_xticklabels(labels)
ax.set_xticklabels(labels, fontdict=font, rotation=25)
plt.title('The predicted proportional graph of the wrong predicted model (sub.15AB class)',fontsize=18, fontdict=font, pad=15)
ax.legend()
fig.tight_layout()

plt.show()

# %% [markdown]
# # สัดส่วนการทำนายผิดของโมเดลเเยกตาม Predict class

# %%
import pandas as pd
df = pd.read_csv( '/home/yupaporn/CSV_file/BiTNeT_predict15AB_Incerrect.csv')#แก้

# %%
df
# Out:
#    15AB_predict      None     FPact
# 0          AB01  0.210526  0.224138
# 1          AB02  0.426230  0.426230
# 2          AB03  0.500000  0.526316
# 3          AB04  0.187500  0.187500
# 4          AB05  0.173913  0.208333
# 5          AB06  0.166667  0.083333
# 6          AB07  0.285714  0.214286
# 7         AB081  0.217391  0.240000
# 8         AB082  0.210526  0.200000
# 9         AB083  0.200000  0.000000
# 10         AB09  0.166667  0.000000
# 11         AB10  0.952381  0.000000
# 12         AB11  1.000000  0.043478
# 13         AB12  0.578947  0.549020
# 14       Normal  0.097458  0.097354

# %%
class_ = df['15AB_predict'].tolist()
none = [0.2105,
0.4262,
0.5000,
0.1875,
0.1739,
0.1667,
0.2857,
0.2174,
0.2105,
0.2000,
0.0000,
0.2000,
0.0909,
0.5789,
0.0975]

act = df['FPact'].tolist()

# %%
none_cerrect =[]
for i in none:
    none_cerrect.append(1-i)
    
act_cerrect =[]
for i in act:
    act_cerrect.append(1-i)

# %%
import matplotlib.pyplot as plt
import numpy as np

labels = class_
none = none
act = act
x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots(figsize=(10, 5))
rects1 = ax.bar(x - width/2, none, width, color=['#75bbfd'], label='BiTNet') #color= '#75bbfd'
rects2 = ax.bar(x + width/2, act, width, color=['#fdaa48'], label='BiTNet+5FPact') #color= '#ffb07c'

ax.set_xticks(x)
# ax.set_xticklabels(labels)
ax.set_xticklabels(labels, fontdict=font)

plt.title('The predicted proportional graph of the wrong predicted model /15AB class \n (Number incorrect prediction per all number prediction in each class)',fontsize=18, fontdict=font, pad=15)
ax.legend()
fig.tight_layout()

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

labels = class_
none = none_cerrect
act = act_cerrect
x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots(figsize=(10, 5))
rects1 = ax.bar(x - width/2, none, width, color=['#75bbfd'], label='BiTNet') #color= '#75bbfd'
rects2 = ax.bar(x + width/2, act, width, color=['#fdaa48'], label='BiTNet+5FPact') #color= '#ffb07c'

ax.set_xticks(x)
# ax.set_xticklabels(labels)
ax.set_xticklabels(labels, fontdict=font)

plt.title('The predicted proportional graph of the cerrect predicted model /15AB class \n (Number cerrect prediction per all number prediction in each class)',fontsize=18, fontdict=font, pad=15)
ax.legend()
fig.tight_layout()

plt.show()

# %% [markdown]
# ### Plot Graph Suspect

# %%
import matplotlib.pyplot as plt
import numpy as np
from pylab import plot, show, title, xlabel, ylabel
from pylab import legend
from pylab import axis

# %%
font = {'family': 'serif',
        'color':  'black',
        'weight': 'normal'}
        
fig, ax = plt.subplots(figsize=(12, 6))
ass = [0.1939, 0.3123, 0.0974]
unass  = [0.2083, 0.3272, 0.0975]
# ai = [0.84,0.84,0.84,0.84]
# X = [[0,0],[0.5,0.5],[1,1],[1.5,1.5]]
# Y = [[0.61,0.35],[0.69,0.5],[0.81,0.75],[0.84,0.64]]
plt.ylim(0.,0.35) 
x = np.arange(0,3,1)  

# plt.plot(x, ai , color='#363737',  linestyle='--', linewidth=2, label='BiTnet model (Acc. 0.84)')

# for i in range(len(X)):
#     plt.plot(X[i], Y[i] , color='#AAA7A7',  linestyle='-', linewidth=4)

plt.plot(x, unass, color='#fec615',  linestyle=' ', marker='o', markeredgecolor='#fec615', markersize=11, label='BiTNet')
plt.plot(x, ass, color='#658cbb',  linestyle=' ', marker='D', markeredgecolor='#658cbb', markersize=10, label='BiTNet+5FPact')

# legend(['Unassisted', 'Assisted'], bbox_to_anchor=(1.17,1.))
plt.title('Proportion of incorrect model prediction (Precision)',fontsize=25, fontdict=font, pad=35) 
plt.xlabel('Class',fontsize=23, fontdict=font,  labelpad=18)
plt.ylabel('Incorrect proportion',fontsize=23, fontdict=font,  labelpad=18)
ax.set_xticks(x)
labels = ['Suspect', 'Non-Suspect','Normal']
ax.set_xticklabels(labels,fontsize=12, fontdict=font)
plt.legend(loc='lower right', prop={'family': 'serif', 'size': 16})

hfont = {'fontname':'serif'}
plt.yticks(fontsize=16, **hfont)
plt.xticks(fontsize=20, **hfont)


plt.grid(True)
show()

# %%
font = {'family': 'serif',
        'color':  'black',
        'weight': 'normal'}
        
fig, ax = plt.subplots(figsize=(12, 6))
ass = [0.8061, 0.6877, 0.9026]
unass  = [0.7917, 0.6728, 0.9025]
# ai = [0.84,0.84,0.84,0.84]
# X = [[0,0],[0.5,0.5],[1,1],[1.5,1.5]]
# Y = [[0.61,0.35],[0.69,0.5],[0.81,0.75],[0.84,0.64]]
plt.ylim(0.6,1) 
x = np.arange(0,3,1)  

# plt.plot(x, ai , color='#363737',  linestyle='--', linewidth=2, label='BiTnet model (Acc. 0.84)')

# for i in range(len(X)):
#     plt.plot(X[i], Y[i] , color='#AAA7A7',  linestyle='-', linewidth=4)

plt.plot(x, unass, color='#fec615',  linestyle=' ', marker='o', markeredgecolor='#fec615', markersize=11, label='BiTNet')
plt.plot(x, ass, color='#658cbb',  linestyle=' ', marker='D', markeredgecolor='#658cbb', markersize=10, label='BiTNet+5FPact')

# legend(['Unassisted', 'Assisted'], bbox_to_anchor=(1.17,1.))
plt.title('Proportion of correct model prediction (Precision)',fontsize=25, fontdict=font, pad=35) 
plt.xlabel('Class',fontsize=23, fontdict=font,  labelpad=18)
plt.ylabel('Correct proportion',fontsize=23, fontdict=font,  labelpad=18)
ax.set_xticks(x)
labels = ['Suspect', 'Non-Suspect','Normal']
ax.set_xticklabels(labels,fontsize=12, fontdict=font)
plt.legend(loc='lower right', prop={'family': 'serif', 'size': 16})

hfont = {'fontname':'serif'}
plt.yticks(fontsize=16, **hfont)
plt.xticks(fontsize=20, **hfont)


plt.grid(True)
show()

# %%
font = {'family': 'serif',
        'color':  'black',
        'weight': 'normal'}
        
fig, ax = plt.subplots(figsize=(12, 6))
ass = [0.1939, 0.1450]
unass  = [0.2083, 0.1488]

plt.ylim(0.,0.35) 
x = np.arange(0,1,0.5)  
plt.plot(x, unass, color='#fec615',  linestyle=' ', marker='o', markeredgecolor='#fec615', markersize=11, label='BiTNet')
plt.plot(x, ass, color='#658cbb',  linestyle=' ', marker='D', markeredgecolor='#658cbb', markersize=10, label='BiTNet+5FPact')

plt.title('Proportion of incorrect model prediction (Precision)',fontsize=25, fontdict=font, pad=35) 
plt.xlabel('Class',fontsize=23, fontdict=font,  labelpad=18)
plt.ylabel('Incorrect proportion',fontsize=23, fontdict=font,  labelpad=18)
ax.set_xticks(x)
labels = ['Suspect', 'Non-Suspect']
ax.set_xticklabels(labels,fontsize=12, fontdict=font)
plt.legend(loc='lower right', prop={'family': 'serif', 'size': 16})

hfont = {'fontname':'serif'}
plt.yticks(fontsize=16, **hfont)
plt.xticks(fontsize=20, **hfont)

plt.grid(True)
show()

# %%
font = {'family': 'serif',
        'color':  'black',
        'weight': 'normal'}
        
fig, ax = plt.subplots(figsize=(12, 6))
ass = [0.8061, 0.8550]
unass  = [0.7917, 0.8512]

plt.ylim(0.6,1) 
x = np.arange(0,2,1)  

plt.plot(x, unass, color='#fec615',  linestyle=' ', marker='o', markeredgecolor='#fec615', markersize=11, label='BiTNet')
plt.plot(x, ass, color='#658cbb',  linestyle=' ', marker='D', markeredgecolor='#658cbb', markersize=10, label='BiTNet+5FPact')

plt.title('Proportion of correct model prediction (Precision)',fontsize=25, fontdict=font, pad=35) 
plt.xlabel('Class',fontsize=23, fontdict=font,  labelpad=18)
plt.ylabel('Correct proportion',fontsize=23, fontdict=font,  labelpad=18)
ax.set_xticks(x)
labels = ['Suspect', 'Non-Suspect']
ax.set_xticklabels(labels,fontsize=12, fontdict=font)
plt.legend(loc='lower right', prop={'family': 'serif', 'size': 16})

hfont = {'fontname':'serif'}
plt.yticks(fontsize=16, **hfont)
plt.xticks(fontsize=20, **hfont)


plt.grid(True)
show()

# %% [markdown]
# ## plot  graph Suspect non-suspect and normal รายเคส

# %%
font = {'family': 'serif',
        'color':  'black',
        'weight': 'normal'}
        
fig, ax = plt.subplots(figsize=(12, 6))
ass = [0.3070, 0.1277, 0.0563]
unass  = [0.2895, 0.1277, 0.0423]

plt.ylim(0.,0.35) 
x = np.arange(0,3,1)  

plt.plot(x, unass, color='#fec615',  linestyle=' ', marker='o', markeredgecolor='#fec615', markersize=11, label='BiTNet')
plt.plot(x, ass, color='#658cbb',  linestyle=' ', marker='D', markeredgecolor='#658cbb', markersize=10, label='BiTNet+5FPact')

plt.title('Proportion of incorrect model prediction (Recall)',fontsize=25, fontdict=font, pad=35) 
plt.xlabel('Class',fontsize=23, fontdict=font,  labelpad=18)
plt.ylabel('Incorrect proportion',fontsize=23, fontdict=font,  labelpad=18)
ax.set_xticks(x)
labels = ['SuspectedCCA', 'Non_SuspectedCCA','Normal']
ax.set_xticklabels(labels,fontsize=12, fontdict=font)
plt.legend(loc='lower right', prop={'family': 'serif', 'size': 16})

hfont = {'fontname':'serif'}
plt.yticks(fontsize=16, **hfont)
plt.xticks(fontsize=20, **hfont)

plt.grid(True)
show()

# %%
font = {'family': 'serif',
        'color':  'black',
        'weight': 'normal'}
        
fig, ax = plt.subplots(figsize=(12, 6))
ass = [0.7105, 0.8723, 0.9577]
unass  = [0.6930, 0.8723, 0.9437]

plt.ylim(0.6,1) 
x = np.arange(0,3,1)  

plt.plot(x, unass, color='#fec615',  linestyle=' ', marker='o', markeredgecolor='#fec615', markersize=11, label='BiTNet')
plt.plot(x, ass, color='#658cbb',  linestyle=' ', marker='D', markeredgecolor='#658cbb', markersize=10, label='BiTNet+5FPact')

plt.title('Proportion of correct model prediction (Recall)',fontsize=25, fontdict=font, pad=35) 
plt.xlabel('Class',fontsize=23, fontdict=font,  labelpad=18)
plt.ylabel('Correct proportion',fontsize=23, fontdict=font,  labelpad=18)
ax.set_xticks(x)
labels = ['SuspectedCCA', 'Non_SuspectedCCA','Normal']
ax.set_xticklabels(labels,fontsize=12, fontdict=font)
plt.legend(loc='lower right', prop={'family': 'serif', 'size': 16})

hfont = {'fontname':'serif'}
plt.yticks(fontsize=16, **hfont)
plt.xticks(fontsize=20, **hfont)

plt.grid(True)
show()

# %%
font = {'family': 'serif',
        'color':  'black',
        'weight': 'normal'}
        
fig, ax = plt.subplots(figsize=(12, 6))
ass = [0.0595, 0.0291, 0.4274]
unass  = [0.0595, 0.0465, 0.4274]

plt.ylim(0.,0.5) 
x = np.arange(0,3,1)  

plt.plot(x, unass, color='#fec615',  linestyle=' ', marker='o', markeredgecolor='#fec615', markersize=11, label='BiTNet')
plt.plot(x, ass, color='#658cbb',  linestyle=' ', marker='D', markeredgecolor='#658cbb', markersize=10, label='BiTNet+5FPact')

plt.title('Proportion of incorrect model prediction (Preadiction)',fontsize=25, fontdict=font, pad=35) 
plt.xlabel('Class',fontsize=23, fontdict=font,  labelpad=18)
plt.ylabel('Incorrect proportion',fontsize=23, fontdict=font,  labelpad=18)
ax.set_xticks(x)
labels = ['SuspectedCCA', 'Non_SuspectedCCA','Normal']
ax.set_xticklabels(labels,fontsize=12, fontdict=font)
plt.legend(loc='lower right', prop={'family': 'serif', 'size': 16})

hfont = {'fontname':'serif'}
plt.yticks(fontsize=16, **hfont)
plt.xticks(fontsize=20, **hfont)

plt.grid(True)
show()

# %%
font = {'family': 'serif',
        'color':  'black',
        'weight': 'normal'}
        
fig, ax = plt.subplots(figsize=(12, 6))
ass = [0.9405, 0.9709, 0.5726]
unass  = [0.9405, 0.9535, 0.5726]

plt.ylim(0.6,1) 
x = np.arange(0,3,1)  

plt.plot(x, unass, color='#fec615',  linestyle=' ', marker='o', markeredgecolor='#fec615', markersize=11, label='BiTNet')
plt.plot(x, ass, color='#658cbb',  linestyle=' ', marker='D', markeredgecolor='#658cbb', markersize=10, label='BiTNet+5FPact')

plt.title('Proportion of incorrect model prediction (Preadiction)',fontsize=25, fontdict=font, pad=35) 
plt.xlabel('Class',fontsize=23, fontdict=font,  labelpad=18)
plt.ylabel('Incorrect proportion',fontsize=23, fontdict=font,  labelpad=18)
ax.set_xticks(x)
labels = ['SuspectedCCA', 'Non_SuspectedCCA','Normal']
ax.set_xticklabels(labels,fontsize=12, fontdict=font)
plt.legend(loc='lower right', prop={'family': 'serif', 'size': 16})

hfont = {'fontname':'serif'}
plt.yticks(fontsize=16, **hfont)
plt.xticks(fontsize=20, **hfont)

plt.grid(True)
show()

# %% [markdown]
# ## plot graph Suspect non-suspect and normal รายรูป

# %%
font = {'family': 'serif',
        'color':  'black',
        'weight': 'normal'}
        
fig, ax = plt.subplots(figsize=(12, 6))
ass = [0.3521, 0.1597, 0.0047]
unass  = [0.3662, 0.1597, 0.0058]

plt.ylim(0.,0.4) 
x = np.arange(0,3,1)  

plt.plot(x, unass, color='#fec615',  linestyle=' ', marker='o', markeredgecolor='#fec615', markersize=11, label='BiTNet')
plt.plot(x, ass, color='#658cbb',  linestyle=' ', marker='D', markeredgecolor='#658cbb', markersize=10, label='BiTNet+5FPact')

plt.title('Proportion of incorrect model prediction (Recall)',fontsize=25, fontdict=font, pad=35) 
plt.xlabel('Class',fontsize=23, fontdict=font,  labelpad=18)
plt.ylabel('Incorrect proportion',fontsize=23, fontdict=font,  labelpad=18)
ax.set_xticks(x)
labels = ['SuspectedCCA', 'Non_SuspectedCCA','Normal']
ax.set_xticklabels(labels,fontsize=12, fontdict=font)
plt.legend(loc='lower right', prop={'family': 'serif', 'size': 16})

hfont = {'fontname':'serif'}
plt.yticks(fontsize=16, **hfont)
plt.xticks(fontsize=20, **hfont)

plt.grid(True)
show()

# %%
font = {'family': 'serif',
        'color':  'black',
        'weight': 'normal'}
        
fig, ax = plt.subplots(figsize=(12, 6))
ass = [1-0.3521, 1-0.1597, 1-0.0047]
unass  = [1-0.3662, 1-0.1597, 1-0.0058]

plt.ylim(0.6,1) 
x = np.arange(0,3,1)  

plt.plot(x, unass, color='#fec615',  linestyle=' ', marker='o', markeredgecolor='#fec615', markersize=11, label='BiTNet')
plt.plot(x, ass, color='#658cbb',  linestyle=' ', marker='D', markeredgecolor='#658cbb', markersize=10, label='BiTNet+5FPact')

plt.title('Proportion of correct model prediction (Recall)',fontsize=25, fontdict=font, pad=35) 
plt.xlabel('Class',fontsize=23, fontdict=font,  labelpad=18)
plt.ylabel('Correct proportion',fontsize=23, fontdict=font,  labelpad=18)
ax.set_xticks(x)
labels = ['SuspectedCCA', 'Non_SuspectedCCA','Normal']
ax.set_xticklabels(labels,fontsize=12, fontdict=font)
plt.legend(loc='lower right', prop={'family': 'serif', 'size': 16})

hfont = {'fontname':'serif'}
plt.yticks(fontsize=16, **hfont)
plt.xticks(fontsize=20, **hfont)

plt.grid(True)
show()

# %%
font = {'family': 'serif',
        'color':  'black',
        'weight': 'normal'}
        
fig, ax = plt.subplots(figsize=(12, 6))
ass = [0.0612, 0.0223, 0.0974]
unass  = [0.0625, 0.0331, 0.0975]

plt.ylim(0.,0.5) 
x = np.arange(0,3,1)  

plt.plot(x, unass, color='#fec615',  linestyle=' ', marker='o', markeredgecolor='#fec615', markersize=11, label='BiTNet')
plt.plot(x, ass, color='#658cbb',  linestyle=' ', marker='D', markeredgecolor='#658cbb', markersize=10, label='BiTNet+5FPact')

plt.title('Proportion of incorrect model prediction (Precision)',fontsize=25, fontdict=font, pad=35) 
plt.xlabel('Class',fontsize=23, fontdict=font,  labelpad=18)
plt.ylabel('Incorrect proportion',fontsize=23, fontdict=font,  labelpad=18)
ax.set_xticks(x)
labels = ['SuspectedCCA', 'Non_SuspectedCCA','Normal']
ax.set_xticklabels(labels,fontsize=12, fontdict=font)
plt.legend(loc='upper right', prop={'family': 'serif', 'size': 16})

hfont = {'fontname':'serif'}
plt.yticks(fontsize=16, **hfont)
plt.xticks(fontsize=20, **hfont)

plt.grid(True)
show()

# %%
font = {'family': 'serif',
        'color':  'black',
        'weight': 'normal'}
        
fig, ax = plt.subplots(figsize=(12, 6))
ass = [1-0.0612, 1-0.0223, 1-0.0974]
unass  = [1-0.0625, 1-0.0331, 1-0.0975]

plt.ylim(0.6,1) 
x = np.arange(0,3,1)  

plt.plot(x, unass, color='#fec615',  linestyle=' ', marker='o', markeredgecolor='#fec615', markersize=11, label='BiTNet')
plt.plot(x, ass, color='#658cbb',  linestyle=' ', marker='D', markeredgecolor='#658cbb', markersize=10, label='BiTNet+5FPact')

plt.title('Proportion of correct model prediction (Precision)',fontsize=25, fontdict=font, pad=35) 
plt.xlabel('Class',fontsize=23, fontdict=font,  labelpad=18)
plt.ylabel('Correct proportion',fontsize=23, fontdict=font,  labelpad=18)
ax.set_xticks(x)
labels = ['SuspectedCCA', 'Non_SuspectedCCA','Normal']
ax.set_xticklabels(labels,fontsize=12, fontdict=font)
plt.legend(loc='lower right', prop={'family': 'serif', 'size': 16})

hfont = {'fontname':'serif'}
plt.yticks(fontsize=16, **hfont)
plt.xticks(fontsize=20, **hfont)

plt.grid(True)
show()

# %% [markdown]
# ## plot graph Suspect non-suspect  รายเคส

# %%
font = {'family': 'serif',
        'color':  'black',
        'weight': 'normal'}
        
fig, ax = plt.subplots(figsize=(12, 6))
ass = [0.9405, 0.8858]
unass  = [0.9405, 0.8789]

plt.ylim(0.6,1) 
x = np.arange(0,2,1)  

plt.plot(x, unass, color='#fec615',  linestyle=' ', marker='o', markeredgecolor='#fec615', markersize=11, label='BiTNet')
plt.plot(x, ass, color='#658cbb',  linestyle=' ', marker='D', markeredgecolor='#658cbb', markersize=10, label='BiTNet+5FPact')

plt.title('Proportion of correct model prediction (Precision)',fontsize=25, fontdict=font, pad=35) 
plt.xlabel('Class',fontsize=23, fontdict=font,  labelpad=18)
plt.ylabel('Correct proportion',fontsize=23, fontdict=font,  labelpad=18)
ax.set_xticks(x)
labels = ['Suspect', 'Non-Suspect']
ax.set_xticklabels(labels,fontsize=12, fontdict=font)
plt.legend(loc='lower right', prop={'family': 'serif', 'size': 16})

hfont = {'fontname':'serif'}
plt.yticks(fontsize=16, **hfont)
plt.xticks(fontsize=20, **hfont)


plt.grid(True)
show()

# %%
font = {'family': 'serif',
        'color':  'black',
        'weight': 'normal'}
        
fig, ax = plt.subplots(figsize=(12, 6))
ass = [1-0.9405, 1-0.8858]
unass  = [1-0.9405, 1-0.8789]

plt.ylim(0.,0.35) 
x = np.arange(0,2,1)  

plt.plot(x, unass, color='#fec615',  linestyle=' ', marker='o', markeredgecolor='#fec615', markersize=11, label='BiTNet')
plt.plot(x, ass, color='#658cbb',  linestyle=' ', marker='D', markeredgecolor='#658cbb', markersize=10, label='BiTNet+5FPact')

plt.title('Proportion of incorrect model prediction (Precision)',fontsize=25, fontdict=font, pad=35) 
plt.xlabel('Class',fontsize=23, fontdict=font,  labelpad=18)
plt.ylabel('Incorrect proportion',fontsize=23, fontdict=font,  labelpad=18)
ax.set_xticks(x)
labels = ['Suspect', 'Non-Suspect']
ax.set_xticklabels(labels,fontsize=12, fontdict=font)
plt.legend(loc='lower right', prop={'family': 'serif', 'size': 16})

hfont = {'fontname':'serif'}
plt.yticks(fontsize=16, **hfont)
plt.xticks(fontsize=20, **hfont)


plt.grid(True)
show()

# %%
font = {'family': 'serif',
        'color':  'black',
        'weight': 'normal'}
        
fig, ax = plt.subplots(figsize=(12, 6))
ass = [0.0439, 0.1274]
unass  = [0.0439, 0.1351]

plt.ylim(0.,0.35) 
x = np.arange(0,2,1)  

plt.plot(x, unass, color='#fec615',  linestyle=' ', marker='o', markeredgecolor='#fec615', markersize=11, label='BiTNet')
plt.plot(x, ass, color='#658cbb',  linestyle=' ', marker='D', markeredgecolor='#658cbb', markersize=10, label='BiTNet+5FPact')

plt.title('Proportion of incorrect model prediction (Recall)',fontsize=25, fontdict=font, pad=35) 
plt.xlabel('Class',fontsize=23, fontdict=font,  labelpad=18)
plt.ylabel('Incorrect proportion',fontsize=23, fontdict=font,  labelpad=18)
ax.set_xticks(x)
labels = ['Suspect', 'Non-Suspect']
ax.set_xticklabels(labels,fontsize=12, fontdict=font)
plt.legend(loc='upper right', prop={'family': 'serif', 'size': 16})

hfont = {'fontname':'serif'}
plt.yticks(fontsize=16, **hfont)
plt.xticks(fontsize=20, **hfont)


plt.grid(True)
show()

# %%
font = {'family': 'serif',
        'color':  'black',
        'weight': 'normal'}
        
fig, ax = plt.subplots(figsize=(12, 6))
ass = [1-0.0439, 1-0.1274]
unass  = [1-0.0439, 1-0.1351]

plt.ylim(0.6,1) 
x = np.arange(0,2,1)  

plt.plot(x, unass, color='#fec615',  linestyle=' ', marker='o', markeredgecolor='#fec615', markersize=11, label='BiTNet')
plt.plot(x, ass, color='#658cbb',  linestyle=' ', marker='D', markeredgecolor='#658cbb', markersize=10, label='BiTNet+5FPact')

plt.title('Proportion of correct model prediction (Recall)',fontsize=25, fontdict=font, pad=35) 
plt.xlabel('Class',fontsize=23, fontdict=font,  labelpad=18)
plt.ylabel('Correct proportion',fontsize=23, fontdict=font,  labelpad=18)
ax.set_xticks(x)
labels = ['Suspect', 'Non-Suspect']
ax.set_xticklabels(labels,fontsize=12, fontdict=font)
plt.legend(loc='lower right', prop={'family': 'serif', 'size': 16})

hfont = {'fontname':'serif'}
plt.yticks(fontsize=16, **hfont)
plt.xticks(fontsize=20, **hfont)


plt.grid(True)
show()

# %% [markdown]
# ## plot graph Suspect non-suspect รายรูป

# %%
font = {'family': 'serif',
        'color':  'black',
        'weight': 'normal'}
        
fig, ax = plt.subplots(figsize=(12, 6))
ass = [1-0.0427, 1-0.0423]
unass  = [1-0.0444, 1-0.0423]

plt.ylim(0.6,1) 
x = np.arange(0,2,1)  

plt.plot(x, unass, color='#fec615',  linestyle=' ', marker='o', markeredgecolor='#fec615', markersize=11, label='BiTNet')
plt.plot(x, ass, color='#658cbb',  linestyle=' ', marker='D', markeredgecolor='#658cbb', markersize=10, label='BiTNet+5FPact')

plt.title('Proportion of correct model prediction (Recall)',fontsize=25, fontdict=font, pad=35) 
plt.xlabel('Class',fontsize=23, fontdict=font,  labelpad=18)
plt.ylabel('Correct proportion',fontsize=23, fontdict=font,  labelpad=18)
ax.set_xticks(x)
labels = ['Suspect', 'Non-Suspect']
ax.set_xticklabels(labels,fontsize=12, fontdict=font)
plt.legend(loc='lower right', prop={'family': 'serif', 'size': 16})

hfont = {'fontname':'serif'}
plt.yticks(fontsize=16, **hfont)
plt.xticks(fontsize=20, **hfont)


plt.grid(True)
show()

# %%
font = {'family': 'serif',
        'color':  'black',
        'weight': 'normal'}
        
fig, ax = plt.subplots(figsize=(12, 6))

ass = [0.0427, 0.0423]
unass  = [0.0444, 0.0423]
plt.ylim(0.,0.35) 
x = np.arange(0,2,1)  

plt.plot(x, unass, color='#fec615',  linestyle=' ', marker='o', markeredgecolor='#fec615', markersize=11, label='BiTNet')
plt.plot(x, ass, color='#658cbb',  linestyle=' ', marker='D', markeredgecolor='#658cbb', markersize=10, label='BiTNet+5FPact')

plt.title('Proportion of incorrect model prediction (Recall)',fontsize=25, fontdict=font, pad=35) 
plt.xlabel('Class',fontsize=23, fontdict=font,  labelpad=18)
plt.ylabel('Incorrect proportion',fontsize=23, fontdict=font,  labelpad=18)
ax.set_xticks(x)
labels = ['Suspect', 'Non-Suspect']
ax.set_xticklabels(labels,fontsize=12, fontdict=font)
plt.legend(loc='upper right', prop={'family': 'serif', 'size': 16})

hfont = {'fontname':'serif'}
plt.yticks(fontsize=16, **hfont)
plt.xticks(fontsize=20, **hfont)


plt.grid(True)
show()

# %%
font = {'family': 'serif',
        'color':  'black',
        'weight': 'normal'}
        
fig, ax = plt.subplots(figsize=(12, 6))
ass = [1-0.0612, 1-0.0412]
unass  = [1-0.0625, 1-0.0428]

plt.ylim(0.6,1) 
x = np.arange(0,2,1)  

plt.plot(x, unass, color='#fec615',  linestyle=' ', marker='o', markeredgecolor='#fec615', markersize=11, label='BiTNet')
plt.plot(x, ass, color='#658cbb',  linestyle=' ', marker='D', markeredgecolor='#658cbb', markersize=10, label='BiTNet+5FPact')

plt.title('Proportion of correct model prediction (Precision)',fontsize=25, fontdict=font, pad=35) 
plt.xlabel('Class',fontsize=23, fontdict=font,  labelpad=18)
plt.ylabel('Correct proportion',fontsize=23, fontdict=font,  labelpad=18)
ax.set_xticks(x)
labels = ['Suspect', 'Non-Suspect']
ax.set_xticklabels(labels,fontsize=12, fontdict=font)
plt.legend(loc='lower right', prop={'family': 'serif', 'size': 16})

hfont = {'fontname':'serif'}
plt.yticks(fontsize=16, **hfont)
plt.xticks(fontsize=20, **hfont)


plt.grid(True)
show()

# %%
font = {'family': 'serif',
        'color':  'black',
        'weight': 'normal'}
        
fig, ax = plt.subplots(figsize=(12, 6))
ass = [0.0612, 0.0412]
unass  = [0.0625, 0.0428]

plt.ylim(0.,0.35) 
x = np.arange(0,2,1)  

plt.plot(x, unass, color='#fec615',  linestyle=' ', marker='o', markeredgecolor='#fec615', markersize=11, label='BiTNet')
plt.plot(x, ass, color='#658cbb',  linestyle=' ', marker='D', markeredgecolor='#658cbb', markersize=10, label='BiTNet+5FPact')

plt.title('Proportion of incorrect model prediction (Precision)',fontsize=25, fontdict=font, pad=35) 
plt.xlabel('Class',fontsize=23, fontdict=font,  labelpad=18)
plt.ylabel('Incorrect proportion',fontsize=23, fontdict=font,  labelpad=18)
ax.set_xticks(x)
labels = ['Suspect', 'Non-Suspect']
ax.set_xticklabels(labels,fontsize=12, fontdict=font)
plt.legend(loc='upper right', prop={'family': 'serif', 'size': 16})

hfont = {'fontname':'serif'}
plt.yticks(fontsize=16, **hfont)
plt.xticks(fontsize=20, **hfont)


plt.grid(True)
show()
