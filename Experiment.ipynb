# %%
import pandas as pd
import os
import glob

# %%
file1 = [os.path.basename(x) for x in glob.glob(r'/media/tohn/HDD/VISION_dataset/USAI/test/all/' + '*')]
file1
# Out:
# ['116_P7.1C183.jpg',
#  '127_P8.Case 225.JPG',
#  '42_AB082 P3-1 C044.JPG',
#  '123_P7-2.Case 246.JPG',
#  '15_AB05 P5-1 C058.JPG',
#  '56_P2.Case 246.JPG',
#  '16_AB6 A9 P1.Case A9.JPG.png',
#  '53_P1.Case 310.JPG',
#  '58_P2.Case 260.JPG',
#  '14_AB05 P4-2 C040.JPG',
#  '144_P8C162.jpg',
#  '142_P8C150.jpg',
#  '75_P4-2.Case 247.JPG',
#  '73_P4-1.Case 329.JPG',
#  '27_AB09 P6-1 C086 .JPG',
#  '101_P6.Case 341.JPG',
#  '6_AB02 P5-1 C009.JPG',
#  '138_P8C068.jpg',
#  '147_P8_Case_007.jpg',
#  '48_P1.Case 261.JPG',
#  '72_P4-1.Case 327.JPG',
#  '31_AB11 A8 P5-2.Case A8.JPG.png',
#  '137_P8.Case 341.JPG',
#  '128_P8.Case 244.JPG',
#  '77_P4-2.Case 284.JPG',
#  '80_P4-2.Case 308.JPG',
#  '146_P8C193.jpg',
#  '109_P6-2.Case 260.JPG',
#  '98_P6.Case 308.JPG',
#  '71_P3-1.Case 350.JPG',
#  '24_AB083 P5-1 C001.JPG',
#  '149_P8_Case_029.jpg',
#  '21_AB07 P5-1 C032.JPG',
#  '28_AB10 P6-1 C009.JPG',
#  '108_P6-1.Case 329.JPG',
#  '131_P8.Case 284.JPG',
#  '18_AB06 P3-1 C002.JPG',
# ...

# %%
# os.chdir('/media/tohn/HDD/VISION_dataset/USAI/test/all/') 
# imglist = glob.glob("*")
# imglist

# %%
Table = list()
for j in file1 :
    a = j.split('_')
    print(len(a))
    if len(a) ==2:
        Num = a[0]
        File = a[1]
        Table.append({'num':Num,'FileName':File})
    elif len(a) ==3:
        Num = a[0]
        File = a[1]+'_'+a[2]
        Table.append({'num':Num,'FileName':File})
    elif len(a) ==4:
        Num = a[0]
        File = a[1]+'_'+a[2]+'_'+a[3]
        Table.append({'num':Num,'FileName':File})
# Out:
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 4
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 4
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 4
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 3
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 4
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2

# %%
Table1 = pd.DataFrame(Table)
Table1
# Out:
#      num             FileName
# 0    116         P7.1C183.jpg
# 1    127      P8.Case 225.JPG
# 2     42  AB082 P3-1 C044.JPG
# 3    123    P7-2.Case 246.JPG
# 4     15   AB05 P5-1 C058.JPG
# ..   ...                  ...
# 145  114    P6-2.Case 310.JPG
# 146   19     AB07 P1 C001.JPG
# 147  132      P8.Case 296.JPG
# 148  126      P8.Case 207.JPG
# 149   62      P2.Case 308.JPG
#
# [150 rows x 2 columns]

# %%
Table1['num'] = Table1['num'].astype(int)

# %%
Table1 = Table1.sort_values(by=['num'])
Table1 = Table1.replace({'FileName': {'AB11 FP D P7-2 Case 164.JPG.png': 'FP D P7-2 Case 164.JPG.png', 'AB11 FP D P7-2 Case 262.JPG.png': 'FP D P7-2 Case 262.JPG.png','AB12 FP D P7-1 Case 052.JPG.png': 'FP D P7-1 Case 052.JPG.png','AB12 P7-1 C004.JPG':'AB04 P7-1 C004.JPG','AB12 P7-1 C032.JPG':'AB04 P7-1 C032.JPG'}})
Table1
# Out:
#      num            FileName
# 142    1    AB01 P1 C100.JPG
# 136    2  AB01 P4-2 C050.JPG
# 123    3  AB01 P5-2 C004.JPG
# 49     4    AB02 P1 C001.JPG
# 115    5  AB02 P3-1 C001.JPG
# ..   ...                 ...
# 26   146          P8C193.jpg
# 18   147     P8_Case_007.jpg
# 125  148     P8_Case_025.jpg
# 31   149     P8_Case_029.jpg
# 61   150     P8_Case_032.jpg
#
# [150 rows x 2 columns]

# %%
os.chdir( '/home/yupaporn/codes/USAI/')
Table1.to_csv('filename_num.csv')

# %%
import pandas as pd
df = pd.read_csv( '/home/yupaporn/codes/USAI/Web.csv')

# %%
df
# Out:
#      Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1 sub_class views  \
# 0             0             0               0      AB01  FP-A
# 1             1             1               7      AB01  FP-B
# 2             2             2               9      AB01  FP-C
# 3             3             3              13      AB02  FP-A
# 4             4             4              17      AB02  FP-B
# ..          ...           ...             ...       ...   ...
# 145         145           103             276    Normal  FP-E
# 146         146           104             261    Normal  FP-E
# 147         147           105             263    Normal  FP-E
# 148         148           106             259    Normal  FP-E
# 149         149           107             258    Normal  FP-E
#
#                                               img_path  \
# 0    /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 1    /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# ...

# %%
result = pd.merge(Table1, df, how='left', on=['FileName'])
result
# Out:
#      num            FileName  Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  \
# 0      1    AB01 P1 C100.JPG           0             0               0
# 1      2  AB01 P4-2 C050.JPG           1             1               7
# 2      3  AB01 P5-2 C004.JPG           2             2               9
# 3      4    AB02 P1 C001.JPG           3             3              13
# 4      5  AB02 P3-1 C001.JPG           4             4              17
# ..   ...                 ...         ...           ...             ...
# 145  146          P8C193.jpg         126            84             266
# 146  147     P8_Case_007.jpg         130            88             277
# 147  148     P8_Case_025.jpg         131            89             274
# 148  149     P8_Case_029.jpg         145           103             276
# 149  150     P8_Case_032.jpg         128            86             275
#
#     sub_class views                                           img_path  \
# ...

# %%
set(Table1['FileName']) - set(df['FileName'])
# Out:
# set()

# %%
set(df['FileName']) - set(Table1['FileName'])
# Out:
# set()

# %%
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 150 entries, 0 to 149
# Data columns (total 22 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   num             150 non-null    int64
#  1   FileName        150 non-null    object
#  2   Unnamed: 0      150 non-null    int64
#  3   Unnamed: 0.1    150 non-null    int64
#  4   Unnamed: 0.1.1  150 non-null    int64
#  5   sub_class       150 non-null    object
#  6   views           150 non-null    object
#  7   img_path        150 non-null    object
#  8   originalImage   150 non-null    object
#  9   tagName1        150 non-null    object
#  10  tagName2        150 non-null    object
#  11  Class           150 non-null    object
#  12  Case            150 non-null    int64
#  13  Abs Position    150 non-null    object
#  14  Sub_class       150 non-null    object
#  15  Path Full       150 non-null    object
#  16  fold            150 non-null    int64
# ...

# %%
# os.chdir( '/home/yupaporn/codes/USAI/')
# result.to_csv('filename_num.csv')

# %%
exp= pd.read_csv( '/home/yupaporn/codes/USAI/Experiment1.csv')
exp
# Out:
#                FileName                   U10_Pred                   U11_Pred
# 0      AB01 P1 C100.JPG                     Normal  AB02 : ModerateFattyLiver
# 1    AB01 P4-2 C050.JPG                     Normal  AB02 : ModerateFattyLiver
# 2    AB01 P5-2 C004.JPG    AB03 : SevereFattyLiver  AB02 : ModerateFattyLiver
# 3      AB02 P1 C001.JPG  AB02 : ModerateFattyLiver  AB02 : ModerateFattyLiver
# 4    AB02 P3-1 C001.JPG      AB082 : BDD, IHDStone      AB01 : MildFattyLiver
# ..                  ...                        ...                        ...
# 145          P8C193.jpg                     Normal                     Normal
# 146     P8_Case_007.jpg                     Normal                     Normal
# 147     P8_Case_025.jpg                     Normal                     Normal
# 148     P8_Case_029.jpg                     Normal                     Normal
# 149     P8_Case_032.jpg                     Normal                     Normal
#
# [150 rows x 3 columns]

# %%
U10 = exp['U10_Pred'].tolist()
Table = list()
for j in U10 :
    A = j.replace(' ','')
    a = A.split(':')
    Num = a[0]
    Table.append({'U10_Pred':Num})

# %%
U11 = exp['U11_Pred'].tolist()
Table1 = list()
for j in U11 :
    A = j.replace(' ','')
    a = A.split(':')
    Num = a[0]
    Table1.append({'U11_Pred':Num})

# %%
Table_1 = pd.DataFrame(Table)
Table_2 = pd.DataFrame(Table1)
result['U10_Pred'] = Table_1
result['U11_Pred'] = Table_2

# %%
result = result.drop(['Unnamed: 0', 'Unnamed: 0.1','Unnamed: 0.1.1'], axis=1)
result
# Out:
#      num            FileName sub_class views  \
# 0      1    AB01 P1 C100.JPG      AB01  FP-A
# 1      2  AB01 P4-2 C050.JPG      AB01  FP-B
# 2      3  AB01 P5-2 C004.JPG      AB01  FP-C
# 3      4    AB02 P1 C001.JPG      AB02  FP-A
# 4      5  AB02 P3-1 C001.JPG      AB02  FP-B
# ..   ...                 ...       ...   ...
# 145  146          P8C193.jpg    Normal  FP-E
# 146  147     P8_Case_007.jpg    Normal  FP-E
# 147  148     P8_Case_025.jpg    Normal  FP-E
# 148  149     P8_Case_029.jpg    Normal  FP-E
# 149  150     P8_Case_032.jpg    Normal  FP-E
#
#                                               img_path  \
# 0    /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 1    /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2    /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 3    /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 4    /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# ..                                                 ...
# ...

# %%
result = result.drop(['sub_class.1', 'views.1'], axis=1)

# %%
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 150 entries, 0 to 149
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   num            150 non-null    int64
#  1   FileName       150 non-null    object
#  2   sub_class      150 non-null    object
#  3   views          150 non-null    object
#  4   img_path       150 non-null    object
#  5   originalImage  150 non-null    object
#  6   tagName1       150 non-null    object
#  7   tagName2       150 non-null    object
#  8   Class          150 non-null    object
#  9   Case           150 non-null    int64
#  10  Abs Position   150 non-null    object
#  11  Sub_class      150 non-null    object
#  12  Path Full      150 non-null    object
#  13  fold           150 non-null    int64
#  14  AI_Pred        150 non-null    object
#  15  U10_Pred       150 non-null    object
#  16  U11_Pred       150 non-null    object
# dtypes: int64(3), object(14)
# ...

# %%
# result = result.drop(['sub_class.1', 'views.1'], axis=1)
os.chdir( '/home/yupaporn/codes/USAI/')
result.to_csv('Experiment.csv')

# %%
import numpy as np
from sklearn.metrics import confusion_matrix
act = result['AI_Pred'].array
pred = result['U11_Pred'].array

cmat = confusion_matrix(act, pred)
print('classifier accuracy = {}%'.format((100.*np.trace(cmat))/(np.sum(cmat))))

#Marking the Confusion Matrix
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(act, pred))#performance
# Out:
# classifier accuracy = 85.33333333333333%
#               precision    recall  f1-score   support
#
#         AB01       0.50      0.50      0.50         2
#         AB02       0.62      1.00      0.77         5
#         AB03       1.00      0.50      0.67         2
#         AB04       0.80      0.80      0.80         5
#         AB05       0.25      1.00      0.40         2
#         AB06       0.00      0.00      0.00         2
#        AB081       0.67      0.40      0.50         5
#        AB082       0.50      0.50      0.50         4
#        AB083       0.50      1.00      0.67         1
#         AB09       1.00      1.00      1.00         3
#         AB10       0.50      1.00      0.67         2
#         AB11       0.20      1.00      0.33         1
#         AB12       1.00      0.67      0.80         3
#       Normal       1.00      0.90      0.95       113
#
#     accuracy                           0.85       150
#    macro avg       0.61      0.73      0.61       150
# ...

# %%
#create CF 
data = {'Actual': act,'Predicted' : pred,}
df = pd.DataFrame(data, columns=['Actual','Predicted'])
conf_mat = pd.crosstab(df['Actual'],df['Predicted'],rownames=['Actual'],colnames=['Predicted'])

#Confusion matrix
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
cm = confusion_matrix(act, pred)

#plot Confusion matrix
import seaborn as sns
sns.set()
fig, ax = plt.subplots(figsize=(8, 5))

ax = sns.heatmap(conf_mat, annot=True, fmt="d", cmap="YlGnBu") #Blues,Oranges,Reds
ax.set_title('Confusion matrix',fontsize=20)
ax.set_ylabel('AI label',fontsize=18)
ax.set_xlabel('U11 label',fontsize=18)
# Out:
# Text(0.5, 21.5, 'U11 label')

# %%
act= result['AI_Pred'].map({'AB12':1, 'AB04':1, 'AB05':1, 'Normal':0, 'AB02':1, 'AB11':1, 'AB082':1, 'AB06':1, 'AB081':1, 'AB09':1, 'AB03':1, 'AB10':1, 'AB01':1, 'AB083':1}).values
pred = result['U11_Pred'].map({'AB12':1, 'AB04':1, 'AB05':1, 'Normal':0, 'AB02':1, 'AB11':1, 'AB082':1, 'AB06':1, 'AB081':1, 'AB09':1, 'AB03':1, 'AB10':1, 'AB01':1, 'AB083':1}).values
cmat = confusion_matrix(act, pred)
print('classifier accuracy = {}%'.format((100.*np.trace(cmat))/(np.sum(cmat))))

#Marking the Confusion Matrix
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(act, pred))#performance
# Out:
# classifier accuracy = 92.66666666666667%
#               precision    recall  f1-score   support
#
#            0       1.00      0.90      0.95       113
#            1       0.77      1.00      0.87        37
#
#     accuracy                           0.93       150
#    macro avg       0.89      0.95      0.91       150
# weighted avg       0.94      0.93      0.93       150

# %%
#create CF 
data = {'Actual': act,'Predicted' : pred,}
df = pd.DataFrame(data, columns=['Actual','Predicted'])
conf_mat = pd.crosstab(df['Actual'],df['Predicted'],rownames=['Actual'],colnames=['Predicted'])

#Confusion matrix
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
cm = confusion_matrix(act, pred)

#plot Confusion matrix
import seaborn as sns
sns.set()
fig, ax = plt.subplots(figsize=(8, 5))

ax = sns.heatmap(conf_mat, annot=True, fmt="d", cmap="YlGnBu") #Blues,Oranges,Reds
ax.set_title('Confusion matrix',fontsize=20)
ax.set_ylabel('True label',fontsize=18)
ax.set_xlabel('Predicted label',fontsize=18)
# Out:
# Text(0.5, 21.5, 'Predicted label')

# %% [markdown]
# # U10_Pred

# %%
import numpy as np
from sklearn.metrics import confusion_matrix
act = result['sub_class.1'].array
pred = result['U10_Pred'].array

cmat = confusion_matrix(act, pred)
print('classifier accuracy = {}%'.format((100.*np.trace(cmat))/(np.sum(cmat))))

#Marking the Confusion Matrix
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(act, pred))#performance
# Out:
# classifier accuracy = 36.666666666666664%
#               precision    recall  f1-score   support
#
#         AB01       0.00      0.00      0.00         3
#         AB02       0.04      0.33      0.07         3
#         AB03       0.00      0.00      0.00         3
#         AB04       0.00      0.00      0.00         3
#         AB05       0.00      0.00      0.00         3
#         AB06       0.25      0.33      0.29         3
#         AB07       0.00      0.00      0.00         3
#        AB081       0.18      0.67      0.29         3
#        AB082       0.00      0.00      0.00         3
#        AB083       0.25      0.33      0.29         3
#         AB09       1.00      0.33      0.50         3
#         AB10       0.43      1.00      0.60         3
#         AB11       0.16      1.00      0.27         3
#         AB12       1.00      1.00      1.00         3
#       Normal       0.87      0.37      0.52       108
#
#     accuracy                           0.37       150
# ...

# %%
#create CF 
data = {'Actual': act,'Predicted' : pred,}
df = pd.DataFrame(data, columns=['Actual','Predicted'])
conf_mat = pd.crosstab(df['Actual'],df['Predicted'],rownames=['Actual'],colnames=['Predicted'])

#Confusion matrix
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
cm = confusion_matrix(act, pred)

#plot Confusion matrix
import seaborn as sns
sns.set()
fig, ax = plt.subplots(figsize=(8, 5))

ax = sns.heatmap(conf_mat, annot=True, fmt="d", cmap="YlGnBu") #Blues,Oranges,Reds
ax.set_title('Confusion matrix',fontsize=20)
ax.set_ylabel('True label',fontsize=18)
ax.set_xlabel('Predicted label',fontsize=18)
# Out:
# Text(0.5, 21.5, 'Predicted label')

# %%
act= result['Class'].map({'Normal':0,'Abnormal':1}).values
pred = result['U10_Pred'].map({'AB12':1, 'AB04':1, 'AB05':1, 'Normal':0, 'AB02':1, 'AB11':1, 'AB082':1, 'AB06':1, 'AB081':1, 'AB09':1, 'AB03':1, 'AB10':1, 'AB01':1, 'AB083':1}).values

# %%
cmat = confusion_matrix(act, pred)
print('classifier accuracy = {}%'.format((100.*np.trace(cmat))/(np.sum(cmat))))

#Marking the Confusion Matrix
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(act, pred))#performance
# Out:
# classifier accuracy = 50.666666666666664%
#               precision    recall  f1-score   support
#
#            0       0.87      0.37      0.52       108
#            1       0.35      0.86      0.49        42
#
#     accuracy                           0.51       150
#    macro avg       0.61      0.61      0.51       150
# weighted avg       0.72      0.51      0.51       150

# %%
#create CF 
data = {'Actual': act,'Predicted' : pred,}
df = pd.DataFrame(data, columns=['Actual','Predicted'])
conf_mat = pd.crosstab(df['Actual'],df['Predicted'],rownames=['Actual'],colnames=['Predicted'])

#Confusion matrix
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
cm = confusion_matrix(act, pred)

#plot Confusion matrix
import seaborn as sns
sns.set()
fig, ax = plt.subplots(figsize=(8, 5))

ax = sns.heatmap(conf_mat, annot=True, fmt="d", cmap="YlGnBu") #Blues,Oranges,Reds
ax.set_title('Confusion matrix',fontsize=20)
ax.set_ylabel('True label',fontsize=18)
ax.set_xlabel('Predicted label',fontsize=18)
# Out:
# Text(0.5, 21.5, 'Predicted label')

# %% [markdown]
# # U11_Pred

# %%
import numpy as np
from sklearn.metrics import confusion_matrix
act = result['sub_class.1'].array
pred = result['U11_Pred'].array

cmat = confusion_matrix(act, pred)
print('classifier accuracy = {}%'.format((100.*np.trace(cmat))/(np.sum(cmat))))

#Marking the Confusion Matrix
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(act, pred))#performance
# Out:
# classifier accuracy = 82.0%
#               precision    recall  f1-score   support
#
#         AB01       0.00      0.00      0.00         3
#         AB02       0.25      0.67      0.36         3
#         AB03       1.00      0.33      0.50         3
#         AB04       0.60      1.00      0.75         3
#         AB05       0.25      0.67      0.36         3
#         AB06       0.00      0.00      0.00         3
#         AB07       0.00      0.00      0.00         3
#        AB081       1.00      1.00      1.00         3
#        AB082       0.50      0.67      0.57         3
#        AB083       0.50      0.33      0.40         3
#         AB09       1.00      1.00      1.00         3
#         AB10       0.75      1.00      0.86         3
#         AB11       0.60      1.00      0.75         3
#         AB12       1.00      0.67      0.80         3
#       Normal       0.96      0.91      0.93       108
#
#     accuracy                           0.82       150
# ...

# %%
#create CF 
data = {'Actual': act,'Predicted' : pred,}
df = pd.DataFrame(data, columns=['Actual','Predicted'])
conf_mat = pd.crosstab(df['Actual'],df['Predicted'],rownames=['Actual'],colnames=['Predicted'])

#Confusion matrix
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
cm = confusion_matrix(act, pred)

#plot Confusion matrix
import seaborn as sns
sns.set()
fig, ax = plt.subplots(figsize=(8, 5))

ax = sns.heatmap(conf_mat, annot=True, fmt="d", cmap="YlGnBu") #Blues,Oranges,Reds
ax.set_title('Confusion matrix',fontsize=20)
ax.set_ylabel('True label',fontsize=18)
ax.set_xlabel('Predicted label',fontsize=18)
# Out:
# Text(0.5, 21.5, 'Predicted label')

# %%
act= result['Class'].map({'Normal':0,'Abnormal':1}).values
pred = result['U11_Pred'].map({'AB12':1, 'AB04':1, 'AB05':1, 'Normal':0, 'AB02':1, 'AB11':1, 'AB082':1, 'AB06':1, 'AB081':1, 'AB09':1, 'AB03':1, 'AB10':1, 'AB01':1, 'AB083':1}).values

# %%
cmat = confusion_matrix(act, pred)
print('classifier accuracy = {}%'.format((100.*np.trace(cmat))/(np.sum(cmat))))

#Marking the Confusion Matrix
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(act, pred))#performance
# Out:
# classifier accuracy = 90.66666666666667%
#               precision    recall  f1-score   support
#
#            0       0.96      0.91      0.93       108
#            1       0.79      0.90      0.84        42
#
#     accuracy                           0.91       150
#    macro avg       0.88      0.91      0.89       150
# weighted avg       0.91      0.91      0.91       150

# %%
#create CF 
data = {'Actual': act,'Predicted' : pred,}
df = pd.DataFrame(data, columns=['Actual','Predicted'])
conf_mat = pd.crosstab(df['Actual'],df['Predicted'],rownames=['Actual'],colnames=['Predicted'])

#Confusion matrix
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
cm = confusion_matrix(act, pred)

#plot Confusion matrix
import seaborn as sns
sns.set()
fig, ax = plt.subplots(figsize=(8, 5))

ax = sns.heatmap(conf_mat, annot=True, fmt="d", cmap="YlGnBu") #Blues,Oranges,Reds
ax.set_title('Confusion matrix',fontsize=20)
ax.set_ylabel('True label',fontsize=18)
ax.set_xlabel('Predicted label',fontsize=18)
# Out:
# Text(0.5, 21.5, 'Predicted label')

# %% [markdown]
# # AI

# %%
import numpy as np
from sklearn.metrics import confusion_matrix
act = result['sub_class.1'].array
pred = result['AI_Pred'].array

cmat = confusion_matrix(act, pred)
print('classifier accuracy = {}%'.format((100.*np.trace(cmat))/(np.sum(cmat))))

#Marking the Confusion Matrix
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(act, pred))#performance
# Out:
# classifier accuracy = 84.66666666666667%
#               precision    recall  f1-score   support
#
#         AB01       0.50      0.33      0.40         3
#         AB02       0.40      0.67      0.50         3
#         AB03       1.00      0.67      0.80         3
#         AB04       0.40      0.67      0.50         3
#         AB05       0.50      0.33      0.40         3
#         AB06       1.00      0.67      0.80         3
#         AB07       0.00      0.00      0.00         3
#        AB081       0.40      0.67      0.50         3
#        AB082       0.25      0.33      0.29         3
#        AB083       0.00      0.00      0.00         3
#         AB09       1.00      1.00      1.00         3
#         AB10       1.00      0.67      0.80         3
#         AB11       1.00      0.33      0.50         3
#         AB12       0.67      0.67      0.67         3
#       Normal       0.94      0.98      0.96       108
#
#     accuracy                           0.85       150
# ...

# %%
#create CF 
data = {'Actual': act,'Predicted' : pred,}
df = pd.DataFrame(data, columns=['Actual','Predicted'])
conf_mat = pd.crosstab(df['Actual'],df['Predicted'],rownames=['Actual'],colnames=['Predicted'])

#Confusion matrix
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
cm = confusion_matrix(act, pred)

#plot Confusion matrix
import seaborn as sns
sns.set()
fig, ax = plt.subplots(figsize=(8, 5))

ax = sns.heatmap(conf_mat, annot=True, fmt="d", cmap="YlGnBu") #Blues,Oranges,Reds
ax.set_title('Confusion matrix',fontsize=20)
ax.set_ylabel('True label',fontsize=18)
ax.set_xlabel('Predicted label',fontsize=18)
# Out:
# Text(0.5, 21.5, 'Predicted label')

# %%
act= result['Class'].map({'Normal':0,'Abnormal':1}).values
pred = result['AI_Pred'].map({'AB12':1, 'AB04':1, 'AB05':1, 'Normal':0, 'AB02':1, 'AB11':1, 'AB082':1, 'AB06':1, 'AB081':1, 'AB09':1, 'AB03':1, 'AB10':1, 'AB01':1, 'AB083':1}).values

# %%
cmat = confusion_matrix(act, pred)
print('classifier accuracy = {}%'.format((100.*np.trace(cmat))/(np.sum(cmat))))

#Marking the Confusion Matrix
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(act, pred))#performance
# Out:
# classifier accuracy = 94.0%
#               precision    recall  f1-score   support
#
#            0       0.94      0.98      0.96       108
#            1       0.95      0.83      0.89        42
#
#     accuracy                           0.94       150
#    macro avg       0.94      0.91      0.92       150
# weighted avg       0.94      0.94      0.94       150

# %%
#create CF 
data = {'Actual': act,'Predicted' : pred,}
df = pd.DataFrame(data, columns=['Actual','Predicted'])
conf_mat = pd.crosstab(df['Actual'],df['Predicted'],rownames=['Actual'],colnames=['Predicted'])

#Confusion matrix
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
cm = confusion_matrix(act, pred)

#plot Confusion matrix
import seaborn as sns
sns.set()
fig, ax = plt.subplots(figsize=(8, 5))

ax = sns.heatmap(conf_mat, annot=True, fmt="d", cmap="YlGnBu") #Blues,Oranges,Reds
ax.set_title('Confusion matrix',fontsize=20)
ax.set_ylabel('True label',fontsize=18)
ax.set_xlabel('Predicted label',fontsize=18)
# Out:
# Text(0.5, 21.5, 'Predicted label')

# %% [markdown]
# # Graph

# %%
import pandas as pd
result= pd.read_csv( '/home/yupaporn/codes/USAI/Experiment_test.csv')
result
# Out:
#      Unnamed: 0  num            FileName sub_class views  \
# 0             0    1    AB01 P1 C100.JPG      AB01  FP-A
# 1             1    2  AB01 P4-2 C050.JPG      AB01  FP-B
# 2             2    3  AB01 P5-2 C004.JPG      AB01  FP-C
# 3             3    4    AB02 P1 C001.JPG      AB02  FP-A
# 4             4    5  AB02 P3-1 C001.JPG      AB02  FP-B
# ..          ...  ...                 ...       ...   ...
# 145         145  146          P8C193.jpg    Normal  FP-E
# 146         146  147     P8_Case_007.jpg    Normal  FP-E
# 147         147  148     P8_Case_025.jpg    Normal  FP-E
# 148         148  149     P8_Case_029.jpg    Normal  FP-E
# 149         149  150     P8_Case_032.jpg    Normal  FP-E
#
#                                               img_path  \
# 0    /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 1    /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2    /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# ...

# %%
df= pd.read_csv( '/home/yupaporn/codes/USAI/RF_Test_Experimaent.csv')
df0 = df[['Path Full','category','Prob','category_top3','Prob_top3']]

# %%
df00 = pd.merge(result,df0, on='Path Full', how='outer')
df00
# Out:
#      Unnamed: 0  num            FileName sub_class views  \
# 0             0    1    AB01 P1 C100.JPG      AB01  FP-A
# 1             1    2  AB01 P4-2 C050.JPG      AB01  FP-B
# 2             2    3  AB01 P5-2 C004.JPG      AB01  FP-C
# 3             3    4    AB02 P1 C001.JPG      AB02  FP-A
# 4             4    5  AB02 P3-1 C001.JPG      AB02  FP-B
# ..          ...  ...                 ...       ...   ...
# 145         145  146          P8C193.jpg    Normal  FP-E
# 146         146  147     P8_Case_007.jpg    Normal  FP-E
# 147         147  148     P8_Case_025.jpg    Normal  FP-E
# 148         148  149     P8_Case_029.jpg    Normal  FP-E
# 149         149  150     P8_Case_032.jpg    Normal  FP-E
#
#                                               img_path  \
# 0    /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 1    /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2    /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# ...

# %%
AI = df00['AI_Pred'].tolist()
cate = df00['category'].tolist()
FileName = df00['FileName'].tolist()
img_path = df00['img_path'].tolist()
dif = list()
for i in range(len(FileName)):
    if cate[i] != AI[i]:
        a = cate[i] 
        b =  AI[i]
        name = FileName[i]
        c = img_path[i]
        dif.append({'AI_Pred':a,'category':b,'FileName':name,'img_path':c})

# %%
dif
# Out:
# [{'AI_Pred': 'AB05',
#   'category': 'AB06',
#   'FileName': 'AB06 P2 C054.JPG',
#   'img_path': '/media/tohn/HDD/VISION_dataset/USAI/ABnormal01/6 ABNORMAL/cropped/AB06 P2 C054.JPG'},
#  {'AI_Pred': 'Normal',
#   'category': 'AB082',
#   'FileName': 'AB083 P5-1 C001.JPG',
#   'img_path': '/media/tohn/HDD/VISION_dataset/USAI/ABnormal01/8.2,8.3 ABNORMAL/8-3 ABNORMAL/cropped/AB083 P5-1 C001.JPG'},
#  {'AI_Pred': 'Normal',
#   'category': 'AB081',
#   'FileName': 'AB10 P6-1 C040.JPG',
#   'img_path': '/media/tohn/HDD/VISION_dataset/USAI/ABnormal01/10 ABNORMAL/cropped/AB10 P6-1 C040.JPG'},
#  {'AI_Pred': 'AB12',
#   'category': 'AB04',
#   'FileName': 'FP D P7-2 Case 262.JPG.png',
#   'img_path': '/media/tohn/HDD/VISION_dataset/USAI/FPD JULY 2020/FPD P7-2/cropped/FP D P7-2 Case 262.JPG.png'}]

# %%
Abs_dff = pd.DataFrame(dif)
Abs_dff
# Out:
#   AI_Pred category                    FileName  \
# 0    AB05     AB06            AB06 P2 C054.JPG
# 1  Normal    AB082         AB083 P5-1 C001.JPG
# 2  Normal    AB081          AB10 P6-1 C040.JPG
# 3    AB12     AB04  FP D P7-2 Case 262.JPG.png
#
#                                             img_path
# 0  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 1  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 3  /media/tohn/HDD/VISION_dataset/USAI/FPD JULY 2...

# %%
Abs_dff['img_path'][1]
# Out:
# '/media/tohn/HDD/VISION_dataset/USAI/ABnormal01/8.2,8.3 ABNORMAL/8-3 ABNORMAL/cropped/AB083 P5-1 C001.JPG'

# %%
from matplotlib import pyplot as plt
plt.imshow(plt.imread('/media/tohn/HDD/VISION_dataset/USAI/ABnormal01/8.2,8.3 ABNORMAL/8-3 ABNORMAL/cropped/AB083 P5-1 C001.JPG'))

# %%
os.chdir( '/home/yupaporn/codes/USAI/')
df00 = df00.drop(['Unnamed: 0'], axis=1)
testdf = df00
testdf.to_csv('Experiment_test.csv')

# %%
AI =result[['FileName','Path Full','AI_Pred']]
AI
# Out:
#                FileName                                          Path Full  \
# 0      AB01 P1 C100.JPG  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 1    AB01 P4-2 C050.JPG  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2    AB01 P5-2 C004.JPG  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 3      AB02 P1 C001.JPG  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 4    AB02 P3-1 C001.JPG  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# ..                  ...                                                ...
# 145          P8C193.jpg  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 146     P8_Case_007.jpg  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 147     P8_Case_025.jpg  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 148     P8_Case_029.jpg  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 149     P8_Case_032.jpg  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
#
#     AI_Pred
# 0      AB02
# 1      AB02
# 2      AB01
# 3      AB02
# ...

# %%
U10 =result[['FileName','Path Full','U10_Pred']]
U10
# Out:
#                FileName                                          Path Full  \
# 0      AB01 P1 C100.JPG  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 1    AB01 P4-2 C050.JPG  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2    AB01 P5-2 C004.JPG  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 3      AB02 P1 C001.JPG  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 4    AB02 P3-1 C001.JPG  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# ..                  ...                                                ...
# 145          P8C193.jpg  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 146     P8_Case_007.jpg  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 147     P8_Case_025.jpg  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 148     P8_Case_029.jpg  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 149     P8_Case_032.jpg  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
#
#     U10_Pred
# 0     Normal
# 1     Normal
# 2       AB03
# ...

# %%
U11 =result[['FileName','Path Full','U11_Pred']]
U11
# Out:
#                FileName                                          Path Full  \
# 0      AB01 P1 C100.JPG  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 1    AB01 P4-2 C050.JPG  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2    AB01 P5-2 C004.JPG  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 3      AB02 P1 C001.JPG  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 4    AB02 P3-1 C001.JPG  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# ..                  ...                                                ...
# 145          P8C193.jpg  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 146     P8_Case_007.jpg  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 147     P8_Case_025.jpg  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 148     P8_Case_029.jpg  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
# 149     P8_Case_032.jpg  /media/tohn/HDD/VISION_dataset/USAI/Prelim. Im...
#
#     U11_Pred
# 0       AB02
# 1       AB02
# 2       AB02
# ...

# %%
# result = result.drop(['Unnamed: 0', 'Unnamed: 0.1'], axis=1)
import os
os.chdir( '/home/yupaporn/codes/USAI/')
AI.to_csv('Experiment_AI.csv')
U10.to_csv('Experiment_U10.csv')
U11.to_csv('Experiment_U11ass.csv')

# %%
tagName1 = result['tagName1'].tolist()
tagName2 = result['tagName2'].tolist()
tag = list()
for i in range(len(tagName1)):
    if tagName1[i] == tagName2[i] :
        a = tagName1[i]
        tag.append(a)
    else :
        a = 'different'
        tag.append(a)

# %%
result['tagName0'] = tag

# %%
result.head()
# Out:
#    Unnamed: 0  num            FileName sub_class views  \
# 0           0    1    AB01 P1 C100.JPG      AB01  FP-A
# 1           1    2  AB01 P4-2 C050.JPG      AB01  FP-B
# 2           2    3  AB01 P5-2 C004.JPG      AB01  FP-C
# 3           3    4    AB02 P1 C001.JPG      AB02  FP-A
# 4           4    5  AB02 P3-1 C001.JPG      AB02  FP-B
#
#                                             img_path  \
# 0  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 1  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 3  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 4  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
#
#                                        originalImage tagName1 tagName2  \
# 0  https://irisprodseatraining.blob.core.windows....     Easy     Easy
# 1  https://irisprodseatraining.blob.core.windows....     Easy     Easy
# 2  https://irisprodseatraining.blob.core.windows....     Easy     Easy
# ...

# %%
sub_class = result['sub_class'].tolist()
AI_Pred = result['AI_Pred'].tolist()
pred = list()
for i in range(len(sub_class)):
    if sub_class[i] == AI_Pred[i] :
        a = 1
        pred.append(a)
    else :
        a = 0
        pred.append(a)
        
sub_class = result['sub_class'].tolist()
U10_Pred = result['U10_Pred'].tolist()
pred1 = list()
for i in range(len(sub_class)):
    if sub_class[i] == U10_Pred[i] :
        a = 1
        pred1.append(a)
    else :
        a = 0
        pred1.append(a)
sub_class = result['sub_class'].tolist()
U11_Pred = result['U11_Pred'].tolist()
pred2 = list()
for i in range(len(sub_class)):
    if sub_class[i] == U11_Pred[i] :
        a = 1
        pred2.append(a)
    else :
        a = 0
        pred2.append(a)

# %%
sub_class = result['sub_class'].tolist()
U10_Pred = result['U10_Pred'].tolist()
pred1 = list()
for i in range(len(sub_class)):
    if sub_class[i] == U10_Pred[i] :
        a = 1
        pred1.append(a)
    else :
        a = 0
        pred1.append(a)

# %%
sub_class = result['sub_class'].tolist()
U11_Pred = result['U11_Pred'].tolist()
pred2 = list()
for i in range(len(sub_class)):
    if sub_class[i] == U11_Pred[i] :
        a = 1
        pred2.append(a)
    else :
        a = 0
        pred2.append(a)

# %%
result['AI_Pred0'] = pred
result['U10_Pred0'] = pred1
result['U11_Pred0'] = pred2

# %%
AI = result['AI_Pred'].map({'AB12':1, 'AB04':1, 'AB05':1, 'Normal':0, 'AB02':1, 'AB11':1, 'AB082':1, 'AB06':1, 'AB081':1, 'AB09':1, 'AB03':1, 'AB10':1, 'AB01':1, 'AB083':1}).values
U10 = result['U10_Pred'].map({'AB12':1, 'AB04':1, 'AB05':1, 'Normal':0, 'AB02':1, 'AB11':1, 'AB082':1, 'AB06':1, 'AB081':1, 'AB09':1, 'AB03':1, 'AB10':1, 'AB01':1, 'AB083':1}).values
U11 = result['U11_Pred'].map({'AB12':1, 'AB04':1, 'AB05':1, 'Normal':0, 'AB02':1, 'AB11':1, 'AB082':1, 'AB06':1, 'AB081':1, 'AB09':1, 'AB03':1, 'AB10':1, 'AB01':1, 'AB083':1}).values

# %%
result['AI_Pred0_AN'] = AI
result['U10_Pred0_AN'] = AI
result['U11_Pred0_AN'] = AI

# %%
Act = result['Class'].map({'Abnormal':1, 'Normal':0}).values
result['Act'] = Act

# %%
result.head()
# Out:
#    Unnamed: 0  num            FileName sub_class views  \
# 0           0    1    AB01 P1 C100.JPG      AB01  FP-A
# 1           1    2  AB01 P4-2 C050.JPG      AB01  FP-B
# 2           2    3  AB01 P5-2 C004.JPG      AB01  FP-C
# 3           3    4    AB02 P1 C001.JPG      AB02  FP-A
# 4           4    5  AB02 P3-1 C001.JPG      AB02  FP-B
#
#                                             img_path  \
# 0  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 1  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 3  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 4  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
#
#                                        originalImage tagName1 tagName2  \
# 0  https://irisprodseatraining.blob.core.windows....     Easy     Easy
# 1  https://irisprodseatraining.blob.core.windows....     Easy     Easy
# 2  https://irisprodseatraining.blob.core.windows....     Easy     Easy
# ...

# %%
result[["tagName0","U10_Pred0","Case"]].groupby(['tagName0','U10_Pred0']).count()
# Out:
#                      Case
# tagName0  U10_Pred0
# Easy      0            38
#           1            18
# Hard      0            35
#           1             9
# different 0            22
#           1            28

# %%
result[["tagName0","U11_Pred0","Case"]].groupby(['tagName0','U11_Pred0']).count()
# Out:
#                      Case
# tagName0  U11_Pred0
# Easy      0            13
#           1            43
# Hard      0            11
#           1            33
# different 0             3
#           1            47

# %%
result[["tagName0","AI_Pred0","Case"]].groupby(['tagName0','AI_Pred0']).count()
# Out:
#                     Case
# tagName0  AI_Pred0
# Easy      0           10
#           1           46
# Hard      0           11
#           1           33
# different 0            2
#           1           48

# %%
import matplotlib.pyplot as plt
import numpy as np
from pylab import plot, show, title, xlabel, ylabel
from pylab import legend
from pylab import axis

# %%
fig, ax = plt.subplots(figsize=(12, 7))

labels = ['Hard', 'Easy', 'different']
correct = [42, 61, 75]
wrong = [46, 51, 25]

plt.ylim(0,80) 
x = np.arange(len(labels))  # the label locations
width = 0.3  # the width of the bars
rects1 = ax.bar(x - width/2 , correct, width, color='#5cac2d', label='Correct')
rects2 = ax.bar(x + width/2, wrong, width, color='#be0119', label='Wrong')
# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Count',fontsize=20)
ax.set_title('Count by group and performance (15AB)',fontsize=25)
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()


def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')


autolabel(rects1)
autolabel(rects2)

fig.tight_layout()

plt.show()

# %%
# import matplotlib
# import matplotlib.pyplot as plt
# import numpy as np


# labels = ['Hard', 'Easy', 'different']
# men_means = [42, 61, 75]
# women_means = [46, 51, 25]

# x = np.arange(len(labels))  # the label locations
# width = 0.35  # the width of the bars

# fig, ax = plt.subplots(figsize=(10, 6))
# rects1 = ax.bar(x - width/2, men_means, width, label='Correct')
# rects2 = ax.bar(x + width/2, women_means, width, label='Wrong')

# # Add some text for labels, title and custom x-axis tick labels, etc.
# ax.set_ylabel('Count')
# ax.set_title('Count by group and performance (15AB)')
# ax.set_xticks(x)
# ax.set_xticklabels(labels)
# ax.legend()


# def autolabel(rects):
#     """Attach a text label above each bar in *rects*, displaying its height."""
#     for rect in rects:
#         height = rect.get_height()
#         ax.annotate('{}'.format(height),
#                     xy=(rect.get_x() + rect.get_width() / 2, height),
#                     xytext=(0, 3),  # 3 points vertical offset
#                     textcoords="offset points",
#                     ha='center', va='bottom')


# autolabel(rects1)
# autolabel(rects2)

# fig.tight_layout()

# plt.show()

# %%
fig, ax = plt.subplots(figsize=(12, 7))

labels = ['Hard', 'Easy', 'different']
correct = [9, 18, 28]
wrong = [35, 38, 22]

plt.ylim(0,50) 
x = np.arange(len(labels))  # the label locations
width = 0.3  # the width of the bars
rects1 = ax.bar(x - width/2 , correct, width, color='#a4be5c', label='Correct')
rects2 = ax.bar(x + width/2, wrong, width, color='#ca6641', label='Wrong')
# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Count',fontsize=20)
ax.set_title('Count by group (15AB) U10 case',fontsize=25)
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()


def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')


autolabel(rects1)
autolabel(rects2)

fig.tight_layout()

plt.show()

# %%
fig, ax = plt.subplots(figsize=(12, 7))

labels = ['Hard', 'Easy', 'different']
correct = [33, 43, 47]
wrong = [11, 13, 3]

plt.ylim(0,50) 
x = np.arange(len(labels))  # the label locations
width = 0.3  # the width of the bars
rects1 = ax.bar(x - width/2 , correct, width, color='#a4be5c', label='Correct')
rects2 = ax.bar(x + width/2, wrong, width, color='#ca6641', label='Wrong')
# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Count',fontsize=20)
ax.set_title('Count by group (15AB) U11ass case',fontsize=25)
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()


def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')


autolabel(rects1)
autolabel(rects2)

fig.tight_layout()

plt.show()

# %%
fig, ax = plt.subplots(figsize=(12, 7))

labels = ['Hard', 'Easy', 'different']
correct = [33, 46, 48]
wrong = [11, 10, 2]

plt.ylim(0,50) 
x = np.arange(len(labels))  # the label locations
width = 0.3  # the width of the bars
rects1 = ax.bar(x - width/2 , correct, width, color='#a4be5c', label='Correct')
rects2 = ax.bar(x + width/2, wrong, width, color='#ca6641', label='Wrong')
# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Count',fontsize=20)
ax.set_title('Count by group (15AB) AI case',fontsize=25)
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()


def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')


autolabel(rects1)
autolabel(rects2)

fig.tight_layout()

plt.show()
