# %%
import pandas as pd
df = pd.read_csv('/home/yupaporn/CSV_file/Dataset_CCA_case_all6628.csv')
df
# Out:
#       Unnamed: 0     Case Abs Position Sub Position     Class  \
# 0              0  AB01_15           P3          P31  Abnormal
# 1              1  AB01_15           P1           P1  Abnormal
# 2              2  AB01_15           P2           P2  Abnormal
# 3              3  AB01_15           P4          P42  Abnormal
# 4              4  AB01_15           P4          P41  Abnormal
# ...          ...      ...          ...          ...       ...
# 6623          54  AB17_20          NaN          NaN  Abnormal
# 6624          55  AB17_09          NaN          NaN  Abnormal
# 6625          56  AB17_01          NaN          NaN  Abnormal
# 6626          57  AB17_07          NaN          NaN  Abnormal
# 6627          58  AB17_15          NaN          NaN  Abnormal
#
#                                               Path Full  \
# 0     /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 1     /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# ...

# %%
Test = df[df['Spilt'] == 'Test']
Train = df[df['Spilt'] != 'Test']
print(len(Test))
print(len(Train))
# Out:
# 1328
# 5300

# %%
5300+1328
# Out:
# 6628

# %%
Train.to_csv('/home/yupaporn/CSV_file/Train_Dataset_CCA_5300.csv')
Test.to_csv('/home/yupaporn/CSV_file/Test_Dataset_CCA_1328.csv')

# %% [markdown]
# ## Load to Test Train folders

# %%
import pandas as pd
traindf = pd.read_csv (r'/home/yupaporn/CSV_file/Train_Dataset_CCA_5300.csv')
traindf
# Out:
#       Unnamed: 0  Unnamed: 0.1     Case Abs Position Sub Position     Class  \
# 0              0             0  AB01_15           P3          P31  Abnormal
# 1              1             1  AB01_15           P1           P1  Abnormal
# 2              2             2  AB01_15           P2           P2  Abnormal
# 3              3             3  AB01_15           P4          P42  Abnormal
# 4              4             4  AB01_15           P4          P41  Abnormal
# ...          ...           ...      ...          ...          ...       ...
# 5295        6621            52  AB17_05          NaN          NaN  Abnormal
# 5296        6622            53  AB17_08          NaN          NaN  Abnormal
# 5297        6623            54  AB17_20          NaN          NaN  Abnormal
# 5298        6624            55  AB17_09          NaN          NaN  Abnormal
# 5299        6625            56  AB17_01          NaN          NaN  Abnormal
#
# ...

# %%
import os
os.chdir('/media/tohn/SSD/Images/Image_13122564')
# !ls
# Out:
# test  train

# %% [markdown]
# ### Train

# %%
import shutil
dic = {"filename": []}
case = list()

path_train = traindf['Path Crop'].tolist() 
#Train
train_Nor_dir = '/media/tohn/SSD/Images/Image_13122564/train'
fnames = path_train  
for fname in fnames:
    dst = os.path.join(train_Nor_dir, os.path.basename(fname))
    if os.path.exists(dst):
        dst = dst+'cp.jpg'
    a = dst.split('/')[-1]
    dic["filename"].append(a)
    shutil.copyfile(fname, dst)

# %%
dics = pd.DataFrame(dic)
len(dics)
# Out:
# 5300

# %% [markdown]
# ### Test

# %%
testdf  = pd.read_csv (r'/home/yupaporn/CSV_file/Test_Dataset_CCA_1328.csv')
testdf
# Out:
#       Unnamed: 0  Unnamed: 0.1     Case Abs Position Sub Position     Class  \
# 0            111           111  AB01_40           P1           P1  Abnormal
# 1            112           112  AB01_40           P2           P2  Abnormal
# 2            113           113  AB01_40           P4          P41  Abnormal
# 3            114           114  AB01_40           P5          P51  Abnormal
# 4            115           115  AB01_40           P3          P31  Abnormal
# ...          ...           ...      ...          ...          ...       ...
# 1323        6607            38  AB17_04          NaN          NaN  Abnormal
# 1324        6616            47  AB17_17          NaN          NaN  Abnormal
# 1325        6617            48  AB17_13          NaN          NaN  Abnormal
# 1326        6626            57  AB17_07          NaN          NaN  Abnormal
# 1327        6627            58  AB17_15          NaN          NaN  Abnormal
#
# ...

# %%
import shutil
dic = {"filename": []}
case = list()

path_train = testdf['Path Crop'].tolist() 
#Train
train_Nor_dir = '/media/tohn/SSD/Images/Image_13122564/test'
fnames = path_train  
for fname in fnames:
    dst = os.path.join(train_Nor_dir, os.path.basename(fname))
    if os.path.exists(dst):
        dst = dst+'cp.jpg'
    a = dst.split('/')[-1]
    dic["filename"].append(a)
    shutil.copyfile(fname, dst)

# %%
dics = pd.DataFrame(dic)
len(dics)
# Out:
# 1328
